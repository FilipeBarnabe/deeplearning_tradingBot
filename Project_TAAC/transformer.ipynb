# %%
# Data related variables, treatment, loading and visualization
import pandas as pd
from pandas_datareader import data
import numpy as np
import matplotlib.pyplot as plt
import math

# Just to time the training of the model
import time

# Pytorch libraries to create and train the model
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchmetrics import MeanAbsoluteError, MeanAbsolutePercentageError
from torchinfo import summary

# Remove Warnings 
import warnings
warnings.filterwarnings('ignore')

# %%
def get_data(ticker: str, dates: list[str, str]) -> pd.DataFrame:
    """The dataset is delivered in USD, gets the data from the yahoo finance API

    Args:
        ticker (str): the ticker of stock, ETF or crypto (example.: apple->ticker:AAPL)
        dates (list[str, str]): list of two dates of str type, [start data, end date] (example.: ["2012-10-21", "2022-10-20"])

    Returns:
        pd.DataFrame: returns the dataset as dataframe
    """
    # API call to get the data as a dataframe
    panel_data = data.DataReader(ticker, "yahoo", dates[0], dates[1])

    # Resample the data to normalize it, the data comes without any data on the (days that the markets are close, weekends)
    panel_data = panel_data.resample("D").max()

    # Fill the data in the closed markets with the data from the previous trading day, because it is their true value
    panel_data = panel_data.fillna(method="ffill")

    print(f"\n{ticker} data acquired")

    return panel_data

# %%
# Get the data for S&P500 ticker ^GSPC 
ticker = "^GSPC"

source_df = get_data(ticker=ticker, dates=["2000-01-01", "2022-12-1"])
source_df = source_df.reset_index()
source_df.tail()
# Out:
# ^GSPC data acquired
#            Date         High          Low         Open        Close  \
# 8364 2022-11-27  4034.020020  4020.760010  4023.340088  4026.120117
# 8365 2022-11-28  4012.270020  3955.770020  4005.360107  3963.939941
# 8366 2022-11-29  3976.770020  3937.649902  3964.189941  3957.629883
# 8367 2022-11-30  4080.110107  3938.580078  3957.179932  4080.110107
# 8368 2022-12-01  4100.509766  4050.870117  4087.139893  4076.570068
#
#             Volume    Adj Close
# 8364  1.706460e+09  4026.120117
# 8365  3.615430e+09  3963.939941
# 8366  3.546040e+09  3957.629883
# 8367  6.579360e+09  4080.110107
# 8368  4.527130e+09  4076.570068

# %%
def two_plots(ticker: str, df: pd.DataFrame) -> None:
    """Generates the plot to show the prices and Volume of the stock

    Args:
        ticker (str): the trading stock
        df (pd.DataFrame): the dataframe with the data of the stock
    """
    fig = plt.figure(figsize=(15,10))
    st = fig.suptitle(f"{ticker} Close Price")
    st.set_y(0.92)

    ax1 = fig.add_subplot(211)
    ax1.plot(df['Date'],df['Close'], label=f'{ticker} Close Price')
    ax1.set_ylabel('Close Price', fontsize=18)
    ax1.legend(loc="upper left", fontsize=12)
    ax1.grid(linestyle="--")

    ax2 = fig.add_subplot(212)
    ax2.plot(df["Date"],df['Volume'], label=f'{ticker} Volume')
    ax2.set_ylabel('Volume', fontsize=18)
    ax2.legend(loc="upper left", fontsize=12)
    ax2.grid(linestyle="--")

# %% [markdown]
# # Main parameters to feed the model
# Sequence length -> 128 days\
# Batch size -> 32 sequences per batch
#
# With the 128 days we'll predict the following day
#
#
# Since we have 5 features, this will result in batches of size (32, 128, 5):
# * Price Columns (4 features):
#     * Open
#     * High
#     * Low
#     * Close
# * Volume Columns (1 feature):
#     * Volume

# %%
# the features are separated into sequences of 128 days, 4 price features and 1 volume feature
seq_len = 128

# during a single step the model receives 32 sequences
batch_size = 32

# %%
# Selection of columns
df = source_df[["Date", "High", "Low", "Open", "Close", "Volume"]].copy(deep=True)

# Avoid dividing by 0 
# (The volume isn't a given, for really old data we can have values of 0 for the volume)
df['Volume'].replace(to_replace=0, method='ffill', inplace=True)

# Sort the values based on date
df.sort_values('Date', inplace=True)

df.tail()
# Out:
#            Date         High          Low         Open        Close  \
# 8364 2022-11-27  4034.020020  4020.760010  4023.340088  4026.120117
# 8365 2022-11-28  4012.270020  3955.770020  4005.360107  3963.939941
# 8366 2022-11-29  3976.770020  3937.649902  3964.189941  3957.629883
# 8367 2022-11-30  4080.110107  3938.580078  3957.179932  4080.110107
# 8368 2022-12-01  4100.509766  4050.870117  4087.139893  4076.570068
#
#             Volume
# 8364  1.706460e+09
# 8365  3.615430e+09
# 8366  3.546040e+09
# 8367  6.579360e+09
# 8368  4.527130e+09

# %%
two_plots(ticker=ticker, df=df)

# %% [markdown]
# ## Data normalization
# - Instead of the values we keep the percentage of change
# - Get the separation index values
# - Get the min and max returns
# - Normalize the data with the max and min (0-1 range)

# %%
def data_normalization(df: pd.DataFrame) -> tuple[pd.DataFrame, np.int64, np.int64]:
    """normalizes the data

    Args:
        df (pd.DataFrame): data

    Returns:
        tuple[pd.DataFrame, np.int64, np.int64]: dataframe, last 10 percent, last 20 percent
    """
    # Create arithmetic returns column
    df['Open'] = df['Open'].pct_change() 
    df['High'] = df['High'].pct_change()
    df['Low'] = df['Low'].pct_change()
    df['Close'] = df['Close'].pct_change()
    df['Volume'] = df['Volume'].pct_change()

    # Drop the rows with the NaN created by the percentage change
    df.dropna(how="any", axis=0, inplace=True)

    # Get the values to create the separation of the dataset
    times = sorted(df.index.values)
    last_10pct = sorted(df.index.values)[-int(0.1*len(times))]
    last_20pct = sorted(df.index.values)[-int(0.2*len(times))]

    # min-max price columns
    min_return = min(df[(df.index<last_20pct)][["Open", "High", "Low", "Close"]].min(axis=0))
    max_return = max(df[(df.index<last_20pct)][["Open", "High", "Low", "Close"]].max(axis=0))

    # Min-max normalize price columns (0-1 range)
    df["Open"] = (df["Open"] - min_return) / (max_return - min_return)
    df["High"] = (df["High"] - min_return) / (max_return - min_return)
    df["Low"] = (df["Low"] - min_return) / (max_return - min_return)
    df["Close"] = (df["Close"] - min_return) / (max_return - min_return)

    # min-max volume column
    min_volume = df[(df.index<last_20pct)]["Volume"].min(axis=0)
    max_volume = df[(df.index<last_20pct)]["Volume"].max(axis=0)

    # Min-max normalize volume columns (0-1 range)
    df["Volume"] = (df["Volume"] - min_volume) / (max_volume - min_volume)

    return df, last_10pct, last_20pct

# %%
df, last_10pct, last_20pct = data_normalization(df=df)

# %% [markdown]
# ## Split the data
# - Split into train, the first 80% of the data
# - Split into validation, between the first 80% and 90% of the data
# - Split into test, between 90% and tha 100% of the data

# %%
def split_data(df: pd.DataFrame, last_20pct: np.int64, last_10pct: np.int64) -> tuple[np.ndarray, np.ndarray, np.ndarray]:
    """Splits the data into train, validation and test

    Args:
        df (pd.DataFrame): data to split
        last_20pct (np.int64): the position to split on the 80%
        last_10pct (np.int64): the position to split on the 90%

    Returns:
        tuple[np.ndarray, np.ndarray, np.ndarray]: train data, validation data and test data
    """
    df_train = df[(df.index < last_20pct)]
    df_val = df[(df.index >= last_20pct) & (df.index < last_10pct)]
    df_test = df[(df.index >= last_10pct)]

    # Drop the date column from the splitted datasets
    df_train.drop(columns=["Date"], inplace=True)
    df_val.drop(columns=["Date"], inplace=True)
    df_test.drop(columns=["Date"], inplace=True)

    # Train data into arrays np.ndarray
    train_data = df_train.values
    val_data = df_val.values
    test_data = df_test.values

    print('Training data shape: {}'.format(train_data.shape))
    print('Validation data shape: {}'.format(val_data.shape))
    print('Test data shape: {}'.format(test_data.shape))

    print(df_train.head(10))

    return (train_data, val_data, test_data)

# %%
train_data, val_data, test_data = split_data(df=df, last_10pct=last_10pct, last_20pct=last_20pct)
# Out:
# Training data shape: (6695, 5)
# Validation data shape: (837, 5)
# Test data shape: (836, 5)
#         High       Low      Open     Close    Volume
# 1   0.363507  0.300237  0.391951  0.252268  0.211225
# 2   0.298436  0.369714  0.252268  0.447596  0.209465
# 3   0.433569  0.489044  0.447596  0.442908  0.192058
# 4   0.539865  0.468343  0.442908  0.569683  0.220940
# 5   0.438272  0.438272  0.438272  0.438272  0.190491
# 6   0.438272  0.438272  0.438272  0.438272  0.190491
# 7   0.515301  0.579357  0.569683  0.492552  0.157727
# 8   0.419390  0.414547  0.492552  0.374908  0.178551
# 9   0.384863  0.413449  0.374908  0.416994  0.180766
# 10  0.477277  0.455845  0.416994  0.497305  0.204819

# %% [markdown]
# # Visualization of the data separated

# %%
def data_separated_plot(train_data: np.ndarray, val_data: np.ndarray, test_data: np.ndarray):
    """Visualize the data splitted

    Args:
        train_data (np.ndarray): training data
        val_data (np.ndarray): validation data
        test_data (np.ndarray): testing data
    """
    fig = plt.figure(figsize=(15, 10))
    st = fig.suptitle("Data Separation", fontsize=20)
    st.set_y(0.95)

    ax1 = fig.add_subplot(211)
    ax1.plot(np.arange(train_data.shape[0]), train_data[:,3], label='Training data')
    ax1.plot(np.arange(train_data.shape[0], train_data.shape[0]+val_data.shape[0]), val_data[:,3], label='Validation data')
    ax1.plot(np.arange(train_data.shape[0]+val_data.shape[0], train_data.shape[0]+val_data.shape[0]+test_data.shape[0]), test_data[:,3], label='Test data')
    ax1.set_xlabel('Date')
    ax1.set_ylabel('Normalized Closing Returns')
    ax1.set_title("Close Price", fontsize=18)
    ax1.legend(loc="best", fontsize=12)
    ax1.grid()

    ax2 = fig.add_subplot(212)
    ax2.plot(np.arange(train_data.shape[0]), train_data[:,4], label='Training data')
    ax2.plot(np.arange(train_data.shape[0], train_data.shape[0]+val_data.shape[0]), val_data[:,4], label='Validation data')
    ax2.plot(np.arange(train_data.shape[0]+val_data.shape[0], train_data.shape[0]+val_data.shape[0]+test_data.shape[0]), test_data[:,4], label='Test data')
    ax2.set_xlabel('Date')
    ax2.set_ylabel('Normalized Volume Changes')
    ax2.set_title("Volume", fontsize=18)
    ax2.legend(loc="best", fontsize=12)
    ax2.grid()

# %%
data_separated_plot(train_data=train_data, val_data=val_data, test_data=test_data)

# %% [markdown]
# # Dataset
# Creation of dataset class which will have the definition of the targets and inputs

# %%
class TickerData(Dataset):
    """Dataset class to create the dataset (inputs & targets) for train, validation and test

    Args:
        Dataset (_type_): imported from torch.utils.data
    """
    def __init__(self, data: np.ndarray, seq_len: int) -> None:
        """Init function of dataset class

        Args:
            data (np.ndarray): data from the dataframe to numpy
            seq_len (int): len of values to base for the prediction
        """
        self.inputs, self.targets = [], []

        for i in range(seq_len, len(data)):
            # Chunks of  data with a length of 128 df-rows
            self.inputs.append(data[i-seq_len:i])
            
            # Value of 4th column (Close Price) of df-row 128+1
            self.targets.append(data[:, 3][i])
        
        self.inputs, self.targets = torch.FloatTensor(np.array(self.inputs)), torch.FloatTensor(np.array(self.targets))
        
    def __getitem__(self, idx: int) -> dict:
        """Get item at a certain index

        Args:
            idx (int): index to get the value

        Returns:
            dict: returns the input and the target
        """
        return {'inputs': self.inputs[idx],
                'targets': self.targets[idx]}
    
    def __len__(self) -> int:
        """Length function 

        Returns:
            int: length of the Dataset
        """
        return min(len(self.inputs), len(self.targets))

# %%
train_data = TickerData(data=train_data, seq_len=seq_len)
val_data = TickerData(data=val_data, seq_len=seq_len)
test_data = TickerData(data=test_data, seq_len=seq_len)

# %% [markdown]
# # Data Loader
# Data loading, creation of the batches to feed the model

# %%
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=False, drop_last=True)
val_loader = DataLoader(dataset=val_data, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False, drop_last=True)

# %% [markdown]
# # Device
# For some unknown reason it's faster on CPU however I leave commented the possibility of running on mps

# %%
# device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
device = torch.device("cpu")
device
# Out:
# device(type='cpu')

# %% [markdown]
# # Model Creation -> Transformer
# Creation of the time to vector class for the positional encoding\
# Creation of the transformer model

# %% [markdown]
# ## Time2Vector

# %%
class Time2Vector(nn.Module):
    """Time to vector encoding to keep the position of the values as a feature

    Args:
        nn (_type_): imported from torch 
    """
    def __init__(self, seq_len):
        """init function

        Args:
            seq_len (_type_): sequence length 
        """
        super(Time2Vector, self).__init__()
        self.seq_len = seq_len

        self.weights_linear = nn.Parameter(torch.Tensor(int(self.seq_len)))
        nn.init.uniform_(self.weights_linear)

        self.bias_linear = nn.Parameter(torch.Tensor(int(self.seq_len)))
        nn.init.uniform_(self.bias_linear)

        self.weights_periodic = nn.Parameter(torch.Tensor(int(self.seq_len)))
        nn.init.uniform_(self.weights_periodic)

        self.bias_periodic = nn.Parameter(torch.Tensor(int(self.seq_len)))
        nn.init.uniform_(self.bias_periodic)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        """forward function that gets called when to do the time2vec

        Args:
            x (torch.Tensor): input data

        Returns:
            torch.Tensor: tensor that gives the periodic and the linear features
        """
        x = torch.mean(x[:,:,:4], dim=-1)
        time_linear = self.weights_linear * x + self.bias_linear
        time_linear = time_linear.unsqueeze(-1)

        time_periodic = torch.sin(x * self.weights_periodic + self.bias_periodic)
        time_periodic = time_periodic.unsqueeze(-1)

        return torch.cat([time_linear, time_periodic], dim=-1)

# %% [markdown]
# ## Transformer

# %%
class TimeSeriesTransformer(nn.Module):
    """Transformer model

    Args:
        nn (_type_): module from torch
    """
    def __init__(self,feature_size: int=128, num_layers: int=1, dropout: float=0.0):
        """initiation function that creates the layers

        Args:
            feature_size (int, optional): size of the feature (sequence length). Defaults to 128.
            num_layers (int, optional): number of layers. Defaults to 1.
            dropout (float, optional): dropout. Defaults to 0.0.
        """
        super(TimeSeriesTransformer, self).__init__()
        self.model_type = 'Transformer'
        self.src_mask = None
        self.t2v = Time2Vector(feature_size)
        self.encoder_layer = nn.TransformerEncoderLayer(d_model=feature_size, nhead=8, batch_first=True, dropout=dropout)
        self.transformer_encoder = nn.TransformerEncoder(self.encoder_layer, num_layers=num_layers)     
        self.decoder = nn.Linear(feature_size,1)
        self.init_weights()

    def init_weights(self):
        """weights initialization
        """
        initrange = 0.1    
        self.decoder.bias.data.zero_()
        self.decoder.weight.data.uniform_(-initrange, initrange)

    def forward(self,src: torch.Tensor) -> torch.Tensor:
        
        # Generation of the mask
        if self.src_mask is None or self.src_mask.size(0) != 7:
            device = src.device
            mask = self._generate_square_subsequent_mask(7).to(device)
            self.src_mask = mask

        # first goes through time to vector layer for the position features
        t2v = self.t2v(src)
        # adds the 2 features that derived from the time to the five original features (open, high, low, close, volume)
        src = torch.concatenate((t2v, src), axis=2)
        # encoder layer
        output = self.transformer_encoder(src.swapaxes(1,2), self.src_mask)
        # decoder layer 
        output = self.decoder(output[:, -1, :])

        return output

    def _generate_square_subsequent_mask(self, sz: int) -> torch.Tensor:
        """generates the mask to eliminate the information from the future

        Args:
            sz (int): size of the mask, number of features, in the present case it is 7

        Returns:
            torch.Tensor: mask
        """
        mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
        mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
        
        return mask

# %%
# model attribution
model = TimeSeriesTransformer().to(device)

# The criterion is the MSE (Mean Squared Error)
criterion = nn.MSELoss()

# ADAM as optimizer
lr = 0.005
optimizer = torch.optim.AdamW(model.parameters(), lr=lr)

scheduler = torch.optim.lr_scheduler.StepLR(optimizer=optimizer, step_size=1.0, gamma=0.98)

# Metrics for evaluation of the model
mean_absolute_error = MeanAbsoluteError()
mean_absolute_percentage_error = MeanAbsolutePercentageError()

# %% [markdown]
# # Training

# %%
def train_model(model, prev_loss: torch.Tensor, train_loader: DataLoader, epoch: int) -> tuple[torch.Tensor, torch.Tensor, torch.Tensor]:
    """function to train the model, gets the batch and trains on the batch

    Args:
        train_loader (DataLoader): data to train on
        prev_loss (torch.Tensor): previous loss to save the model on the best loss

    Returns:
        tuple[torch.Tensor, torch.Tensor, torch.Tensor]: returns the loss, mae and mape
    """
    # Turn on the train mode
    model.train()

    total_loss = 0.
    start_time = time.time()

    total_mae = 0.
    total_mape = 0.

    for i, batch in enumerate(train_loader):
        
        # data from batch and to device
        data, targets = batch['inputs'].to(device), batch['targets'].to(device).unsqueeze(1)

        optimizer.zero_grad()

        output = model(data)  

        loss = criterion(output, targets)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
        optimizer.step()

        total_loss += loss.item()
        log_interval = int(len(train_loader) / 5)

        mae = mean_absolute_error(output, targets)
        mape = mean_absolute_percentage_error(output, targets)

        if i % log_interval == 0 and i > 0:
            cur_loss = total_loss / log_interval
            elapsed = time.time() - start_time

            print('| epoch {:3d} | {:5d}/{:5d} batches | '
                  'lr {:02.6f} | {:5.2f} ms | '
                  'loss {:5.5f} | ppl {:8.2f} | '
                  'mae {:5.5f} | mape {:5.5}'.format(
                    epoch, i, len(train_loader), scheduler.get_lr()[0],
                    elapsed * 1000 / log_interval,
                    cur_loss, math.exp(cur_loss),
                    mae.item(), mape.item()))

            total_loss = 0
            start_time = time.time()

        total_mae += mae
        total_mape += mape
            
        if loss < prev_loss:
            
            torch.save(model.state_dict(), 'tranformer_models/state_dict.pt')  # save model state (wights, etc.)
            torch.save(model, 'tranformer_models/model_complete.pt')  # save complete model
            
            prev_loss = loss

    return prev_loss, total_mae / len(train_loader), total_mape / len(train_loader)

# %%
def evaluate(eval_model, val_loader: DataLoader):
    """evaluation function

    Args:
        eval_model (_type_): model
        val_loader (DataLoader): data from dataloader

    Returns:
        _type_: loss, mae, mape
    """
    
    # Turn on the evaluation mode
    eval_model.eval()

    total_loss = 0.

    total_mae = 0.
    total_mape = 0.
    
    with torch.no_grad():
        for _, batch in enumerate(val_loader):
            # print(batch["targets"])
            data, targets = batch['inputs'].to(device), batch["targets"].to(device).unsqueeze(1)
            
            # print(data.size())
            output = eval_model(data)
            total_mae += mean_absolute_error(output, targets)
            total_mape += mean_absolute_percentage_error(output, targets)

            total_loss += len(data[0])* criterion(output[-1:], targets[-1:]).cpu().item()

    return total_loss / len(val_loader), total_mae / len(val_loader), total_mape / len(val_loader)

# %%
def fit(epochs: int, model, train_loader: DataLoader, val_loader: DataLoader) -> tuple[list, list, list, list]:

    # Initialization of the prev loss as Inf to make sure thar the model starts saving
    prev_loss = np.Inf

    # Matrices to store the evaluation metrics
    train_mae = []
    train_mape = []

    val_mae = []
    val_mape = []

    for epoch in range(1, epochs + 1):

        epoch_start_time = time.time()
        prev_loss, mae_train, mape_train = train_model(model=model, prev_loss=prev_loss, epoch=epoch, train_loader=train_loader)
        
        train_mae.append(mae_train.cpu().detach().numpy())
        train_mape.append(mape_train.cpu().detach().numpy())
        
        val_loss, mae_val, mape_val = evaluate(eval_model=model, val_loader=val_loader)

        val_mae.append(mae_val.cpu().detach().numpy())
        val_mape.append(mape_val.cpu().detach().numpy())
            
        print('-' * 118)
        print('| end of epoch {:3d} | time: {:5.2f}s | valid loss {:5.5f} | valid ppl {:8.2f} | valid MAE {:5.5f} | valid MAPE {:5.5f}'.format(epoch, (time.time() - epoch_start_time),
                                        val_loss, math.exp(val_loss), mae_val, mape_val))
        print('-' * 118)

        scheduler.step()

    return train_mae, train_mape, val_mae, val_mape

# %%
train_mae, train_mape, val_mae, val_mape = fit(epochs=1000, model=model, train_loader=train_loader, val_loader=val_loader)
# Out:
# | epoch   1 |    41/  205 batches | lr 0.005000 | 16.36 ms | loss 1.76003 | ppl     5.81 | mae 0.07869 | mape 0.17944
# | epoch   1 |    82/  205 batches | lr 0.005000 | 10.04 ms | loss 0.00825 | ppl     1.01 | mae 0.11329 | mape 0.29213
# | epoch   1 |   123/  205 batches | lr 0.005000 | 10.80 ms | loss 0.00936 | ppl     1.01 | mae 0.04601 | mape 0.11491
# | epoch   1 |   164/  205 batches | lr 0.005000 | 13.20 ms | loss 0.00201 | ppl     1.00 | mae 0.03694 | mape 0.085765
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch   1 | time:  2.60s | valid loss 1.05977 | valid ppl     2.89 | valid MAE 0.03724 | valid MAPE 0.12919
# ----------------------------------------------------------------------------------------------------------------------
# | epoch   2 |    41/  205 batches | lr 0.004802 | 13.11 ms | loss 0.00402 | ppl     1.00 | mae 0.04607 | mape 0.10584
# | epoch   2 |    82/  205 batches | lr 0.004802 | 12.41 ms | loss 0.00108 | ppl     1.00 | mae 0.04388 | mape 0.11274
# | epoch   2 |   123/  205 batches | lr 0.004802 | 11.41 ms | loss 0.00574 | ppl     1.01 | mae 0.04534 | mape 0.1132
# | epoch   2 |   164/  205 batches | lr 0.004802 | 10.57 ms | loss 0.00193 | ppl     1.00 | mae 0.04059 | mape 0.098446
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch   2 | time:  2.46s | valid loss 1.06243 | valid ppl     2.89 | valid MAE 0.03776 | valid MAPE 0.13065
# ----------------------------------------------------------------------------------------------------------------------
# | epoch   3 |    41/  205 batches | lr 0.004706 |  9.63 ms | loss 0.00389 | ppl     1.00 | mae 0.03158 | mape 0.072413
# | epoch   3 |    82/  205 batches | lr 0.004706 |  9.48 ms | loss 0.00092 | ppl     1.00 | mae 0.04381 | mape 0.11263
# | epoch   3 |   123/  205 batches | lr 0.004706 | 10.00 ms | loss 0.00555 | ppl     1.01 | mae 0.04209 | mape 0.1049
# | epoch   3 |   164/  205 batches | lr 0.004706 |  9.27 ms | loss 0.00174 | ppl     1.00 | mae 0.03828 | mape 0.088044
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch   3 | time:  2.02s | valid loss 1.06325 | valid ppl     2.90 | valid MAE 0.03329 | valid MAPE 0.11550
# ----------------------------------------------------------------------------------------------------------------------
# | epoch   4 |    41/  205 batches | lr 0.004612 |  9.09 ms | loss 0.00356 | ppl     1.00 | mae 0.02258 | mape 0.051331
# | epoch   4 |    82/  205 batches | lr 0.004612 |  9.04 ms | loss 0.00093 | ppl     1.00 | mae 0.04503 | mape 0.11789
# | epoch   4 |   123/  205 batches | lr 0.004612 |  8.75 ms | loss 0.00553 | ppl     1.01 | mae 0.03677 | mape 0.091027
# | epoch   4 |   164/  205 batches | lr 0.004612 |  8.42 ms | loss 0.00170 | ppl     1.00 | mae 0.03590 | mape 0.084115
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch   4 | time:  1.90s | valid loss 1.06963 | valid ppl     2.91 | valid MAE 0.03434 | valid MAPE 0.11736
# ----------------------------------------------------------------------------------------------------------------------
# | epoch   5 |    41/  205 batches | lr 0.004520 |  9.25 ms | loss 0.00343 | ppl     1.00 | mae 0.02474 | mape 0.056439
# | epoch   5 |    82/  205 batches | lr 0.004520 |  8.59 ms | loss 0.00097 | ppl     1.00 | mae 0.04325 | mape 0.11233
# | epoch   5 |   123/  205 batches | lr 0.004520 |  8.75 ms | loss 0.00543 | ppl     1.01 | mae 0.03520 | mape 0.086907
# | epoch   5 |   164/  205 batches | lr 0.004520 |  8.95 ms | loss 0.00168 | ppl     1.00 | mae 0.03679 | mape 0.085509
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch   5 | time:  1.88s | valid loss 1.08753 | valid ppl     2.97 | valid MAE 0.03683 | valid MAPE 0.12190
# ----------------------------------------------------------------------------------------------------------------------
# | epoch   6 |    41/  205 batches | lr 0.004429 |  8.87 ms | loss 0.00335 | ppl     1.00 | mae 0.02775 | mape 0.063485
# | epoch   6 |    82/  205 batches | lr 0.004429 |  8.63 ms | loss 0.00097 | ppl     1.00 | mae 0.04333 | mape 0.1119
# | epoch   6 |   123/  205 batches | lr 0.004429 |  8.87 ms | loss 0.00545 | ppl     1.01 | mae 0.03170 | mape 0.076658
# | epoch   6 |   164/  205 batches | lr 0.004429 |  8.97 ms | loss 0.00175 | ppl     1.00 | mae 0.03938 | mape 0.090079
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch   6 | time:  1.88s | valid loss 1.08263 | valid ppl     2.95 | valid MAE 0.03618 | valid MAPE 0.12071
# ----------------------------------------------------------------------------------------------------------------------
# | epoch   7 |    41/  205 batches | lr 0.004341 | 10.03 ms | loss 0.00326 | ppl     1.00 | mae 0.02182 | mape 0.049545
# | epoch   7 |    82/  205 batches | lr 0.004341 | 10.00 ms | loss 0.00092 | ppl     1.00 | mae 0.04524 | mape 0.11852
# | epoch   7 |   123/  205 batches | lr 0.004341 | 10.02 ms | loss 0.00536 | ppl     1.01 | mae 0.03218 | mape 0.077444
# | epoch   7 |   164/  205 batches | lr 0.004341 | 11.78 ms | loss 0.00181 | ppl     1.00 | mae 0.03726 | mape 0.086299
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch   7 | time:  2.15s | valid loss 1.06452 | valid ppl     2.90 | valid MAE 0.03351 | valid MAPE 0.11588
# ----------------------------------------------------------------------------------------------------------------------
# | epoch   8 |    41/  205 batches | lr 0.004254 | 10.00 ms | loss 0.00321 | ppl     1.00 | mae 0.01656 | mape 0.03678
# | epoch   8 |    82/  205 batches | lr 0.004254 |  9.92 ms | loss 0.00093 | ppl     1.00 | mae 0.04649 | mape 0.12239
# | epoch   8 |   123/  205 batches | lr 0.004254 | 10.17 ms | loss 0.00531 | ppl     1.01 | mae 0.03146 | mape 0.076263
# | epoch   8 |   164/  205 batches | lr 0.004254 |  9.49 ms | loss 0.00179 | ppl     1.00 | mae 0.03658 | mape 0.087513
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch   8 | time:  2.05s | valid loss 1.07466 | valid ppl     2.93 | valid MAE 0.03508 | valid MAPE 0.11870
# ----------------------------------------------------------------------------------------------------------------------
# | epoch   9 |    41/  205 batches | lr 0.004169 |  9.05 ms | loss 0.00324 | ppl     1.00 | mae 0.01691 | mape 0.036811
# | epoch   9 |    82/  205 batches | lr 0.004169 |  8.62 ms | loss 0.00097 | ppl     1.00 | mae 0.04885 | mape 0.12952
# | epoch   9 |   123/  205 batches | lr 0.004169 |  9.00 ms | loss 0.00530 | ppl     1.01 | mae 0.03087 | mape 0.075382
# | epoch   9 |   164/  205 batches | lr 0.004169 |  8.54 ms | loss 0.00172 | ppl     1.00 | mae 0.03815 | mape 0.09183
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch   9 | time:  1.85s | valid loss 1.09010 | valid ppl     2.97 | valid MAE 0.03716 | valid MAPE 0.12253
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  10 |    41/  205 batches | lr 0.004085 |  9.38 ms | loss 0.00330 | ppl     1.00 | mae 0.02409 | mape 0.052451
# | epoch  10 |    82/  205 batches | lr 0.004085 |  9.50 ms | loss 0.00096 | ppl     1.00 | mae 0.04681 | mape 0.12339
# | epoch  10 |   123/  205 batches | lr 0.004085 |  9.11 ms | loss 0.00530 | ppl     1.01 | mae 0.03203 | mape 0.078498
# | epoch  10 |   164/  205 batches | lr 0.004085 |  8.73 ms | loss 0.00168 | ppl     1.00 | mae 0.03704 | mape 0.088796
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  10 | time:  1.92s | valid loss 1.09462 | valid ppl     2.99 | valid MAE 0.03772 | valid MAPE 0.12359
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  11 |    41/  205 batches | lr 0.004004 |  8.82 ms | loss 0.00334 | ppl     1.00 | mae 0.02891 | mape 0.062997
# | epoch  11 |    82/  205 batches | lr 0.004004 |  8.66 ms | loss 0.00091 | ppl     1.00 | mae 0.04510 | mape 0.11809
# | epoch  11 |   123/  205 batches | lr 0.004004 |  8.64 ms | loss 0.00529 | ppl     1.01 | mae 0.03174 | mape 0.077713
# | epoch  11 |   164/  205 batches | lr 0.004004 |  9.22 ms | loss 0.00165 | ppl     1.00 | mae 0.03600 | mape 0.085901
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  11 | time:  1.88s | valid loss 1.09906 | valid ppl     3.00 | valid MAE 0.03826 | valid MAPE 0.12459
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  12 |    41/  205 batches | lr 0.003924 |  9.16 ms | loss 0.00333 | ppl     1.00 | mae 0.02657 | mape 0.057862
# | epoch  12 |    82/  205 batches | lr 0.003924 |  9.65 ms | loss 0.00086 | ppl     1.00 | mae 0.04557 | mape 0.11954
# | epoch  12 |   123/  205 batches | lr 0.003924 |  9.00 ms | loss 0.00530 | ppl     1.01 | mae 0.03227 | mape 0.079121
# | epoch  12 |   164/  205 batches | lr 0.003924 |  9.08 ms | loss 0.00164 | ppl     1.00 | mae 0.03565 | mape 0.084932
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  12 | time:  1.93s | valid loss 1.09754 | valid ppl     3.00 | valid MAE 0.03808 | valid MAPE 0.12425
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  13 |    41/  205 batches | lr 0.003845 |  9.28 ms | loss 0.00330 | ppl     1.00 | mae 0.02180 | mape 0.047429
# | epoch  13 |    82/  205 batches | lr 0.003845 |  9.26 ms | loss 0.00084 | ppl     1.00 | mae 0.04565 | mape 0.11978
# | epoch  13 |   123/  205 batches | lr 0.003845 |  8.93 ms | loss 0.00531 | ppl     1.01 | mae 0.03295 | mape 0.080951
# | epoch  13 |   164/  205 batches | lr 0.003845 |  8.92 ms | loss 0.00163 | ppl     1.00 | mae 0.03554 | mape 0.084631
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  13 | time:  1.93s | valid loss 1.09349 | valid ppl     2.98 | valid MAE 0.03758 | valid MAPE 0.12332
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  14 |    41/  205 batches | lr 0.003768 |  9.51 ms | loss 0.00326 | ppl     1.00 | mae 0.01799 | mape 0.039173
# | epoch  14 |    82/  205 batches | lr 0.003768 |  8.75 ms | loss 0.00083 | ppl     1.00 | mae 0.04530 | mape 0.11872
# | epoch  14 |   123/  205 batches | lr 0.003768 |  8.94 ms | loss 0.00532 | ppl     1.01 | mae 0.03387 | mape 0.083403
# | epoch  14 |   164/  205 batches | lr 0.003768 |  8.62 ms | loss 0.00163 | ppl     1.00 | mae 0.03549 | mape 0.084482
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  14 | time:  1.89s | valid loss 1.08895 | valid ppl     2.97 | valid MAE 0.03701 | valid MAPE 0.12225
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  15 |    41/  205 batches | lr 0.003693 |  9.24 ms | loss 0.00323 | ppl     1.00 | mae 0.01551 | mape 0.033796
# | epoch  15 |    82/  205 batches | lr 0.003693 |  8.95 ms | loss 0.00082 | ppl     1.00 | mae 0.04495 | mape 0.11762
# | epoch  15 |   123/  205 batches | lr 0.003693 |  8.79 ms | loss 0.00532 | ppl     1.01 | mae 0.03487 | mape 0.086042
# | epoch  15 |   164/  205 batches | lr 0.003693 |  8.80 ms | loss 0.00163 | ppl     1.00 | mae 0.03552 | mape 0.084579
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  15 | time:  1.89s | valid loss 1.08463 | valid ppl     2.96 | valid MAE 0.03644 | valid MAPE 0.12119
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  16 |    41/  205 batches | lr 0.003619 |  9.34 ms | loss 0.00320 | ppl     1.00 | mae 0.01570 | mape 0.034401
# | epoch  16 |    82/  205 batches | lr 0.003619 |  8.92 ms | loss 0.00082 | ppl     1.00 | mae 0.04470 | mape 0.11684
# | epoch  16 |   123/  205 batches | lr 0.003619 |  8.75 ms | loss 0.00532 | ppl     1.01 | mae 0.03555 | mape 0.087847
# | epoch  16 |   164/  205 batches | lr 0.003619 |  8.53 ms | loss 0.00163 | ppl     1.00 | mae 0.03564 | mape 0.084896
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  16 | time:  1.87s | valid loss 1.08053 | valid ppl     2.95 | valid MAE 0.03590 | valid MAPE 0.12020
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  17 |    41/  205 batches | lr 0.003547 |  9.26 ms | loss 0.00318 | ppl     1.00 | mae 0.01589 | mape 0.034956
# | epoch  17 |    82/  205 batches | lr 0.003547 |  9.08 ms | loss 0.00082 | ppl     1.00 | mae 0.04457 | mape 0.11645
# | epoch  17 |   123/  205 batches | lr 0.003547 |  9.07 ms | loss 0.00533 | ppl     1.01 | mae 0.03596 | mape 0.088903
# | epoch  17 |   164/  205 batches | lr 0.003547 |  9.12 ms | loss 0.00164 | ppl     1.00 | mae 0.03555 | mape 0.084662
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  17 | time:  1.94s | valid loss 1.07595 | valid ppl     2.93 | valid MAE 0.03526 | valid MAPE 0.11903
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  18 |    41/  205 batches | lr 0.003476 |  9.36 ms | loss 0.00316 | ppl     1.00 | mae 0.01600 | mape 0.035278
# | epoch  18 |    82/  205 batches | lr 0.003476 |  9.87 ms | loss 0.00082 | ppl     1.00 | mae 0.04447 | mape 0.11615
# | epoch  18 |   123/  205 batches | lr 0.003476 |  9.15 ms | loss 0.00533 | ppl     1.01 | mae 0.03677 | mape 0.091028
# | epoch  18 |   164/  205 batches | lr 0.003476 |  9.06 ms | loss 0.00165 | ppl     1.00 | mae 0.03638 | mape 0.086956
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  18 | time:  1.96s | valid loss 1.07127 | valid ppl     2.92 | valid MAE 0.03458 | valid MAPE 0.11780
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  19 |    41/  205 batches | lr 0.003406 |  9.33 ms | loss 0.00314 | ppl     1.00 | mae 0.01611 | mape 0.035588
# | epoch  19 |    82/  205 batches | lr 0.003406 |  9.30 ms | loss 0.00083 | ppl     1.00 | mae 0.04433 | mape 0.11572
# | epoch  19 |   123/  205 batches | lr 0.003406 |  8.71 ms | loss 0.00533 | ppl     1.01 | mae 0.03724 | mape 0.092273
# | epoch  19 |   164/  205 batches | lr 0.003406 |  8.51 ms | loss 0.00165 | ppl     1.00 | mae 0.03597 | mape 0.085837
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  19 | time:  1.87s | valid loss 1.06786 | valid ppl     2.91 | valid MAE 0.03406 | valid MAPE 0.11686
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  20 |    41/  205 batches | lr 0.003338 |  8.94 ms | loss 0.00312 | ppl     1.00 | mae 0.01612 | mape 0.035608
# | epoch  20 |    82/  205 batches | lr 0.003338 |  8.48 ms | loss 0.00083 | ppl     1.00 | mae 0.04412 | mape 0.11507
# | epoch  20 |   123/  205 batches | lr 0.003338 |  8.56 ms | loss 0.00533 | ppl     1.01 | mae 0.03719 | mape 0.092141
# | epoch  20 |   164/  205 batches | lr 0.003338 |  8.67 ms | loss 0.00165 | ppl     1.00 | mae 0.03553 | mape 0.084614
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  20 | time:  1.82s | valid loss 1.06422 | valid ppl     2.90 | valid MAE 0.03345 | valid MAPE 0.11579
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  21 |    41/  205 batches | lr 0.003271 |  9.39 ms | loss 0.00311 | ppl     1.00 | mae 0.01611 | mape 0.035575
# | epoch  21 |    82/  205 batches | lr 0.003271 |  9.08 ms | loss 0.00083 | ppl     1.00 | mae 0.04393 | mape 0.11448
# | epoch  21 |   123/  205 batches | lr 0.003271 |  8.98 ms | loss 0.00536 | ppl     1.01 | mae 0.03571 | mape 0.08825
# | epoch  21 |   164/  205 batches | lr 0.003271 |  8.81 ms | loss 0.00167 | ppl     1.00 | mae 0.03518 | mape 0.083633
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  21 | time:  1.92s | valid loss 1.06281 | valid ppl     2.89 | valid MAE 0.03320 | valid MAPE 0.11535
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  22 |    41/  205 batches | lr 0.003206 |  9.46 ms | loss 0.00310 | ppl     1.00 | mae 0.01602 | mape 0.035321
# | epoch  22 |    82/  205 batches | lr 0.003206 |  9.25 ms | loss 0.00084 | ppl     1.00 | mae 0.04331 | mape 0.11254
# | epoch  22 |   123/  205 batches | lr 0.003206 |  9.29 ms | loss 0.00532 | ppl     1.01 | mae 0.03627 | mape 0.089709
# | epoch  22 |   164/  205 batches | lr 0.003206 |  9.24 ms | loss 0.00166 | ppl     1.00 | mae 0.03561 | mape 0.084822
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  22 | time:  1.96s | valid loss 1.06960 | valid ppl     2.91 | valid MAE 0.03433 | valid MAPE 0.11734
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  23 |    41/  205 batches | lr 0.003142 |  9.38 ms | loss 0.00310 | ppl     1.00 | mae 0.01591 | mape 0.034996
# | epoch  23 |    82/  205 batches | lr 0.003142 |  9.38 ms | loss 0.00084 | ppl     1.00 | mae 0.04295 | mape 0.11134
# | epoch  23 |   123/  205 batches | lr 0.003142 |  8.99 ms | loss 0.00532 | ppl     1.01 | mae 0.03525 | mape 0.087057
# | epoch  23 |   164/  205 batches | lr 0.003142 |  9.25 ms | loss 0.00168 | ppl     1.00 | mae 0.03630 | mape 0.086745
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  23 | time:  1.95s | valid loss 1.05636 | valid ppl     2.88 | valid MAE 0.03192 | valid MAPE 0.11312
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  24 |    41/  205 batches | lr 0.003079 |  9.34 ms | loss 0.00308 | ppl     1.00 | mae 0.01577 | mape 0.034613
# | epoch  24 |    82/  205 batches | lr 0.003079 |  8.93 ms | loss 0.00084 | ppl     1.00 | mae 0.04346 | mape 0.11209
# | epoch  24 |   123/  205 batches | lr 0.003079 |  8.84 ms | loss 0.00531 | ppl     1.01 | mae 0.03426 | mape 0.084443
# | epoch  24 |   164/  205 batches | lr 0.003079 |  9.48 ms | loss 0.00165 | ppl     1.00 | mae 0.03530 | mape 0.083964
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  24 | time:  1.90s | valid loss 1.05990 | valid ppl     2.89 | valid MAE 0.03266 | valid MAPE 0.11439
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  25 |    41/  205 batches | lr 0.003017 |  8.72 ms | loss 0.00308 | ppl     1.00 | mae 0.01565 | mape 0.03425
# | epoch  25 |    82/  205 batches | lr 0.003017 |  8.59 ms | loss 0.00084 | ppl     1.00 | mae 0.04367 | mape 0.11241
# | epoch  25 |   123/  205 batches | lr 0.003017 |  8.36 ms | loss 0.00530 | ppl     1.01 | mae 0.03421 | mape 0.084326
# | epoch  25 |   164/  205 batches | lr 0.003017 |  8.38 ms | loss 0.00164 | ppl     1.00 | mae 0.03611 | mape 0.086215
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  25 | time:  1.80s | valid loss 1.05564 | valid ppl     2.87 | valid MAE 0.03176 | valid MAPE 0.11286
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  26 |    41/  205 batches | lr 0.002957 |  8.70 ms | loss 0.00307 | ppl     1.00 | mae 0.01554 | mape 0.033925
# | epoch  26 |    82/  205 batches | lr 0.002957 |  8.58 ms | loss 0.00084 | ppl     1.00 | mae 0.04385 | mape 0.11268
# | epoch  26 |   123/  205 batches | lr 0.002957 |  8.52 ms | loss 0.00530 | ppl     1.01 | mae 0.03349 | mape 0.08239
# | epoch  26 |   164/  205 batches | lr 0.002957 |  8.50 ms | loss 0.00164 | ppl     1.00 | mae 0.03504 | mape 0.082787
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  26 | time:  1.81s | valid loss 1.05659 | valid ppl     2.88 | valid MAE 0.03197 | valid MAPE 0.11321
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  27 |    41/  205 batches | lr 0.002898 |  9.15 ms | loss 0.00307 | ppl     1.00 | mae 0.01549 | mape 0.033767
# | epoch  27 |    82/  205 batches | lr 0.002898 |  8.81 ms | loss 0.00084 | ppl     1.00 | mae 0.04390 | mape 0.11277
# | epoch  27 |   123/  205 batches | lr 0.002898 |  9.07 ms | loss 0.00529 | ppl     1.01 | mae 0.03359 | mape 0.082677
# | epoch  27 |   164/  205 batches | lr 0.002898 |  9.27 ms | loss 0.00164 | ppl     1.00 | mae 0.03503 | mape 0.082778
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  27 | time:  1.91s | valid loss 1.05582 | valid ppl     2.87 | valid MAE 0.03180 | valid MAPE 0.11293
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  28 |    41/  205 batches | lr 0.002840 |  9.28 ms | loss 0.00307 | ppl     1.00 | mae 0.01593 | mape 0.0347
# | epoch  28 |    82/  205 batches | lr 0.002840 |  9.08 ms | loss 0.00084 | ppl     1.00 | mae 0.04383 | mape 0.11266
# | epoch  28 |   123/  205 batches | lr 0.002840 |  9.08 ms | loss 0.00529 | ppl     1.01 | mae 0.03318 | mape 0.081565
# | epoch  28 |   164/  205 batches | lr 0.002840 |  8.89 ms | loss 0.00164 | ppl     1.00 | mae 0.03492 | mape 0.082603
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  28 | time:  1.91s | valid loss 1.05557 | valid ppl     2.87 | valid MAE 0.03175 | valid MAPE 0.11284
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  29 |    41/  205 batches | lr 0.002783 |  9.42 ms | loss 0.00306 | ppl     1.00 | mae 0.01624 | mape 0.03537
# | epoch  29 |    82/  205 batches | lr 0.002783 |  9.93 ms | loss 0.00083 | ppl     1.00 | mae 0.04372 | mape 0.11247
# | epoch  29 |   123/  205 batches | lr 0.002783 |  9.50 ms | loss 0.00529 | ppl     1.01 | mae 0.03343 | mape 0.082243
# | epoch  29 |   164/  205 batches | lr 0.002783 |  9.22 ms | loss 0.00164 | ppl     1.00 | mae 0.03693 | mape 0.08849
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  29 | time:  1.98s | valid loss 1.05372 | valid ppl     2.87 | valid MAE 0.03187 | valid MAPE 0.11339
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  30 |    41/  205 batches | lr 0.002727 |  9.34 ms | loss 0.00306 | ppl     1.00 | mae 0.01667 | mape 0.036302
# | epoch  30 |    82/  205 batches | lr 0.002727 |  9.23 ms | loss 0.00083 | ppl     1.00 | mae 0.04350 | mape 0.11214
# | epoch  30 |   123/  205 batches | lr 0.002727 |  8.60 ms | loss 0.00530 | ppl     1.01 | mae 0.03255 | mape 0.079873
# | epoch  30 |   164/  205 batches | lr 0.002727 |  8.48 ms | loss 0.00163 | ppl     1.00 | mae 0.03714 | mape 0.089068
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  30 | time:  1.87s | valid loss 1.05425 | valid ppl     2.87 | valid MAE 0.03178 | valid MAPE 0.11310
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  31 |    41/  205 batches | lr 0.002673 |  8.74 ms | loss 0.00306 | ppl     1.00 | mae 0.01675 | mape 0.036477
# | epoch  31 |    82/  205 batches | lr 0.002673 |  8.65 ms | loss 0.00083 | ppl     1.00 | mae 0.04333 | mape 0.1119
# | epoch  31 |   123/  205 batches | lr 0.002673 |  8.43 ms | loss 0.00530 | ppl     1.01 | mae 0.03265 | mape 0.08016
# | epoch  31 |   164/  205 batches | lr 0.002673 |  9.06 ms | loss 0.00164 | ppl     1.00 | mae 0.03523 | mape 0.083771
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  31 | time:  1.86s | valid loss 1.05431 | valid ppl     2.87 | valid MAE 0.03177 | valid MAPE 0.11307
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  32 |    41/  205 batches | lr 0.002619 |  9.05 ms | loss 0.00305 | ppl     1.00 | mae 0.01694 | mape 0.036878
# | epoch  32 |    82/  205 batches | lr 0.002619 |  8.83 ms | loss 0.00082 | ppl     1.00 | mae 0.04312 | mape 0.1116
# | epoch  32 |   123/  205 batches | lr 0.002619 |  9.04 ms | loss 0.00530 | ppl     1.01 | mae 0.03215 | mape 0.078803
# | epoch  32 |   164/  205 batches | lr 0.002619 |  8.54 ms | loss 0.00163 | ppl     1.00 | mae 0.03731 | mape 0.089543
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  32 | time:  1.88s | valid loss 1.05469 | valid ppl     2.87 | valid MAE 0.03171 | valid MAPE 0.11287
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  33 |    41/  205 batches | lr 0.002567 |  9.38 ms | loss 0.00305 | ppl     1.00 | mae 0.01680 | mape 0.036588
# | epoch  33 |    82/  205 batches | lr 0.002567 |  8.80 ms | loss 0.00082 | ppl     1.00 | mae 0.04297 | mape 0.11137
# | epoch  33 |   123/  205 batches | lr 0.002567 |  9.00 ms | loss 0.00530 | ppl     1.01 | mae 0.03187 | mape 0.078053
# | epoch  33 |   164/  205 batches | lr 0.002567 |  8.98 ms | loss 0.00164 | ppl     1.00 | mae 0.03524 | mape 0.083809
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  33 | time:  1.90s | valid loss 1.05348 | valid ppl     2.87 | valid MAE 0.03191 | valid MAPE 0.11353
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  34 |    41/  205 batches | lr 0.002516 |  9.43 ms | loss 0.00305 | ppl     1.00 | mae 0.01681 | mape 0.036597
# | epoch  34 |    82/  205 batches | lr 0.002516 |  8.96 ms | loss 0.00082 | ppl     1.00 | mae 0.04311 | mape 0.11189
# | epoch  34 |   123/  205 batches | lr 0.002516 |  8.92 ms | loss 0.00531 | ppl     1.01 | mae 0.03180 | mape 0.077866
# | epoch  34 |   164/  205 batches | lr 0.002516 |  9.21 ms | loss 0.00162 | ppl     1.00 | mae 0.03483 | mape 0.082657
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  34 | time:  1.91s | valid loss 1.05627 | valid ppl     2.88 | valid MAE 0.03190 | valid MAPE 0.11309
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  35 |    41/  205 batches | lr 0.002465 |  9.90 ms | loss 0.00304 | ppl     1.00 | mae 0.01673 | mape 0.036422
# | epoch  35 |    82/  205 batches | lr 0.002465 |  9.23 ms | loss 0.00082 | ppl     1.00 | mae 0.04325 | mape 0.11234
# | epoch  35 |   123/  205 batches | lr 0.002465 |  9.36 ms | loss 0.00531 | ppl     1.01 | mae 0.03257 | mape 0.079938
# | epoch  35 |   164/  205 batches | lr 0.002465 |  9.21 ms | loss 0.00162 | ppl     1.00 | mae 0.03520 | mape 0.083683
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  35 | time:  1.98s | valid loss 1.05677 | valid ppl     2.88 | valid MAE 0.03201 | valid MAPE 0.11328
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  36 |    41/  205 batches | lr 0.002416 |  9.52 ms | loss 0.00304 | ppl     1.00 | mae 0.01680 | mape 0.036591
# | epoch  36 |    82/  205 batches | lr 0.002416 |  8.85 ms | loss 0.00082 | ppl     1.00 | mae 0.04337 | mape 0.11274
# | epoch  36 |   123/  205 batches | lr 0.002416 |  8.50 ms | loss 0.00531 | ppl     1.01 | mae 0.03167 | mape 0.077523
# | epoch  36 |   164/  205 batches | lr 0.002416 |  8.42 ms | loss 0.00163 | ppl     1.00 | mae 0.03559 | mape 0.084758
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  36 | time:  1.86s | valid loss 1.05562 | valid ppl     2.87 | valid MAE 0.03176 | valid MAPE 0.11286
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  37 |    41/  205 batches | lr 0.002368 |  8.85 ms | loss 0.00304 | ppl     1.00 | mae 0.01689 | mape 0.03678
# | epoch  37 |    82/  205 batches | lr 0.002368 |  8.53 ms | loss 0.00082 | ppl     1.00 | mae 0.04355 | mape 0.11329
# | epoch  37 |   123/  205 batches | lr 0.002368 |  8.71 ms | loss 0.00532 | ppl     1.01 | mae 0.03300 | mape 0.08109
# | epoch  37 |   164/  205 batches | lr 0.002368 |  8.77 ms | loss 0.00162 | ppl     1.00 | mae 0.03606 | mape 0.086078
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  37 | time:  1.83s | valid loss 1.05715 | valid ppl     2.88 | valid MAE 0.03209 | valid MAPE 0.11342
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  38 |    41/  205 batches | lr 0.002320 |  8.80 ms | loss 0.00304 | ppl     1.00 | mae 0.01698 | mape 0.036964
# | epoch  38 |    82/  205 batches | lr 0.002320 |  8.72 ms | loss 0.00083 | ppl     1.00 | mae 0.04369 | mape 0.11374
# | epoch  38 |   123/  205 batches | lr 0.002320 |  8.72 ms | loss 0.00531 | ppl     1.01 | mae 0.03153 | mape 0.077158
# | epoch  38 |   164/  205 batches | lr 0.002320 |  8.92 ms | loss 0.00168 | ppl     1.00 | mae 0.03620 | mape 0.086476
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  38 | time:  1.87s | valid loss 1.05815 | valid ppl     2.88 | valid MAE 0.03230 | valid MAPE 0.11378
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  39 |    41/  205 batches | lr 0.002274 |  9.25 ms | loss 0.00304 | ppl     1.00 | mae 0.01678 | mape 0.036543
# | epoch  39 |    82/  205 batches | lr 0.002274 |  8.79 ms | loss 0.00081 | ppl     1.00 | mae 0.04379 | mape 0.11404
# | epoch  39 |   123/  205 batches | lr 0.002274 |  8.79 ms | loss 0.00533 | ppl     1.01 | mae 0.03743 | mape 0.092752
# | epoch  39 |   164/  205 batches | lr 0.002274 |  8.97 ms | loss 0.00165 | ppl     1.00 | mae 0.03533 | mape 0.084046
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  39 | time:  1.95s | valid loss 1.05289 | valid ppl     2.87 | valid MAE 0.03202 | valid MAPE 0.11389
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  40 |    41/  205 batches | lr 0.002229 |  9.29 ms | loss 0.00304 | ppl     1.00 | mae 0.01617 | mape 0.035225
# | epoch  40 |    82/  205 batches | lr 0.002229 |  9.73 ms | loss 0.00081 | ppl     1.00 | mae 0.04392 | mape 0.11445
# | epoch  40 |   123/  205 batches | lr 0.002229 |  9.03 ms | loss 0.00533 | ppl     1.01 | mae 0.03798 | mape 0.094205
# | epoch  40 |   164/  205 batches | lr 0.002229 |  9.33 ms | loss 0.00164 | ppl     1.00 | mae 0.03556 | mape 0.084679
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  40 | time:  1.95s | valid loss 1.05718 | valid ppl     2.88 | valid MAE 0.03210 | valid MAPE 0.11343
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  41 |    41/  205 batches | lr 0.002184 |  8.92 ms | loss 0.00304 | ppl     1.00 | mae 0.01604 | mape 0.034943
# | epoch  41 |    82/  205 batches | lr 0.002184 |  8.49 ms | loss 0.00081 | ppl     1.00 | mae 0.04402 | mape 0.11475
# | epoch  41 |   123/  205 batches | lr 0.002184 |  8.71 ms | loss 0.00533 | ppl     1.01 | mae 0.03883 | mape 0.09644
# | epoch  41 |   164/  205 batches | lr 0.002184 |  8.48 ms | loss 0.00167 | ppl     1.00 | mae 0.03678 | mape 0.088083
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  41 | time:  1.81s | valid loss 1.05813 | valid ppl     2.88 | valid MAE 0.03230 | valid MAPE 0.11377
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  42 |    41/  205 batches | lr 0.002140 |  8.67 ms | loss 0.00304 | ppl     1.00 | mae 0.01581 | mape 0.034435
# | epoch  42 |    82/  205 batches | lr 0.002140 |  8.63 ms | loss 0.00081 | ppl     1.00 | mae 0.04407 | mape 0.1149
# | epoch  42 |   123/  205 batches | lr 0.002140 |  8.42 ms | loss 0.00532 | ppl     1.01 | mae 0.03877 | mape 0.096271
# | epoch  42 |   164/  205 batches | lr 0.002140 |  8.31 ms | loss 0.00168 | ppl     1.00 | mae 0.03575 | mape 0.085215
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  42 | time:  1.79s | valid loss 1.05750 | valid ppl     2.88 | valid MAE 0.03217 | valid MAPE 0.11354
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  43 |    41/  205 batches | lr 0.002097 |  8.87 ms | loss 0.00303 | ppl     1.00 | mae 0.01555 | mape 0.033959
# | epoch  43 |    82/  205 batches | lr 0.002097 |  8.84 ms | loss 0.00081 | ppl     1.00 | mae 0.04402 | mape 0.11477
# | epoch  43 |   123/  205 batches | lr 0.002097 |  9.44 ms | loss 0.00532 | ppl     1.01 | mae 0.03881 | mape 0.096373
# | epoch  43 |   164/  205 batches | lr 0.002097 |  9.50 ms | loss 0.00166 | ppl     1.00 | mae 0.03527 | mape 0.083891
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  43 | time:  1.93s | valid loss 1.05646 | valid ppl     2.88 | valid MAE 0.03194 | valid MAPE 0.11316
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  44 |    41/  205 batches | lr 0.002055 |  9.35 ms | loss 0.00304 | ppl     1.00 | mae 0.01557 | mape 0.034021
# | epoch  44 |    82/  205 batches | lr 0.002055 |  9.06 ms | loss 0.00081 | ppl     1.00 | mae 0.04394 | mape 0.11452
# | epoch  44 |   123/  205 batches | lr 0.002055 |  8.82 ms | loss 0.00532 | ppl     1.01 | mae 0.03842 | mape 0.095345
# | epoch  44 |   164/  205 batches | lr 0.002055 |  9.03 ms | loss 0.00166 | ppl     1.00 | mae 0.03632 | mape 0.086809
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  44 | time:  1.91s | valid loss 1.05226 | valid ppl     2.86 | valid MAE 0.03216 | valid MAPE 0.11433
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  45 |    41/  205 batches | lr 0.002014 |  9.35 ms | loss 0.00303 | ppl     1.00 | mae 0.01573 | mape 0.034497
# | epoch  45 |    82/  205 batches | lr 0.002014 |  9.08 ms | loss 0.00081 | ppl     1.00 | mae 0.04383 | mape 0.11417
# | epoch  45 |   123/  205 batches | lr 0.002014 |  8.99 ms | loss 0.00531 | ppl     1.01 | mae 0.03805 | mape 0.094374
# | epoch  45 |   164/  205 batches | lr 0.002014 |  8.72 ms | loss 0.00166 | ppl     1.00 | mae 0.03507 | mape 0.083318
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  45 | time:  1.90s | valid loss 1.05633 | valid ppl     2.88 | valid MAE 0.03191 | valid MAPE 0.11311
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  46 |    41/  205 batches | lr 0.001974 |  9.67 ms | loss 0.00303 | ppl     1.00 | mae 0.01575 | mape 0.034536
# | epoch  46 |    82/  205 batches | lr 0.001974 |  9.22 ms | loss 0.00081 | ppl     1.00 | mae 0.04378 | mape 0.11401
# | epoch  46 |   123/  205 batches | lr 0.001974 |  8.52 ms | loss 0.00531 | ppl     1.01 | mae 0.03756 | mape 0.093099
# | epoch  46 |   164/  205 batches | lr 0.001974 |  8.43 ms | loss 0.00166 | ppl     1.00 | mae 0.03685 | mape 0.088278
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  46 | time:  1.89s | valid loss 1.05142 | valid ppl     2.86 | valid MAE 0.03238 | valid MAPE 0.11502
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  47 |    41/  205 batches | lr 0.001935 |  9.10 ms | loss 0.00303 | ppl     1.00 | mae 0.01575 | mape 0.034554
# | epoch  47 |    82/  205 batches | lr 0.001935 |  8.72 ms | loss 0.00081 | ppl     1.00 | mae 0.04371 | mape 0.11379
# | epoch  47 |   123/  205 batches | lr 0.001935 |  8.59 ms | loss 0.00531 | ppl     1.01 | mae 0.03713 | mape 0.091965
# | epoch  47 |   164/  205 batches | lr 0.001935 |  8.94 ms | loss 0.00165 | ppl     1.00 | mae 0.03669 | mape 0.087823
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  47 | time:  1.85s | valid loss 1.05371 | valid ppl     2.87 | valid MAE 0.03187 | valid MAPE 0.11340
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  48 |    41/  205 batches | lr 0.001896 |  8.91 ms | loss 0.00303 | ppl     1.00 | mae 0.01601 | mape 0.035296
# | epoch  48 |    82/  205 batches | lr 0.001896 |  8.75 ms | loss 0.00081 | ppl     1.00 | mae 0.04358 | mape 0.11338
# | epoch  48 |   123/  205 batches | lr 0.001896 |  8.50 ms | loss 0.00531 | ppl     1.01 | mae 0.03666 | mape 0.090731
# | epoch  48 |   164/  205 batches | lr 0.001896 |  8.49 ms | loss 0.00166 | ppl     1.00 | mae 0.03472 | mape 0.082304
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  48 | time:  1.84s | valid loss 1.05676 | valid ppl     2.88 | valid MAE 0.03201 | valid MAPE 0.11327
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  49 |    41/  205 batches | lr 0.001858 |  9.28 ms | loss 0.00303 | ppl     1.00 | mae 0.01590 | mape 0.034966
# | epoch  49 |    82/  205 batches | lr 0.001858 |  8.75 ms | loss 0.00081 | ppl     1.00 | mae 0.04359 | mape 0.11342
# | epoch  49 |   123/  205 batches | lr 0.001858 |  9.10 ms | loss 0.00531 | ppl     1.01 | mae 0.03612 | mape 0.08934
# | epoch  49 |   164/  205 batches | lr 0.001858 |  9.13 ms | loss 0.00165 | ppl     1.00 | mae 0.03649 | mape 0.087271
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  49 | time:  1.92s | valid loss 1.05367 | valid ppl     2.87 | valid MAE 0.03188 | valid MAPE 0.11342
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  50 |    41/  205 batches | lr 0.001821 |  9.68 ms | loss 0.00303 | ppl     1.00 | mae 0.01615 | mape 0.035692
# | epoch  50 |    82/  205 batches | lr 0.001821 |  8.98 ms | loss 0.00082 | ppl     1.00 | mae 0.04353 | mape 0.11324
# | epoch  50 |   123/  205 batches | lr 0.001821 |  8.92 ms | loss 0.00531 | ppl     1.01 | mae 0.03589 | mape 0.088717
# | epoch  50 |   164/  205 batches | lr 0.001821 |  9.64 ms | loss 0.00167 | ppl     1.00 | mae 0.03628 | mape 0.086692
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  50 | time:  1.96s | valid loss 1.05292 | valid ppl     2.87 | valid MAE 0.03202 | valid MAPE 0.11388
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  51 |    41/  205 batches | lr 0.001784 |  9.33 ms | loss 0.00303 | ppl     1.00 | mae 0.01626 | mape 0.035996
# | epoch  51 |    82/  205 batches | lr 0.001784 |  9.06 ms | loss 0.00082 | ppl     1.00 | mae 0.04354 | mape 0.11326
# | epoch  51 |   123/  205 batches | lr 0.001784 |  9.06 ms | loss 0.00530 | ppl     1.01 | mae 0.03541 | mape 0.087473
# | epoch  51 |   164/  205 batches | lr 0.001784 |  8.99 ms | loss 0.00166 | ppl     1.00 | mae 0.03671 | mape 0.087887
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  51 | time:  1.90s | valid loss 1.05307 | valid ppl     2.87 | valid MAE 0.03199 | valid MAPE 0.11378
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  52 |    41/  205 batches | lr 0.001749 |  9.23 ms | loss 0.00303 | ppl     1.00 | mae 0.01638 | mape 0.036317
# | epoch  52 |    82/  205 batches | lr 0.001749 |  8.64 ms | loss 0.00082 | ppl     1.00 | mae 0.04357 | mape 0.11338
# | epoch  52 |   123/  205 batches | lr 0.001749 |  8.64 ms | loss 0.00530 | ppl     1.01 | mae 0.03505 | mape 0.086521
# | epoch  52 |   164/  205 batches | lr 0.001749 |  8.74 ms | loss 0.00166 | ppl     1.00 | mae 0.03699 | mape 0.088665
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  52 | time:  1.86s | valid loss 1.05377 | valid ppl     2.87 | valid MAE 0.03186 | valid MAPE 0.11337
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  53 |    41/  205 batches | lr 0.001714 |  9.08 ms | loss 0.00303 | ppl     1.00 | mae 0.01638 | mape 0.036321
# | epoch  53 |    82/  205 batches | lr 0.001714 |  8.83 ms | loss 0.00082 | ppl     1.00 | mae 0.04363 | mape 0.11356
# | epoch  53 |   123/  205 batches | lr 0.001714 |  8.85 ms | loss 0.00530 | ppl     1.01 | mae 0.03442 | mape 0.084879
# | epoch  53 |   164/  205 batches | lr 0.001714 |  8.71 ms | loss 0.00165 | ppl     1.00 | mae 0.03547 | mape 0.084428
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  53 | time:  1.87s | valid loss 1.05168 | valid ppl     2.86 | valid MAE 0.03231 | valid MAPE 0.11479
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  54 |    41/  205 batches | lr 0.001679 |  8.93 ms | loss 0.00303 | ppl     1.00 | mae 0.01666 | mape 0.037028
# | epoch  54 |    82/  205 batches | lr 0.001679 |  9.12 ms | loss 0.00082 | ppl     1.00 | mae 0.04360 | mape 0.11344
# | epoch  54 |   123/  205 batches | lr 0.001679 |  9.21 ms | loss 0.00530 | ppl     1.01 | mae 0.03627 | mape 0.089718
# | epoch  54 |   164/  205 batches | lr 0.001679 |  8.98 ms | loss 0.00164 | ppl     1.00 | mae 0.03665 | mape 0.087725
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  54 | time:  1.91s | valid loss 1.05199 | valid ppl     2.86 | valid MAE 0.03223 | valid MAPE 0.11453
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  55 |    41/  205 batches | lr 0.001646 |  9.31 ms | loss 0.00303 | ppl     1.00 | mae 0.01678 | mape 0.037342
# | epoch  55 |    82/  205 batches | lr 0.001646 |  8.97 ms | loss 0.00082 | ppl     1.00 | mae 0.04381 | mape 0.11411
# | epoch  55 |   123/  205 batches | lr 0.001646 |  9.12 ms | loss 0.00530 | ppl     1.01 | mae 0.03340 | mape 0.082167
# | epoch  55 |   164/  205 batches | lr 0.001646 |  9.07 ms | loss 0.00162 | ppl     1.00 | mae 0.03513 | mape 0.083492
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  55 | time:  1.92s | valid loss 1.05186 | valid ppl     2.86 | valid MAE 0.03226 | valid MAPE 0.11464
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  56 |    41/  205 batches | lr 0.001613 |  9.57 ms | loss 0.00303 | ppl     1.00 | mae 0.01684 | mape 0.037495
# | epoch  56 |    82/  205 batches | lr 0.001613 |  9.12 ms | loss 0.00082 | ppl     1.00 | mae 0.04384 | mape 0.11419
# | epoch  56 |   123/  205 batches | lr 0.001613 | 10.38 ms | loss 0.00530 | ppl     1.01 | mae 0.03404 | mape 0.083858
# | epoch  56 |   164/  205 batches | lr 0.001613 |  9.22 ms | loss 0.00165 | ppl     1.00 | mae 0.03528 | mape 0.083916
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  56 | time:  1.99s | valid loss 1.05164 | valid ppl     2.86 | valid MAE 0.03232 | valid MAPE 0.11482
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  57 |    41/  205 batches | lr 0.001581 |  9.15 ms | loss 0.00303 | ppl     1.00 | mae 0.01695 | mape 0.037761
# | epoch  57 |    82/  205 batches | lr 0.001581 |  8.99 ms | loss 0.00082 | ppl     1.00 | mae 0.04392 | mape 0.11443
# | epoch  57 |   123/  205 batches | lr 0.001581 |  8.88 ms | loss 0.00530 | ppl     1.01 | mae 0.03393 | mape 0.08357
# | epoch  57 |   164/  205 batches | lr 0.001581 |  8.85 ms | loss 0.00165 | ppl     1.00 | mae 0.03515 | mape 0.083556
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  57 | time:  1.88s | valid loss 1.05164 | valid ppl     2.86 | valid MAE 0.03232 | valid MAPE 0.11482
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  58 |    41/  205 batches | lr 0.001549 |  8.91 ms | loss 0.00303 | ppl     1.00 | mae 0.01698 | mape 0.037838
# | epoch  58 |    82/  205 batches | lr 0.001549 |  8.80 ms | loss 0.00082 | ppl     1.00 | mae 0.04367 | mape 0.11368
# | epoch  58 |   123/  205 batches | lr 0.001549 |  8.53 ms | loss 0.00530 | ppl     1.01 | mae 0.03737 | mape 0.092601
# | epoch  58 |   164/  205 batches | lr 0.001549 |  9.13 ms | loss 0.00164 | ppl     1.00 | mae 0.03676 | mape 0.088026
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  58 | time:  1.89s | valid loss 1.05425 | valid ppl     2.87 | valid MAE 0.03178 | valid MAPE 0.11311
# ...
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 982 |    41/  205 batches | lr 0.000000 |  8.53 ms | loss 0.00252 | ppl     1.00 | mae 0.01841 | mape 0.040624
# | epoch 982 |    82/  205 batches | lr 0.000000 |  8.49 ms | loss 0.00082 | ppl     1.00 | mae 0.04549 | mape 0.11792
# | epoch 982 |   123/  205 batches | lr 0.000000 |  8.55 ms | loss 0.00264 | ppl     1.00 | mae 0.02889 | mape 0.066985
# | epoch 982 |   164/  205 batches | lr 0.000000 |  8.75 ms | loss 0.00138 | ppl     1.00 | mae 0.03566 | mape 0.085234
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 982 | time:  1.81s | valid loss 1.01301 | valid ppl     2.75 | valid MAE 0.03592 | valid MAPE 0.12265
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 983 |    41/  205 batches | lr 0.000000 |  8.51 ms | loss 0.00252 | ppl     1.00 | mae 0.01841 | mape 0.040624
# | epoch 983 |    82/  205 batches | lr 0.000000 |  8.33 ms | loss 0.00082 | ppl     1.00 | mae 0.04549 | mape 0.11792
# | epoch 983 |   123/  205 batches | lr 0.000000 |  8.52 ms | loss 0.00264 | ppl     1.00 | mae 0.02889 | mape 0.066985
# | epoch 983 |   164/  205 batches | lr 0.000000 |  8.34 ms | loss 0.00138 | ppl     1.00 | mae 0.03566 | mape 0.085234
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 983 | time:  1.77s | valid loss 1.01301 | valid ppl     2.75 | valid MAE 0.03592 | valid MAPE 0.12265
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 984 |    41/  205 batches | lr 0.000000 |  8.71 ms | loss 0.00252 | ppl     1.00 | mae 0.01841 | mape 0.040624
# | epoch 984 |    82/  205 batches | lr 0.000000 |  8.59 ms | loss 0.00082 | ppl     1.00 | mae 0.04549 | mape 0.11792
# | epoch 984 |   123/  205 batches | lr 0.000000 |  8.53 ms | loss 0.00264 | ppl     1.00 | mae 0.02889 | mape 0.066985
# | epoch 984 |   164/  205 batches | lr 0.000000 |  8.39 ms | loss 0.00138 | ppl     1.00 | mae 0.03566 | mape 0.085234
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 984 | time:  1.80s | valid loss 1.01301 | valid ppl     2.75 | valid MAE 0.03592 | valid MAPE 0.12265
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 985 |    41/  205 batches | lr 0.000000 |  8.64 ms | loss 0.00252 | ppl     1.00 | mae 0.01841 | mape 0.040624
# | epoch 985 |    82/  205 batches | lr 0.000000 |  8.60 ms | loss 0.00082 | ppl     1.00 | mae 0.04549 | mape 0.11792
# | epoch 985 |   123/  205 batches | lr 0.000000 |  8.50 ms | loss 0.00264 | ppl     1.00 | mae 0.02889 | mape 0.066985
# | epoch 985 |   164/  205 batches | lr 0.000000 |  8.49 ms | loss 0.00138 | ppl     1.00 | mae 0.03566 | mape 0.085234
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 985 | time:  1.80s | valid loss 1.01301 | valid ppl     2.75 | valid MAE 0.03592 | valid MAPE 0.12265
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 986 |    41/  205 batches | lr 0.000000 |  8.63 ms | loss 0.00252 | ppl     1.00 | mae 0.01841 | mape 0.040624
# | epoch 986 |    82/  205 batches | lr 0.000000 |  8.43 ms | loss 0.00082 | ppl     1.00 | mae 0.04549 | mape 0.11792
# | epoch 986 |   123/  205 batches | lr 0.000000 |  8.43 ms | loss 0.00264 | ppl     1.00 | mae 0.02889 | mape 0.066985
# | epoch 986 |   164/  205 batches | lr 0.000000 |  8.77 ms | loss 0.00138 | ppl     1.00 | mae 0.03566 | mape 0.085234
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 986 | time:  1.81s | valid loss 1.01301 | valid ppl     2.75 | valid MAE 0.03592 | valid MAPE 0.12265
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 987 |    41/  205 batches | lr 0.000000 |  8.92 ms | loss 0.00252 | ppl     1.00 | mae 0.01841 | mape 0.040624
# | epoch 987 |    82/  205 batches | lr 0.000000 |  8.46 ms | loss 0.00082 | ppl     1.00 | mae 0.04549 | mape 0.11792
# | epoch 987 |   123/  205 batches | lr 0.000000 |  8.46 ms | loss 0.00264 | ppl     1.00 | mae 0.02889 | mape 0.066985
# | epoch 987 |   164/  205 batches | lr 0.000000 |  8.57 ms | loss 0.00138 | ppl     1.00 | mae 0.03566 | mape 0.085234
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 987 | time:  1.81s | valid loss 1.01301 | valid ppl     2.75 | valid MAE 0.03592 | valid MAPE 0.12265
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 988 |    41/  205 batches | lr 0.000000 |  8.55 ms | loss 0.00252 | ppl     1.00 | mae 0.01841 | mape 0.040624
# | epoch 988 |    82/  205 batches | lr 0.000000 |  8.84 ms | loss 0.00082 | ppl     1.00 | mae 0.04549 | mape 0.11792
# | epoch 988 |   123/  205 batches | lr 0.000000 |  8.25 ms | loss 0.00264 | ppl     1.00 | mae 0.02889 | mape 0.066985
# | epoch 988 |   164/  205 batches | lr 0.000000 |  8.31 ms | loss 0.00138 | ppl     1.00 | mae 0.03566 | mape 0.085234
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 988 | time:  1.79s | valid loss 1.01301 | valid ppl     2.75 | valid MAE 0.03592 | valid MAPE 0.12265
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 989 |    41/  205 batches | lr 0.000000 |  8.65 ms | loss 0.00252 | ppl     1.00 | mae 0.01841 | mape 0.040624
# | epoch 989 |    82/  205 batches | lr 0.000000 |  8.30 ms | loss 0.00082 | ppl     1.00 | mae 0.04549 | mape 0.11792
# | epoch 989 |   123/  205 batches | lr 0.000000 |  8.34 ms | loss 0.00264 | ppl     1.00 | mae 0.02889 | mape 0.066985
# | epoch 989 |   164/  205 batches | lr 0.000000 |  8.34 ms | loss 0.00138 | ppl     1.00 | mae 0.03566 | mape 0.085234
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 989 | time:  1.79s | valid loss 1.01301 | valid ppl     2.75 | valid MAE 0.03592 | valid MAPE 0.12265
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 990 |    41/  205 batches | lr 0.000000 |  9.01 ms | loss 0.00252 | ppl     1.00 | mae 0.01841 | mape 0.040624
# | epoch 990 |    82/  205 batches | lr 0.000000 |  8.33 ms | loss 0.00082 | ppl     1.00 | mae 0.04549 | mape 0.11792
# | epoch 990 |   123/  205 batches | lr 0.000000 |  8.33 ms | loss 0.00264 | ppl     1.00 | mae 0.02889 | mape 0.066985
# | epoch 990 |   164/  205 batches | lr 0.000000 |  8.44 ms | loss 0.00138 | ppl     1.00 | mae 0.03566 | mape 0.085234
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 990 | time:  1.79s | valid loss 1.01301 | valid ppl     2.75 | valid MAE 0.03592 | valid MAPE 0.12265
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 991 |    41/  205 batches | lr 0.000000 |  8.60 ms | loss 0.00252 | ppl     1.00 | mae 0.01841 | mape 0.040624
# | epoch 991 |    82/  205 batches | lr 0.000000 |  8.49 ms | loss 0.00082 | ppl     1.00 | mae 0.04549 | mape 0.11792
# | epoch 991 |   123/  205 batches | lr 0.000000 |  8.36 ms | loss 0.00264 | ppl     1.00 | mae 0.02889 | mape 0.066985
# | epoch 991 |   164/  205 batches | lr 0.000000 |  8.35 ms | loss 0.00138 | ppl     1.00 | mae 0.03566 | mape 0.085234
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 991 | time:  1.78s | valid loss 1.01301 | valid ppl     2.75 | valid MAE 0.03592 | valid MAPE 0.12265
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 992 |    41/  205 batches | lr 0.000000 |  8.41 ms | loss 0.00252 | ppl     1.00 | mae 0.01841 | mape 0.040624
# | epoch 992 |    82/  205 batches | lr 0.000000 |  8.33 ms | loss 0.00082 | ppl     1.00 | mae 0.04549 | mape 0.11792
# | epoch 992 |   123/  205 batches | lr 0.000000 |  8.37 ms | loss 0.00264 | ppl     1.00 | mae 0.02889 | mape 0.066985
# | epoch 992 |   164/  205 batches | lr 0.000000 |  8.50 ms | loss 0.00138 | ppl     1.00 | mae 0.03566 | mape 0.085234
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 992 | time:  1.77s | valid loss 1.01301 | valid ppl     2.75 | valid MAE 0.03592 | valid MAPE 0.12265
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 993 |    41/  205 batches | lr 0.000000 |  8.82 ms | loss 0.00252 | ppl     1.00 | mae 0.01841 | mape 0.040624
# | epoch 993 |    82/  205 batches | lr 0.000000 |  8.32 ms | loss 0.00082 | ppl     1.00 | mae 0.04549 | mape 0.11792
# | epoch 993 |   123/  205 batches | lr 0.000000 |  8.25 ms | loss 0.00264 | ppl     1.00 | mae 0.02889 | mape 0.066985
# | epoch 993 |   164/  205 batches | lr 0.000000 |  8.25 ms | loss 0.00138 | ppl     1.00 | mae 0.03566 | mape 0.085234
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 993 | time:  1.79s | valid loss 1.01301 | valid ppl     2.75 | valid MAE 0.03592 | valid MAPE 0.12265
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 994 |    41/  205 batches | lr 0.000000 |  8.75 ms | loss 0.00252 | ppl     1.00 | mae 0.01841 | mape 0.040624
# | epoch 994 |    82/  205 batches | lr 0.000000 |  8.83 ms | loss 0.00082 | ppl     1.00 | mae 0.04549 | mape 0.11792
# | epoch 994 |   123/  205 batches | lr 0.000000 |  8.76 ms | loss 0.00264 | ppl     1.00 | mae 0.02889 | mape 0.066985
# | epoch 994 |   164/  205 batches | lr 0.000000 |  8.50 ms | loss 0.00138 | ppl     1.00 | mae 0.03566 | mape 0.085234
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 994 | time:  1.83s | valid loss 1.01301 | valid ppl     2.75 | valid MAE 0.03592 | valid MAPE 0.12265
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 995 |    41/  205 batches | lr 0.000000 |  8.68 ms | loss 0.00252 | ppl     1.00 | mae 0.01841 | mape 0.040624
# | epoch 995 |    82/  205 batches | lr 0.000000 |  8.42 ms | loss 0.00082 | ppl     1.00 | mae 0.04549 | mape 0.11792
# | epoch 995 |   123/  205 batches | lr 0.000000 |  8.61 ms | loss 0.00264 | ppl     1.00 | mae 0.02889 | mape 0.066985
# | epoch 995 |   164/  205 batches | lr 0.000000 |  8.48 ms | loss 0.00138 | ppl     1.00 | mae 0.03566 | mape 0.085234
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 995 | time:  1.81s | valid loss 1.01301 | valid ppl     2.75 | valid MAE 0.03592 | valid MAPE 0.12265
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 996 |    41/  205 batches | lr 0.000000 |  9.63 ms | loss 0.00252 | ppl     1.00 | mae 0.01841 | mape 0.040624
# | epoch 996 |    82/  205 batches | lr 0.000000 |  8.37 ms | loss 0.00082 | ppl     1.00 | mae 0.04549 | mape 0.11792
# | epoch 996 |   123/  205 batches | lr 0.000000 |  8.41 ms | loss 0.00264 | ppl     1.00 | mae 0.02889 | mape 0.066985
# | epoch 996 |   164/  205 batches | lr 0.000000 |  8.32 ms | loss 0.00138 | ppl     1.00 | mae 0.03566 | mape 0.085234
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 996 | time:  1.82s | valid loss 1.01301 | valid ppl     2.75 | valid MAE 0.03592 | valid MAPE 0.12265
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 997 |    41/  205 batches | lr 0.000000 |  8.68 ms | loss 0.00252 | ppl     1.00 | mae 0.01841 | mape 0.040624
# | epoch 997 |    82/  205 batches | lr 0.000000 |  8.60 ms | loss 0.00082 | ppl     1.00 | mae 0.04549 | mape 0.11792
# | epoch 997 |   123/  205 batches | lr 0.000000 |  8.31 ms | loss 0.00264 | ppl     1.00 | mae 0.02889 | mape 0.066985
# | epoch 997 |   164/  205 batches | lr 0.000000 |  8.34 ms | loss 0.00138 | ppl     1.00 | mae 0.03566 | mape 0.085234
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 997 | time:  1.78s | valid loss 1.01301 | valid ppl     2.75 | valid MAE 0.03592 | valid MAPE 0.12265
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 998 |    41/  205 batches | lr 0.000000 |  8.63 ms | loss 0.00252 | ppl     1.00 | mae 0.01841 | mape 0.040624
# | epoch 998 |    82/  205 batches | lr 0.000000 |  8.41 ms | loss 0.00082 | ppl     1.00 | mae 0.04549 | mape 0.11792
# | epoch 998 |   123/  205 batches | lr 0.000000 |  8.36 ms | loss 0.00264 | ppl     1.00 | mae 0.02889 | mape 0.066985
# | epoch 998 |   164/  205 batches | lr 0.000000 |  8.39 ms | loss 0.00138 | ppl     1.00 | mae 0.03566 | mape 0.085234
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 998 | time:  1.79s | valid loss 1.01301 | valid ppl     2.75 | valid MAE 0.03592 | valid MAPE 0.12265
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 999 |    41/  205 batches | lr 0.000000 |  8.69 ms | loss 0.00252 | ppl     1.00 | mae 0.01841 | mape 0.040624
# | epoch 999 |    82/  205 batches | lr 0.000000 |  8.45 ms | loss 0.00082 | ppl     1.00 | mae 0.04549 | mape 0.11792
# | epoch 999 |   123/  205 batches | lr 0.000000 |  8.45 ms | loss 0.00264 | ppl     1.00 | mae 0.02889 | mape 0.066985
# | epoch 999 |   164/  205 batches | lr 0.000000 |  9.02 ms | loss 0.00138 | ppl     1.00 | mae 0.03566 | mape 0.085234
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 999 | time:  1.81s | valid loss 1.01301 | valid ppl     2.75 | valid MAE 0.03592 | valid MAPE 0.12265
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 1000 |    41/  205 batches | lr 0.000000 |  8.86 ms | loss 0.00252 | ppl     1.00 | mae 0.01841 | mape 0.040624
# | epoch 1000 |    82/  205 batches | lr 0.000000 |  8.49 ms | loss 0.00082 | ppl     1.00 | mae 0.04549 | mape 0.11792
# | epoch 1000 |   123/  205 batches | lr 0.000000 |  8.47 ms | loss 0.00264 | ppl     1.00 | mae 0.02889 | mape 0.066985
# | epoch 1000 |   164/  205 batches | lr 0.000000 |  8.45 ms | loss 0.00138 | ppl     1.00 | mae 0.03566 | mape 0.085234
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 1000 | time:  1.81s | valid loss 1.01301 | valid ppl     2.75 | valid MAE 0.03592 | valid MAPE 0.12265
# ----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Evaluate the model

# %%
# load the bets model
model.load_state_dict(torch.load('tranformer_models/state_dict.pt'))
# Out:
# <All keys matched successfully>

# %%
model
# Out:
# TimeSeriesTransformer(
#   (t2v): Time2Vector()
#   (encoder_layer): TransformerEncoderLayer(
#     (self_attn): MultiheadAttention(
#       (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#     )
#     (linear1): Linear(in_features=128, out_features=2048, bias=True)
#     (dropout): Dropout(p=0.0, inplace=False)
#     (linear2): Linear(in_features=2048, out_features=128, bias=True)
#     (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (dropout1): Dropout(p=0.0, inplace=False)
#     (dropout2): Dropout(p=0.0, inplace=False)
#   )
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (dropout2): Dropout(p=0.0, inplace=False)
#       )
#     )
#   )
#   (decoder): Linear(in_features=128, out_features=1, bias=True)
# )

# %% [markdown]
# ## Mean Absolute Error and Mean Absolute Percentage Error evaluations

# %%
def evaluation_plots(train_mae: list, val_mae: list, train_mape: list, val_mape: list) -> None:
    """plots the mae and mape

    Args:
        train_mae (list): train mae list
        val_mae (list): val mae list
        train_mape (list): train mape list 
        val_mape (list): val mape list
    """
    fig = plt.figure(figsize=(15, 10))
    st = fig.suptitle("MAE and MAPE Evaluation", fontsize=20)
    st.set_y(0.95)

    ax1 = fig.add_subplot(211)
    ax1.plot(train_mae, label='training MAE')
    ax1.plot(val_mae, label='validation MAE')
    ax1.set_xlabel('Epochs')
    ax1.set_title("MAE", fontsize=18)
    ax1.legend(loc="best", fontsize=12)
    ax1.grid(linestyle="--")

    ax2 = fig.add_subplot(212)
    ax2.plot(train_mape, label='training MAPE')
    ax2.plot(val_mape, label='validation MAPE')
    ax2.set_xlabel('Epochs')
    ax2.set_title("MAPE", fontsize=18)
    ax2.legend(loc="best", fontsize=12)
    ax2.grid(linestyle="--")

    print(f"Train -> MAE: {train_mae[-1]} | MAPE: {train_mape[-1]}")
    print(f"Validation -> MAE: {val_mae[-1]} | MAPE: {val_mape[-1]}")

# %%
evaluation_plots(train_mae=train_mae, train_mape=train_mape, val_mae=val_mae, val_mape=val_mape)
# Out:
# Train -> MAE: 0.026107875630259514 | MAPE: 22.57889175415039
# Validation -> MAE: 0.03592125326395035 | MAPE: 0.12264976650476456

# %% [markdown]
# ## Predictions evaluation

# %%
for batch in test_loader:
    print(batch)
# Out:
# {'inputs': tensor([[[0.4490, 0.4253, 0.4471, 0.4494, 0.2056],
#          [0.4447, 0.4376, 0.4461, 0.4169, 0.1912],
#          [0.4258, 0.4167, 0.3925, 0.4536, 0.1736],
#          ...,
#          [0.4073, 0.3733, 0.3886, 0.4193, 0.1077],
#          [0.4322, 0.4912, 0.4564, 0.4282, 0.1538],
#          [0.4553, 0.4556, 0.4322, 0.4419, 0.1736]],
#
#         [[0.4447, 0.4376, 0.4461, 0.4169, 0.1912],
#          [0.4258, 0.4167, 0.3925, 0.4536, 0.1736],
#          [0.4514, 0.4739, 0.4751, 0.4550, 0.1959],
#          ...,
#          [0.4322, 0.4912, 0.4564, 0.4282, 0.1538],
#          [0.4553, 0.4556, 0.4322, 0.4419, 0.1736],
#          [0.4286, 0.4383, 0.4391, 0.4554, 0.0650]],
#
#         [[0.4258, 0.4167, 0.3925, 0.4536, 0.1736],
#          [0.4514, 0.4739, 0.4751, 0.4550, 0.1959],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4553, 0.4556, 0.4322, 0.4419, 0.1736],
#          [0.4286, 0.4383, 0.4391, 0.4554, 0.0650],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         ...,
#
#         [[0.4517, 0.4314, 0.4433, 0.4159, 0.2313],
#          [0.3622, 0.3585, 0.3467, 0.3975, 0.1725],
#          [0.4197, 0.3852, 0.4535, 0.3840, 0.3446],
#          ...,
#          [0.4585, 0.4781, 0.4295, 0.4777, 0.1739],
#          [0.5087, 0.4843, 0.4823, 0.5059, 0.1681],
#          [0.4404, 0.4749, 0.4907, 0.4398, 0.1870]],
#
#         [[0.3622, 0.3585, 0.3467, 0.3975, 0.1725],
#          [0.4197, 0.3852, 0.4535, 0.3840, 0.3446],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.5087, 0.4843, 0.4823, 0.5059, 0.1681],
#          [0.4404, 0.4749, 0.4907, 0.4398, 0.1870],
#          [0.4268, 0.4198, 0.4216, 0.4237, 0.2244]],
#
#         [[0.4197, 0.3852, 0.4535, 0.3840, 0.3446],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4404, 0.4749, 0.4907, 0.4398, 0.1870],
#          [0.4268, 0.4198, 0.4216, 0.4237, 0.2244],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]]]), 'targets': tensor([0.4554, 0.4383, 0.4383, 0.4383, 0.4806, 0.4275, 0.4448, 0.4695, 0.4383,
#         0.4383, 0.4383, 0.3667, 0.4726, 0.4660, 0.5103, 0.4649, 0.4383, 0.4383,
#         0.4065, 0.4403, 0.4493, 0.4201, 0.4034, 0.4383, 0.4383, 0.4383, 0.4777,
#         0.5059, 0.4398, 0.4237, 0.4383, 0.4383])}
# {'inputs': tensor([[[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.3276, 0.3450, 0.3345, 0.3821, 0.1113],
#          ...,
#          [0.4268, 0.4198, 0.4216, 0.4237, 0.2244],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.3276, 0.3450, 0.3345, 0.3821, 0.1113],
#          [0.4896, 0.5011, 0.4533, 0.4893, 0.1459],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4470, 0.3962, 0.4477, 0.4558, 0.2830]],
#
#         [[0.3276, 0.3450, 0.3345, 0.3821, 0.1113],
#          [0.4896, 0.5011, 0.4533, 0.4893, 0.1459],
#          [0.4427, 0.3814, 0.4741, 0.3232, 0.2159],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4470, 0.3962, 0.4477, 0.4558, 0.2830],
#          [0.4529, 0.5029, 0.4525, 0.4310, 0.1596]],
#
#         ...,
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4199, 0.3539, 0.4385, 0.3591, 0.1586],
#          [0.4030, 0.4606, 0.3629, 0.4612, 0.1799],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4043, 0.4030, 0.3942, 0.4008, 0.2458]],
#
#         [[0.4199, 0.3539, 0.4385, 0.3591, 0.1586],
#          [0.4030, 0.4606, 0.3629, 0.4612, 0.1799],
#          [0.4214, 0.4346, 0.4390, 0.4276, 0.2024],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4043, 0.4030, 0.3942, 0.4008, 0.2458],
#          [0.4296, 0.3517, 0.4027, 0.4444, 0.2065]],
#
#         [[0.4030, 0.4606, 0.3629, 0.4612, 0.1799],
#          [0.4214, 0.4346, 0.4390, 0.4276, 0.2024],
#          [0.4322, 0.4132, 0.4363, 0.4636, 0.1946],
#          ...,
#          [0.4043, 0.4030, 0.3942, 0.4008, 0.2458],
#          [0.4296, 0.3517, 0.4027, 0.4444, 0.2065],
#          [0.4789, 0.5071, 0.4592, 0.4933, 0.1792]]]), 'targets': tensor([0.4558, 0.4310, 0.3137, 0.4856, 0.3446, 0.4383, 0.4383, 0.5161, 0.5057,
#         0.4432, 0.4909, 0.4572, 0.4383, 0.4383, 0.4742, 0.4329, 0.4366, 0.4463,
#         0.4611, 0.4383, 0.4383, 0.4383, 0.4355, 0.4367, 0.4169, 0.4293, 0.4383,
#         0.4383, 0.4008, 0.4444, 0.4933, 0.3195])}
# {'inputs': tensor([[[0.4214, 0.4346, 0.4390, 0.4276, 0.2024],
#          [0.4322, 0.4132, 0.4363, 0.4636, 0.1946],
#          [0.4466, 0.4739, 0.4755, 0.4550, 0.1593],
#          ...,
#          [0.4296, 0.3517, 0.4027, 0.4444, 0.2065],
#          [0.4789, 0.5071, 0.4592, 0.4933, 0.1792],
#          [0.4338, 0.3810, 0.4910, 0.3195, 0.2127]],
#
#         [[0.4322, 0.4132, 0.4363, 0.4636, 0.1946],
#          [0.4466, 0.4739, 0.4755, 0.4550, 0.1593],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4789, 0.5071, 0.4592, 0.4933, 0.1792],
#          [0.4338, 0.3810, 0.4910, 0.3195, 0.2127],
#          [0.3592, 0.4071, 0.3440, 0.4152, 0.1897]],
#
#         [[0.4466, 0.4739, 0.4755, 0.4550, 0.1593],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4338, 0.3810, 0.4910, 0.3195, 0.2127],
#          [0.3592, 0.4071, 0.3440, 0.4152, 0.1897],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         ...,
#
#         [[0.3929, 0.4063, 0.3675, 0.4574, 0.1469],
#          [0.4329, 0.4561, 0.4654, 0.4053, 0.1832],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4296, 0.4227, 0.4165, 0.4118, 0.1966],
#          [0.4105, 0.3939, 0.3880, 0.4637, 0.1991],
#          [0.5109, 0.5184, 0.4855, 0.5189, 0.2175]],
#
#         [[0.4329, 0.4561, 0.4654, 0.4053, 0.1832],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4105, 0.3939, 0.3880, 0.4637, 0.1991],
#          [0.5109, 0.5184, 0.4855, 0.5189, 0.2175],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4499, 0.4327, 0.4213, 0.4656, 0.2390],
#          ...,
#          [0.5109, 0.5184, 0.4855, 0.5189, 0.2175],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]]]), 'targets': tensor([0.4152, 0.4383, 0.4383, 0.5537, 0.3991, 0.3749, 0.3732, 0.5328, 0.4383,
#         0.4383, 0.4123, 0.5069, 0.4675, 0.4887, 0.4432, 0.4383, 0.4383, 0.4698,
#         0.4307, 0.4522, 0.3667, 0.4353, 0.4383, 0.4383, 0.4723, 0.4013, 0.4118,
#         0.4637, 0.5189, 0.4383, 0.4383, 0.4341])}
# {'inputs': tensor([[[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4499, 0.4327, 0.4213, 0.4656, 0.2390],
#          [0.5092, 0.4953, 0.4759, 0.5167, 0.2510],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4427, 0.4706, 0.5029, 0.4341, 0.1515]],
#
#         [[0.4499, 0.4327, 0.4213, 0.4656, 0.2390],
#          [0.5092, 0.4953, 0.4759, 0.5167, 0.2510],
#          [0.4292, 0.4696, 0.4936, 0.4306, 0.1359],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4427, 0.4706, 0.5029, 0.4341, 0.1515],
#          [0.4214, 0.4396, 0.4310, 0.4230, 0.1631]],
#
#         [[0.5092, 0.4953, 0.4759, 0.5167, 0.2510],
#          [0.4292, 0.4696, 0.4936, 0.4306, 0.1359],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4427, 0.4706, 0.5029, 0.4341, 0.1515],
#          [0.4214, 0.4396, 0.4310, 0.4230, 0.1631],
#          [0.4705, 0.4661, 0.4431, 0.4558, 0.2182]],
#
#         ...,
#
#         [[0.4073, 0.3733, 0.3886, 0.4193, 0.1077],
#          [0.4322, 0.4912, 0.4564, 0.4282, 0.1538],
#          [0.4553, 0.4556, 0.4322, 0.4419, 0.1736],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4893, 0.4925, 0.4469, 0.2030],
#          [0.4373, 0.4312, 0.4420, 0.4372, 0.1880]],
#
#         [[0.4322, 0.4912, 0.4564, 0.4282, 0.1538],
#          [0.4553, 0.4556, 0.4322, 0.4419, 0.1736],
#          [0.4286, 0.4383, 0.4391, 0.4554, 0.0650],
#          ...,
#          [0.4383, 0.4893, 0.4925, 0.4469, 0.2030],
#          [0.4373, 0.4312, 0.4420, 0.4372, 0.1880],
#          [0.4477, 0.4447, 0.4347, 0.4342, 0.1957]],
#
#         [[0.4553, 0.4556, 0.4322, 0.4419, 0.1736],
#          [0.4286, 0.4383, 0.4391, 0.4554, 0.0650],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4373, 0.4312, 0.4420, 0.4372, 0.1880],
#          [0.4477, 0.4447, 0.4347, 0.4342, 0.1957],
#          [0.4582, 0.4325, 0.4626, 0.4711, 0.2243]]]), 'targets': tensor([0.4230, 0.4558, 0.4956, 0.4383, 0.4383, 0.4383, 0.5083, 0.4335, 0.4454,
#         0.4587, 0.4757, 0.4383, 0.4383, 0.4373, 0.4543, 0.4184, 0.4921, 0.4558,
#         0.4383, 0.4383, 0.4125, 0.4053, 0.4834, 0.3936, 0.4913, 0.4383, 0.4383,
#         0.4469, 0.4372, 0.4342, 0.4711, 0.4034])}
# {'inputs': tensor([[[0.4286, 0.4383, 0.4391, 0.4554, 0.0650],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4477, 0.4447, 0.4347, 0.4342, 0.1957],
#          [0.4582, 0.4325, 0.4626, 0.4711, 0.2243],
#          [0.4145, 0.4360, 0.4290, 0.4034, 0.1906]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4582, 0.4325, 0.4626, 0.4711, 0.2243],
#          [0.4145, 0.4360, 0.4290, 0.4034, 0.1906],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4863, 0.4826, 0.4764, 0.4806, 0.4099],
#          ...,
#          [0.4145, 0.4360, 0.4290, 0.4034, 0.1906],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         ...,
#
#         [[0.4268, 0.4198, 0.4216, 0.4237, 0.2244],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4507, 0.4541, 0.4502, 0.4439, 0.3029],
#          [0.4440, 0.4450, 0.4485, 0.4420, 0.1219],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4470, 0.3962, 0.4477, 0.4558, 0.2830],
#          ...,
#          [0.4440, 0.4450, 0.4485, 0.4420, 0.1219],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4470, 0.3962, 0.4477, 0.4558, 0.2830],
#          [0.4529, 0.5029, 0.4525, 0.4310, 0.1596],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]]]), 'targets': tensor([0.4383, 0.4383, 0.4516, 0.4059, 0.4417, 0.4779, 0.4740, 0.4383, 0.4383,
#         0.3877, 0.3962, 0.3342, 0.4973, 0.5106, 0.4383, 0.4383, 0.4260, 0.3970,
#         0.4240, 0.4895, 0.4345, 0.4383, 0.4383, 0.4863, 0.4280, 0.4474, 0.4439,
#         0.4420, 0.4383, 0.4383, 0.4383, 0.4359])}
# {'inputs': tensor([[[0.4470, 0.3962, 0.4477, 0.4558, 0.2830],
#          [0.4529, 0.5029, 0.4525, 0.4310, 0.1596],
#          [0.3956, 0.2929, 0.4055, 0.3137, 0.3470],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4564, 0.4314, 0.4449, 0.4359, 0.2134]],
#
#         [[0.4529, 0.5029, 0.4525, 0.4310, 0.1596],
#          [0.3956, 0.2929, 0.4055, 0.3137, 0.3470],
#          [0.4303, 0.4685, 0.3358, 0.4856, 0.1156],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4564, 0.4314, 0.4449, 0.4359, 0.2134],
#          [0.4191, 0.4391, 0.4271, 0.4453, 0.2279]],
#
#         [[0.3956, 0.2929, 0.4055, 0.3137, 0.3470],
#          [0.4303, 0.4685, 0.3358, 0.4856, 0.1156],
#          [0.3719, 0.3587, 0.4671, 0.3446, 0.1780],
#          ...,
#          [0.4564, 0.4314, 0.4449, 0.4359, 0.2134],
#          [0.4191, 0.4391, 0.4271, 0.4453, 0.2279],
#          [0.4233, 0.4032, 0.4205, 0.4207, 0.1800]],
#
#         ...,
#
#         [[0.4296, 0.3517, 0.4027, 0.4444, 0.2065],
#          [0.4789, 0.5071, 0.4592, 0.4933, 0.1792],
#          [0.4338, 0.3810, 0.4910, 0.3195, 0.2127],
#          ...,
#          [0.4451, 0.4423, 0.4501, 0.4495, 0.0816],
#          [0.4477, 0.4523, 0.4477, 0.4396, 0.1639],
#          [0.4404, 0.4393, 0.4354, 0.4447, 0.2282]],
#
#         [[0.4789, 0.5071, 0.4592, 0.4933, 0.1792],
#          [0.4338, 0.3810, 0.4910, 0.3195, 0.2127],
#          [0.3592, 0.4071, 0.3440, 0.4152, 0.1897],
#          ...,
#          [0.4477, 0.4523, 0.4477, 0.4396, 0.1639],
#          [0.4404, 0.4393, 0.4354, 0.4447, 0.2282],
#          [0.4588, 0.4527, 0.4497, 0.4636, 0.1625]],
#
#         [[0.4338, 0.3810, 0.4910, 0.3195, 0.2127],
#          [0.3592, 0.4071, 0.3440, 0.4152, 0.1897],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4404, 0.4393, 0.4354, 0.4447, 0.2282],
#          [0.4588, 0.4527, 0.4497, 0.4636, 0.1625],
#          [0.4773, 0.4675, 0.4675, 0.4747, 0.1533]]]), 'targets': tensor([0.4453, 0.4207, 0.4811, 0.4383, 0.4383, 0.4344, 0.4391, 0.4294, 0.4608,
#         0.4477, 0.4383, 0.4383, 0.4471, 0.4285, 0.4121, 0.4362, 0.3746, 0.4383,
#         0.4383, 0.5062, 0.4631, 0.4330, 0.4665, 0.4544, 0.4383, 0.4383, 0.4495,
#         0.4396, 0.4447, 0.4636, 0.4747, 0.4383])}
# {'inputs': tensor([[[0.3592, 0.4071, 0.3440, 0.4152, 0.1897],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4588, 0.4527, 0.4497, 0.4636, 0.1625],
#          [0.4773, 0.4675, 0.4675, 0.4747, 0.1533],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.5054, 0.5061, 0.4419, 0.5537, 0.1364],
#          ...,
#          [0.4773, 0.4675, 0.4675, 0.4747, 0.1533],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.5054, 0.5061, 0.4419, 0.5537, 0.1364],
#          [0.4282, 0.4712, 0.5154, 0.3991, 0.2111],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         ...,
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4427, 0.4706, 0.5029, 0.4341, 0.1515],
#          ...,
#          [0.4189, 0.4229, 0.4289, 0.4120, 0.1851],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4427, 0.4706, 0.5029, 0.4341, 0.1515],
#          [0.4214, 0.4396, 0.4310, 0.4230, 0.1631],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4492, 0.4329, 0.4512, 0.4293, 0.1758]],
#
#         [[0.4427, 0.4706, 0.5029, 0.4341, 0.1515],
#          [0.4214, 0.4396, 0.4310, 0.4230, 0.1631],
#          [0.4705, 0.4661, 0.4431, 0.4558, 0.2182],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4492, 0.4329, 0.4512, 0.4293, 0.1758],
#          [0.4400, 0.4252, 0.4227, 0.4781, 0.2067]]]), 'targets': tensor([0.4383, 0.4383, 0.4285, 0.4546, 0.3967, 0.4930, 0.4383, 0.4383, 0.4550,
#         0.4212, 0.4439, 0.4224, 0.4017, 0.4383, 0.4383, 0.3613, 0.5118, 0.4783,
#         0.4481, 0.4875, 0.4383, 0.4383, 0.4498, 0.4154, 0.4374, 0.4587, 0.4120,
#         0.4383, 0.4383, 0.4293, 0.4781, 0.4158])}
# {'inputs': tensor([[[0.4214, 0.4396, 0.4310, 0.4230, 0.1631],
#          [0.4705, 0.4661, 0.4431, 0.4558, 0.2182],
#          [0.4701, 0.4698, 0.4695, 0.4956, 0.1678],
#          ...,
#          [0.4492, 0.4329, 0.4512, 0.4293, 0.1758],
#          [0.4400, 0.4252, 0.4227, 0.4781, 0.2067],
#          [0.4299, 0.4685, 0.4639, 0.4158, 0.2091]],
#
#         [[0.4705, 0.4661, 0.4431, 0.4558, 0.2182],
#          [0.4701, 0.4698, 0.4695, 0.4956, 0.1678],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4400, 0.4252, 0.4227, 0.4781, 0.2067],
#          [0.4299, 0.4685, 0.4639, 0.4158, 0.2091],
#          [0.4532, 0.4478, 0.4305, 0.4674, 0.1616]],
#
#         [[0.4701, 0.4698, 0.4695, 0.4956, 0.1678],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4299, 0.4685, 0.4639, 0.4158, 0.2091],
#          [0.4532, 0.4478, 0.4305, 0.4674, 0.1616],
#          [0.4504, 0.4605, 0.4605, 0.4464, 0.1694]],
#
#         ...,
#
#         [[0.4477, 0.4447, 0.4347, 0.4342, 0.1957],
#          [0.4582, 0.4325, 0.4626, 0.4711, 0.2243],
#          [0.4145, 0.4360, 0.4290, 0.4034, 0.1906],
#          ...,
#          [0.4319, 0.4405, 0.4555, 0.4317, 0.2791],
#          [0.4444, 0.4450, 0.4373, 0.4398, 0.1769],
#          [0.4476, 0.4411, 0.4444, 0.4521, 0.1707]],
#
#         [[0.4582, 0.4325, 0.4626, 0.4711, 0.2243],
#          [0.4145, 0.4360, 0.4290, 0.4034, 0.1906],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4444, 0.4450, 0.4373, 0.4398, 0.1769],
#          [0.4476, 0.4411, 0.4444, 0.4521, 0.1707],
#          [0.4336, 0.4347, 0.4361, 0.4366, 0.1558]],
#
#         [[0.4145, 0.4360, 0.4290, 0.4034, 0.1906],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4476, 0.4411, 0.4444, 0.4521, 0.1707],
#          [0.4336, 0.4347, 0.4361, 0.4366, 0.1558],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]]]), 'targets': tensor([0.4674, 0.4464, 0.4383, 0.4383, 0.4337, 0.4431, 0.4445, 0.4584, 0.4461,
#         0.4383, 0.4383, 0.4510, 0.4040, 0.3861, 0.4444, 0.4778, 0.4383, 0.4383,
#         0.4796, 0.4455, 0.4490, 0.4100, 0.4810, 0.4383, 0.4383, 0.4592, 0.4317,
#         0.4398, 0.4521, 0.4366, 0.4383, 0.4383])}
# {'inputs': tensor([[[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4513, 0.4536, 0.4312, 0.4516, 0.1771],
#          ...,
#          [0.4336, 0.4347, 0.4361, 0.4366, 0.1558],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4513, 0.4536, 0.4312, 0.4516, 0.1771],
#          [0.4033, 0.3694, 0.4233, 0.4059, 0.2140],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4513, 0.4536, 0.4312, 0.4516, 0.1771],
#          [0.4033, 0.3694, 0.4233, 0.4059, 0.2140],
#          [0.4483, 0.4763, 0.4360, 0.4417, 0.1780],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4318, 0.4294, 0.4414, 0.4218, 0.2376]],
#
#         ...,
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4564, 0.4314, 0.4449, 0.4359, 0.2134],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4165, 0.4274, 0.4739, 0.3753, 0.2091]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4564, 0.4314, 0.4449, 0.4359, 0.2134],
#          [0.4191, 0.4391, 0.4271, 0.4453, 0.2279],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4165, 0.4274, 0.4739, 0.3753, 0.2091],
#          [0.4536, 0.4733, 0.3948, 0.4893, 0.1670]],
#
#         [[0.4564, 0.4314, 0.4449, 0.4359, 0.2134],
#          [0.4191, 0.4391, 0.4271, 0.4453, 0.2279],
#          [0.4233, 0.4032, 0.4205, 0.4207, 0.1800],
#          ...,
#          [0.4165, 0.4274, 0.4739, 0.3753, 0.2091],
#          [0.4536, 0.4733, 0.3948, 0.4893, 0.1670],
#          [0.4342, 0.4165, 0.4492, 0.4582, 0.1973]]]), 'targets': tensor([0.4383, 0.4218, 0.4319, 0.4159, 0.4008, 0.4383, 0.4383, 0.4493, 0.4104,
#         0.4794, 0.4307, 0.3941, 0.4383, 0.4383, 0.3559, 0.4343, 0.4844, 0.4971,
#         0.4454, 0.4383, 0.4383, 0.4248, 0.3395, 0.4459, 0.3805, 0.4940, 0.4383,
#         0.4383, 0.3753, 0.4893, 0.4582, 0.4785])}
# {'inputs': tensor([[[0.4191, 0.4391, 0.4271, 0.4453, 0.2279],
#          [0.4233, 0.4032, 0.4205, 0.4207, 0.1800],
#          [0.4718, 0.4826, 0.4552, 0.4811, 0.1256],
#          ...,
#          [0.4536, 0.4733, 0.3948, 0.4893, 0.1670],
#          [0.4342, 0.4165, 0.4492, 0.4582, 0.1973],
#          [0.5098, 0.5437, 0.5103, 0.4785, 0.1801]],
#
#         [[0.4233, 0.4032, 0.4205, 0.4207, 0.1800],
#          [0.4718, 0.4826, 0.4552, 0.4811, 0.1256],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4342, 0.4165, 0.4492, 0.4582, 0.1973],
#          [0.5098, 0.5437, 0.5103, 0.4785, 0.1801],
#          [0.4186, 0.4410, 0.4635, 0.4290, 0.1538]],
#
#         [[0.4718, 0.4826, 0.4552, 0.4811, 0.1256],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.5098, 0.5437, 0.5103, 0.4785, 0.1801],
#          [0.4186, 0.4410, 0.4635, 0.4290, 0.1538],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         ...,
#
#         [[0.4588, 0.4527, 0.4497, 0.4636, 0.1625],
#          [0.4773, 0.4675, 0.4675, 0.4747, 0.1533],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4679, 0.4465, 0.4565, 0.4696, 0.2122],
#          [0.4586, 0.4817, 0.4721, 0.4586, 0.1988],
#          [0.4750, 0.4578, 0.4761, 0.4564, 0.1908]],
#
#         [[0.4773, 0.4675, 0.4675, 0.4747, 0.1533],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4586, 0.4817, 0.4721, 0.4586, 0.1988],
#          [0.4750, 0.4578, 0.4761, 0.4564, 0.1908],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4750, 0.4578, 0.4761, 0.4564, 0.1908],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]]]), 'targets': tensor([0.4290, 0.4383, 0.4383, 0.4050, 0.4265, 0.4529, 0.5210, 0.4745, 0.4383,
#         0.4383, 0.4546, 0.4741, 0.4560, 0.4528, 0.4331, 0.4383, 0.4383, 0.4613,
#         0.4471, 0.4138, 0.4860, 0.4477, 0.4383, 0.4383, 0.4470, 0.4561, 0.4696,
#         0.4586, 0.4564, 0.4383, 0.4383, 0.4426])}
# {'inputs': tensor([[[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4394, 0.4246, 0.4717, 0.4285, 0.2746],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4346, 0.4518, 0.4406, 0.4426, 0.1794]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4394, 0.4246, 0.4717, 0.4285, 0.2746],
#          [0.4443, 0.4556, 0.4322, 0.4546, 0.1747],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4346, 0.4518, 0.4406, 0.4426, 0.1794],
#          [0.4317, 0.4140, 0.4442, 0.4213, 0.1815]],
#
#         [[0.4394, 0.4246, 0.4717, 0.4285, 0.2746],
#          [0.4443, 0.4556, 0.4322, 0.4546, 0.1747],
#          [0.4038, 0.3930, 0.4049, 0.3967, 0.2097],
#          ...,
#          [0.4346, 0.4518, 0.4406, 0.4426, 0.1794],
#          [0.4317, 0.4140, 0.4442, 0.4213, 0.1815],
#          [0.4139, 0.3967, 0.4002, 0.3984, 0.2140]],
#
#         ...,
#
#         [[0.4492, 0.4329, 0.4512, 0.4293, 0.1758],
#          [0.4400, 0.4252, 0.4227, 0.4781, 0.2067],
#          [0.4299, 0.4685, 0.4639, 0.4158, 0.2091],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4431, 0.4873, 0.3948, 0.4952, 0.1681],
#          [0.5239, 0.5360, 0.5274, 0.5387, 0.1759]],
#
#         [[0.4400, 0.4252, 0.4227, 0.4781, 0.2067],
#          [0.4299, 0.4685, 0.4639, 0.4158, 0.2091],
#          [0.4532, 0.4478, 0.4305, 0.4674, 0.1616],
#          ...,
#          [0.4431, 0.4873, 0.3948, 0.4952, 0.1681],
#          [0.5239, 0.5360, 0.5274, 0.5387, 0.1759],
#          [0.4497, 0.4828, 0.4999, 0.4532, 0.1761]],
#
#         [[0.4299, 0.4685, 0.4639, 0.4158, 0.2091],
#          [0.4532, 0.4478, 0.4305, 0.4674, 0.1616],
#          [0.4504, 0.4605, 0.4605, 0.4464, 0.1694],
#          ...,
#          [0.5239, 0.5360, 0.5274, 0.5387, 0.1759],
#          [0.4497, 0.4828, 0.4999, 0.4532, 0.1761],
#          [0.4282, 0.4294, 0.4384, 0.4034, 0.1709]]]), 'targets': tensor([0.4213, 0.3984, 0.4409, 0.4733, 0.4383, 0.4383, 0.4382, 0.4570, 0.4257,
#         0.4547, 0.4315, 0.4383, 0.4383, 0.4228, 0.4463, 0.4494, 0.4383, 0.3280,
#         0.4383, 0.4383, 0.5023, 0.3463, 0.3810, 0.5071, 0.3973, 0.4383, 0.4383,
#         0.4952, 0.5387, 0.4532, 0.4034, 0.4846])}
# {'inputs': tensor([[[0.4532, 0.4478, 0.4305, 0.4674, 0.1616],
#          [0.4504, 0.4605, 0.4605, 0.4464, 0.1694],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4497, 0.4828, 0.4999, 0.4532, 0.1761],
#          [0.4282, 0.4294, 0.4384, 0.4034, 0.1709],
#          [0.4572, 0.4427, 0.4348, 0.4846, 0.1883]],
#
#         [[0.4504, 0.4605, 0.4605, 0.4464, 0.1694],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4282, 0.4294, 0.4384, 0.4034, 0.1709],
#          [0.4572, 0.4427, 0.4348, 0.4846, 0.1883],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4367, 0.4335, 0.4478, 0.4337, 0.1903],
#          ...,
#          [0.4572, 0.4427, 0.4348, 0.4846, 0.1883],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         ...,
#
#         [[0.4336, 0.4347, 0.4361, 0.4366, 0.1558],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.3648, 0.4092, 0.3424, 0.4336, 0.1601],
#          [0.4208, 0.4294, 0.4427, 0.4186, 0.1839],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4208, 0.4294, 0.4427, 0.4186, 0.1839],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4318, 0.4294, 0.4414, 0.4218, 0.2376],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4023, 0.3545, 0.3946, 0.4313, 0.2103]]]), 'targets': tensor([0.4383, 0.4383, 0.3940, 0.4020, 0.5176, 0.3959, 0.3884, 0.4383, 0.4383,
#         0.3830, 0.5245, 0.4877, 0.4685, 0.4383, 0.4383, 0.4383, 0.5054, 0.4334,
#         0.4451, 0.4238, 0.4255, 0.4383, 0.4383, 0.4692, 0.4352, 0.3442, 0.4336,
#         0.4186, 0.4383, 0.4383, 0.4313, 0.4827])}
# {'inputs': tensor([[[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4318, 0.4294, 0.4414, 0.4218, 0.2376],
#          [0.4237, 0.4178, 0.4198, 0.4319, 0.1858],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4023, 0.3545, 0.3946, 0.4313, 0.2103],
#          [0.4809, 0.4976, 0.4527, 0.4827, 0.1677]],
#
#         [[0.4318, 0.4294, 0.4414, 0.4218, 0.2376],
#          [0.4237, 0.4178, 0.4198, 0.4319, 0.1858],
#          [0.4470, 0.4362, 0.4328, 0.4159, 0.1895],
#          ...,
#          [0.4023, 0.3545, 0.3946, 0.4313, 0.2103],
#          [0.4809, 0.4976, 0.4527, 0.4827, 0.1677],
#          [0.4740, 0.5098, 0.5000, 0.4519, 0.1872]],
#
#         [[0.4237, 0.4178, 0.4198, 0.4319, 0.1858],
#          [0.4470, 0.4362, 0.4328, 0.4159, 0.1895],
#          [0.4282, 0.4011, 0.4317, 0.4008, 0.1830],
#          ...,
#          [0.4809, 0.4976, 0.4527, 0.4827, 0.1677],
#          [0.4740, 0.5098, 0.5000, 0.4519, 0.1872],
#          [0.4335, 0.3801, 0.4434, 0.3692, 0.2031]],
#
#         ...,
#
#         [[0.4536, 0.4733, 0.3948, 0.4893, 0.1670],
#          [0.4342, 0.4165, 0.4492, 0.4582, 0.1973],
#          [0.5098, 0.5437, 0.5103, 0.4785, 0.1801],
#          ...,
#          [0.4193, 0.4600, 0.4631, 0.4203, 0.1651],
#          [0.4484, 0.4317, 0.4106, 0.4790, 0.2042],
#          [0.5011, 0.5269, 0.5108, 0.5087, 0.1941]],
#
#         [[0.4342, 0.4165, 0.4492, 0.4582, 0.1973],
#          [0.5098, 0.5437, 0.5103, 0.4785, 0.1801],
#          [0.4186, 0.4410, 0.4635, 0.4290, 0.1538],
#          ...,
#          [0.4484, 0.4317, 0.4106, 0.4790, 0.2042],
#          [0.5011, 0.5269, 0.5108, 0.5087, 0.1941],
#          [0.4371, 0.3714, 0.4449, 0.3504, 0.2342]],
#
#         [[0.5098, 0.5437, 0.5103, 0.4785, 0.1801],
#          [0.4186, 0.4410, 0.4635, 0.4290, 0.1538],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.5011, 0.5269, 0.5108, 0.5087, 0.1941],
#          [0.4371, 0.3714, 0.4449, 0.3504, 0.2342],
#          [0.3721, 0.3486, 0.3882, 0.3463, 0.1875]]]), 'targets': tensor([0.4519, 0.3692, 0.4422, 0.4383, 0.4383, 0.4383, 0.3491, 0.3913, 0.3847,
#         0.3465, 0.4383, 0.4383, 0.4517, 0.3792, 0.4310, 0.4122, 0.5564, 0.4383,
#         0.4383, 0.5299, 0.4716, 0.4840, 0.3200, 0.4633, 0.4383, 0.4383, 0.4203,
#         0.4790, 0.5087, 0.3504, 0.3463, 0.4383])}
# {'inputs': tensor([[[0.4186, 0.4410, 0.4635, 0.4290, 0.1538],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4371, 0.3714, 0.4449, 0.3504, 0.2342],
#          [0.3721, 0.3486, 0.3882, 0.3463, 0.1875],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4425, 0.4099, 0.4151, 0.4050, 0.1906],
#          ...,
#          [0.3721, 0.3486, 0.3882, 0.3463, 0.1875],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4425, 0.4099, 0.4151, 0.4050, 0.1906],
#          [0.3932, 0.4177, 0.4193, 0.4265, 0.2116],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.3310, 0.3980, 0.3374, 0.4196, 0.1595]],
#
#         ...,
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4346, 0.4518, 0.4406, 0.4426, 0.1794],
#          ...,
#          [0.4641, 0.4275, 0.4690, 0.3754, 0.1884],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4346, 0.4518, 0.4406, 0.4426, 0.1794],
#          [0.4317, 0.4140, 0.4442, 0.4213, 0.1815],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.3892, 0.3935, 0.3513, 0.4023, 0.2227]],
#
#         [[0.4346, 0.4518, 0.4406, 0.4426, 0.1794],
#          [0.4317, 0.4140, 0.4442, 0.4213, 0.1815],
#          [0.4139, 0.3967, 0.4002, 0.3984, 0.2140],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.3892, 0.3935, 0.3513, 0.4023, 0.2227],
#          [0.4651, 0.4688, 0.4222, 0.5421, 0.1823]]]), 'targets': tensor([0.4383, 0.4196, 0.5148, 0.4425, 0.3356, 0.4035, 0.4383, 0.4383, 0.4383,
#         0.3891, 0.3490, 0.5108, 0.5468, 0.4383, 0.4383, 0.4264, 0.3632, 0.5287,
#         0.4128, 0.3998, 0.4383, 0.4383, 0.2951, 0.4032, 0.5629, 0.4175, 0.3754,
#         0.4383, 0.4383, 0.4023, 0.5421, 0.5469])}
# {'inputs': tensor([[[0.4317, 0.4140, 0.4442, 0.4213, 0.1815],
#          [0.4139, 0.3967, 0.4002, 0.3984, 0.2140],
#          [0.4173, 0.4566, 0.4270, 0.4409, 0.1584],
#          ...,
#          [0.3892, 0.3935, 0.3513, 0.4023, 0.2227],
#          [0.4651, 0.4688, 0.4222, 0.5421, 0.1823],
#          [0.5380, 0.5125, 0.5533, 0.5469, 0.2331]],
#
#         [[0.4139, 0.3967, 0.4002, 0.3984, 0.2140],
#          [0.4173, 0.4566, 0.4270, 0.4409, 0.1584],
#          [0.4631, 0.4408, 0.4340, 0.4733, 0.1779],
#          ...,
#          [0.4651, 0.4688, 0.4222, 0.5421, 0.1823],
#          [0.5380, 0.5125, 0.5533, 0.5469, 0.2331],
#          [0.4981, 0.5337, 0.5027, 0.4982, 0.1380]],
#
#         [[0.4173, 0.4566, 0.4270, 0.4409, 0.1584],
#          [0.4631, 0.4408, 0.4340, 0.4733, 0.1779],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.5380, 0.5125, 0.5533, 0.5469, 0.2331],
#          [0.4981, 0.5337, 0.5027, 0.4982, 0.1380],
#          [0.4962, 0.4997, 0.5077, 0.4948, 0.3558]],
#
#         ...,
#
#         [[0.4497, 0.4828, 0.4999, 0.4532, 0.1761],
#          [0.4282, 0.4294, 0.4384, 0.4034, 0.1709],
#          [0.4572, 0.4427, 0.4348, 0.4846, 0.1883],
#          ...,
#          [0.4455, 0.4085, 0.4110, 0.4217, 0.1838],
#          [0.4197, 0.4508, 0.3910, 0.4925, 0.1710],
#          [0.4454, 0.4361, 0.4988, 0.3794, 0.2072]],
#
#         [[0.4282, 0.4294, 0.4384, 0.4034, 0.1709],
#          [0.4572, 0.4427, 0.4348, 0.4846, 0.1883],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4197, 0.4508, 0.3910, 0.4925, 0.1710],
#          [0.4454, 0.4361, 0.4988, 0.3794, 0.2072],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4572, 0.4427, 0.4348, 0.4846, 0.1883],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4454, 0.4361, 0.4988, 0.3794, 0.2072],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]]]), 'targets': tensor([0.4982, 0.4948, 0.4383, 0.4383, 0.4362, 0.4931, 0.3787, 0.5079, 0.4628,
#         0.4383, 0.4383, 0.4729, 0.4977, 0.4077, 0.3623, 0.4548, 0.4383, 0.4383,
#         0.4775, 0.3774, 0.3911, 0.4589, 0.4254, 0.4383, 0.4383, 0.3564, 0.4217,
#         0.4925, 0.3794, 0.4383, 0.4383, 0.4383])}
# {'inputs': tensor([[[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4349, 0.4355, 0.4617, 0.3940, 0.2246],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4349, 0.4355, 0.4617, 0.3940, 0.2246],
#          [0.3870, 0.3748, 0.3690, 0.4020, 0.1955],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.3837, 0.4157, 0.3690, 0.4373, 0.1799]],
#
#         [[0.4349, 0.4355, 0.4617, 0.3940, 0.2246],
#          [0.3870, 0.3748, 0.3690, 0.4020, 0.1955],
#          [0.4925, 0.4432, 0.4314, 0.5176, 0.2142],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.3837, 0.4157, 0.3690, 0.4373, 0.1799],
#          [0.5051, 0.4608, 0.4438, 0.5162, 0.2031]],
#
#         ...,
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4023, 0.3545, 0.3946, 0.4313, 0.2103],
#          [0.4809, 0.4976, 0.4527, 0.4827, 0.1677],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4474, 0.4629, 0.4984, 0.4191, 0.1534]],
#
#         [[0.4023, 0.3545, 0.3946, 0.4313, 0.2103],
#          [0.4809, 0.4976, 0.4527, 0.4827, 0.1677],
#          [0.4740, 0.5098, 0.5000, 0.4519, 0.1872],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4474, 0.4629, 0.4984, 0.4191, 0.1534],
#          [0.4913, 0.4991, 0.4854, 0.5361, 0.2147]],
#
#         [[0.4809, 0.4976, 0.4527, 0.4827, 0.1677],
#          [0.4740, 0.5098, 0.5000, 0.4519, 0.1872],
#          [0.4335, 0.3801, 0.4434, 0.3692, 0.2031],
#          ...,
#          [0.4474, 0.4629, 0.4984, 0.4191, 0.1534],
#          [0.4913, 0.4991, 0.4854, 0.5361, 0.2147],
#          [0.3923, 0.2915, 0.4382, 0.2423, 0.2040]]]), 'targets': tensor([0.4373, 0.5162, 0.4353, 0.3667, 0.3037, 0.4383, 0.4383, 0.4659, 0.3017,
#         0.4484, 0.5583, 0.2623, 0.4383, 0.4383, 0.4658, 0.4617, 0.5831, 0.2653,
#         0.4107, 0.4383, 0.4383, 0.2829, 0.4502, 0.3584, 0.4320, 0.5541, 0.4383,
#         0.4383, 0.4191, 0.5361, 0.2423, 0.4100])}
# {'inputs': tensor([[[0.4740, 0.5098, 0.5000, 0.4519, 0.1872],
#          [0.4335, 0.3801, 0.4434, 0.3692, 0.2031],
#          [0.3575, 0.4012, 0.3403, 0.4422, 0.1956],
#          ...,
#          [0.4913, 0.4991, 0.4854, 0.5361, 0.2147],
#          [0.3923, 0.2915, 0.4382, 0.2423, 0.2040],
#          [0.3113, 0.3945, 0.2551, 0.4100, 0.1910]],
#
#         [[0.4335, 0.3801, 0.4434, 0.3692, 0.2031],
#          [0.3575, 0.4012, 0.3403, 0.4422, 0.1956],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.3923, 0.2915, 0.4382, 0.2423, 0.2040],
#          [0.3113, 0.3945, 0.2551, 0.4100, 0.1910],
#          [0.4351, 0.3554, 0.4741, 0.4390, 0.1913]],
#
#         [[0.3575, 0.4012, 0.3403, 0.4422, 0.1956],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.3113, 0.3945, 0.2551, 0.4100, 0.1910],
#          [0.4351, 0.3554, 0.4741, 0.4390, 0.1913],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         ...,
#
#         [[0.4371, 0.3714, 0.4449, 0.3504, 0.2342],
#          [0.3721, 0.3486, 0.3882, 0.3463, 0.1875],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.5145, 0.4600, 0.4390, 0.5091, 0.2088],
#          [0.3000, 0.3307, 0.3920, 0.2806, 0.1957],
#          [0.4116, 0.4344, 0.3572, 0.4489, 0.3180]],
#
#         [[0.3721, 0.3486, 0.3882, 0.3463, 0.1875],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.3000, 0.3307, 0.3920, 0.2806, 0.1957],
#          [0.4116, 0.4344, 0.3572, 0.4489, 0.3180],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.3310, 0.3980, 0.3374, 0.4196, 0.1595],
#          ...,
#          [0.4116, 0.4344, 0.3572, 0.4489, 0.3180],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]]]), 'targets': tensor([0.4390, 0.4383, 0.4383, 0.5283, 0.3989, 0.4841, 0.5347, 0.5583, 0.4383,
#         0.4383, 0.4383, 0.4078, 0.4020, 0.5277, 0.3590, 0.4383, 0.4383, 0.4535,
#         0.4845, 0.3859, 0.3228, 0.2971, 0.4383, 0.4383, 0.2502, 0.4200, 0.5091,
#         0.2806, 0.4489, 0.4383, 0.4383, 0.4383])}
# {'inputs': tensor([[[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.3310, 0.3980, 0.3374, 0.4196, 0.1595],
#          [0.4893, 0.5099, 0.4566, 0.5148, 0.1813],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.3310, 0.3980, 0.3374, 0.4196, 0.1595],
#          [0.4893, 0.5099, 0.4566, 0.5148, 0.1813],
#          [0.4565, 0.4387, 0.4673, 0.4425, 0.1822],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.5324, 0.5429, 0.5037, 0.5570, 0.0957]],
#
#         [[0.4893, 0.5099, 0.4566, 0.5148, 0.1813],
#          [0.4565, 0.4387, 0.4673, 0.4425, 0.1822],
#          [0.4021, 0.3771, 0.4386, 0.3356, 0.2054],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.5324, 0.5429, 0.5037, 0.5570, 0.0957],
#          [0.4667, 0.4414, 0.4625, 0.4320, 0.1795]],
#
#         ...,
#
#         [[0.3892, 0.3935, 0.3513, 0.4023, 0.2227],
#          [0.4651, 0.4688, 0.4222, 0.5421, 0.1823],
#          [0.5380, 0.5125, 0.5533, 0.5469, 0.2331],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4870, 0.4401, 0.5219, 0.3977, 0.1846],
#          [0.4847, 0.4918, 0.4095, 0.5723, 0.1901]],
#
#         [[0.4651, 0.4688, 0.4222, 0.5421, 0.1823],
#          [0.5380, 0.5125, 0.5533, 0.5469, 0.2331],
#          [0.4981, 0.5337, 0.5027, 0.4982, 0.1380],
#          ...,
#          [0.4870, 0.4401, 0.5219, 0.3977, 0.1846],
#          [0.4847, 0.4918, 0.4095, 0.5723, 0.1901],
#          [0.4805, 0.5153, 0.5320, 0.4669, 0.1994]],
#
#         [[0.5380, 0.5125, 0.5533, 0.5469, 0.2331],
#          [0.4981, 0.5337, 0.5027, 0.4982, 0.1380],
#          [0.4962, 0.4997, 0.5077, 0.4948, 0.3558],
#          ...,
#          [0.4847, 0.4918, 0.4095, 0.5723, 0.1901],
#          [0.4805, 0.5153, 0.5320, 0.4669, 0.1994],
#          [0.4690, 0.4452, 0.4631, 0.4861, 0.1874]]]), 'targets': tensor([0.5570, 0.4320, 0.4845, 0.5865, 0.4383, 0.4383, 0.4238, 0.3406, 0.4348,
#         0.3958, 0.4895, 0.4383, 0.4383, 0.4383, 0.4460, 0.4556, 0.5109, 0.4342,
#         0.4383, 0.4383, 0.3824, 0.3934, 0.4167, 0.4237, 0.5314, 0.4383, 0.4383,
#         0.3977, 0.5723, 0.4669, 0.4861, 0.3930])}
# {'inputs': tensor([[[0.4981, 0.5337, 0.5027, 0.4982, 0.1380],
#          [0.4962, 0.4997, 0.5077, 0.4948, 0.3558],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4805, 0.5153, 0.5320, 0.4669, 0.1994],
#          [0.4690, 0.4452, 0.4631, 0.4861, 0.1874],
#          [0.4542, 0.4521, 0.4910, 0.3930, 0.1812]],
#
#         [[0.4962, 0.4997, 0.5077, 0.4948, 0.3558],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4690, 0.4452, 0.4631, 0.4861, 0.1874],
#          [0.4542, 0.4521, 0.4910, 0.3930, 0.1812],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4560, 0.4755, 0.4989, 0.4362, 0.0874],
#          ...,
#          [0.4542, 0.4521, 0.4910, 0.3930, 0.1812],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         ...,
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4274, 0.4484, 0.4300, 0.4493, 0.1554],
#          [0.4086, 0.3890, 0.4305, 0.3757, 0.2220],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.3837, 0.4157, 0.3690, 0.4373, 0.1799],
#          ...,
#          [0.4086, 0.3890, 0.4305, 0.3757, 0.2220],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.3837, 0.4157, 0.3690, 0.4373, 0.1799],
#          [0.5051, 0.4608, 0.4438, 0.5162, 0.2031],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.3573, 0.3361, 0.3573, 0.3345, 0.2002]]]), 'targets': tensor([0.4383, 0.4383, 0.4447, 0.3823, 0.5652, 0.4971, 0.5072, 0.4383, 0.4383,
#         0.4246, 0.4060, 0.5141, 0.4345, 0.4304, 0.4383, 0.4383, 0.4323, 0.4177,
#         0.5415, 0.4348, 0.5223, 0.4383, 0.4383, 0.4575, 0.4474, 0.4032, 0.4493,
#         0.3757, 0.4383, 0.4383, 0.3345, 0.4274])}
# {'inputs': tensor([[[0.3837, 0.4157, 0.3690, 0.4373, 0.1799],
#          [0.5051, 0.4608, 0.4438, 0.5162, 0.2031],
#          [0.4570, 0.5025, 0.5285, 0.4353, 0.2016],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.3573, 0.3361, 0.3573, 0.3345, 0.2002],
#          [0.3974, 0.4314, 0.3666, 0.4274, 0.1851]],
#
#         [[0.5051, 0.4608, 0.4438, 0.5162, 0.2031],
#          [0.4570, 0.5025, 0.5285, 0.4353, 0.2016],
#          [0.4649, 0.3682, 0.4566, 0.3667, 0.2107],
#          ...,
#          [0.3573, 0.3361, 0.3573, 0.3345, 0.2002],
#          [0.3974, 0.4314, 0.3666, 0.4274, 0.1851],
#          [0.4345, 0.4335, 0.4306, 0.4524, 0.1748]],
#
#         [[0.4570, 0.5025, 0.5285, 0.4353, 0.2016],
#          [0.4649, 0.3682, 0.4566, 0.3667, 0.2107],
#          [0.3016, 0.3090, 0.3266, 0.3037, 0.1913],
#          ...,
#          [0.3974, 0.4314, 0.3666, 0.4274, 0.1851],
#          [0.4345, 0.4335, 0.4306, 0.4524, 0.1748],
#          [0.4896, 0.4708, 0.4697, 0.5066, 0.1893]],
#
#         ...,
#
#         [[0.4913, 0.4991, 0.4854, 0.5361, 0.2147],
#          [0.3923, 0.2915, 0.4382, 0.2423, 0.2040],
#          [0.3113, 0.3945, 0.2551, 0.4100, 0.1910],
#          ...,
#          [0.4626, 0.4401, 0.3995, 0.4715, 0.0587],
#          [0.4079, 0.4244, 0.4702, 0.3836, 0.2098],
#          [0.4771, 0.3900, 0.4335, 0.3552, 0.1917]],
#
#         [[0.3923, 0.2915, 0.4382, 0.2423, 0.2040],
#          [0.3113, 0.3945, 0.2551, 0.4100, 0.1910],
#          [0.4351, 0.3554, 0.4741, 0.4390, 0.1913],
#          ...,
#          [0.4079, 0.4244, 0.4702, 0.3836, 0.2098],
#          [0.4771, 0.3900, 0.4335, 0.3552, 0.1917],
#          [0.2940, 0.3870, 0.3267, 0.3974, 0.2031]],
#
#         [[0.3113, 0.3945, 0.2551, 0.4100, 0.1910],
#          [0.4351, 0.3554, 0.4741, 0.4390, 0.1913],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4771, 0.3900, 0.4335, 0.3552, 0.1917],
#          [0.2940, 0.3870, 0.3267, 0.3974, 0.2031],
#          [0.3567, 0.3063, 0.3675, 0.3547, 0.2407]]]), 'targets': tensor([0.4524, 0.5066, 0.2749, 0.4383, 0.4383, 0.4059, 0.3848, 0.4004, 0.4528,
#         0.3862, 0.4383, 0.4383, 0.4383, 0.4184, 0.5272, 0.4703, 0.5124, 0.4383,
#         0.4383, 0.4896, 0.2285, 0.4547, 0.3834, 0.4034, 0.4383, 0.4383, 0.4715,
#         0.3836, 0.3552, 0.3974, 0.3547, 0.4383])}
# {'inputs': tensor([[[0.4351, 0.3554, 0.4741, 0.4390, 0.1913],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.2940, 0.3870, 0.3267, 0.3974, 0.2031],
#          [0.3567, 0.3063, 0.3675, 0.3547, 0.2407],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4856, 0.5639, 0.4280, 0.5283, 0.1558],
#          ...,
#          [0.3567, 0.3063, 0.3675, 0.3547, 0.2407],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4856, 0.5639, 0.4280, 0.5283, 0.1558],
#          [0.4064, 0.3962, 0.4674, 0.3989, 0.2190],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4233, 0.4347, 0.3805, 0.3881, 0.1779]],
#
#         ...,
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4667, 0.4263, 0.3963, 0.5534, 0.2228],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.5324, 0.5429, 0.5037, 0.5570, 0.0957],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.5065, 0.5636, 0.5774, 0.4959, 0.1742]],
#
#         [[0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.5324, 0.5429, 0.5037, 0.5570, 0.0957],
#          [0.4667, 0.4414, 0.4625, 0.4320, 0.1795],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.5065, 0.5636, 0.5774, 0.4959, 0.1742],
#          [0.5046, 0.5132, 0.4865, 0.5172, 0.1955]]]), 'targets': tensor([0.4383, 0.3881, 0.4280, 0.5337, 0.3358, 0.3652, 0.4383, 0.4383, 0.5638,
#         0.5866, 0.4285, 0.3886, 0.3024, 0.4383, 0.4383, 0.4019, 0.4066, 0.4223,
#         0.5642, 0.3235, 0.4383, 0.4383, 0.5667, 0.4937, 0.4059, 0.3997, 0.5534,
#         0.4383, 0.4383, 0.4959, 0.5172, 0.4024])}
# {'inputs': tensor([[[0.5324, 0.5429, 0.5037, 0.5570, 0.0957],
#          [0.4667, 0.4414, 0.4625, 0.4320, 0.1795],
#          [0.4393, 0.4720, 0.4913, 0.4845, 0.1925],
#          ...,
#          [0.5065, 0.5636, 0.5774, 0.4959, 0.1742],
#          [0.5046, 0.5132, 0.4865, 0.5172, 0.1955],
#          [0.4675, 0.4697, 0.4721, 0.4024, 0.1892]],
#
#         [[0.4667, 0.4414, 0.4625, 0.4320, 0.1795],
#          [0.4393, 0.4720, 0.4913, 0.4845, 0.1925],
#          [0.5800, 0.5396, 0.4987, 0.5865, 0.3388],
#          ...,
#          [0.5046, 0.5132, 0.4865, 0.5172, 0.1955],
#          [0.4675, 0.4697, 0.4721, 0.4024, 0.1892],
#          [0.4056, 0.4125, 0.4493, 0.4088, 0.1837]],
#
#         [[0.4393, 0.4720, 0.4913, 0.4845, 0.1925],
#          [0.5800, 0.5396, 0.4987, 0.5865, 0.3388],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4675, 0.4697, 0.4721, 0.4024, 0.1892],
#          [0.4056, 0.4125, 0.4493, 0.4088, 0.1837],
#          [0.4954, 0.4440, 0.4048, 0.5577, 0.1783]],
#
#         ...,
#
#         [[0.4805, 0.5153, 0.5320, 0.4669, 0.1994],
#          [0.4690, 0.4452, 0.4631, 0.4861, 0.1874],
#          [0.4542, 0.4521, 0.4910, 0.3930, 0.1812],
#          ...,
#          [0.4920, 0.4673, 0.4497, 0.5041, 0.1929],
#          [0.4721, 0.4895, 0.4808, 0.4670, 0.1513],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]],
#
#         [[0.4690, 0.4452, 0.4631, 0.4861, 0.1874],
#          [0.4542, 0.4521, 0.4910, 0.3930, 0.1812],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4721, 0.4895, 0.4808, 0.4670, 0.1513],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4386, 0.4651, 0.4662, 0.4369, 0.0704]],
#
#         [[0.4542, 0.4521, 0.4910, 0.3930, 0.1812],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          ...,
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905],
#          [0.4386, 0.4651, 0.4662, 0.4369, 0.0704],
#          [0.4383, 0.4383, 0.4383, 0.4383, 0.1905]]]), 'targets': tensor([0.4088, 0.5577, 0.4383, 0.4383, 0.4021, 0.4184, 0.3170, 0.3869, 0.5043,
#         0.4383, 0.4383, 0.4849, 0.4654, 0.3375, 0.7072, 0.4831, 0.4383, 0.4383,
#         0.3949, 0.4805, 0.3982, 0.4233, 0.4614, 0.4383, 0.4383, 0.4194, 0.5041,
#         0.4670, 0.4383, 0.4369, 0.4383, 0.4383])}

# %%
def test_predictions(model, test_loader: DataLoader) -> list:
    test_losses = []
    test_preds = []

    model.eval()

    for batch in test_loader:
        
        inputs, labels = batch['inputs'].to(device), batch['targets'].to(device).unsqueeze(1)

        output = model(inputs)

        test_preds.append(output.cpu().detach().numpy())

        test_loss = criterion(output.squeeze(), labels.float())
        test_losses.append(test_loss.item())
            
    print("Test loss: {:.3f}".format(np.mean(test_losses)))

    return test_preds

# %%
test_preds = test_predictions(model=model, test_loader=test_loader)
# Out:
# Test loss: 0.002

# %%
def plot_predictions(test_preds: list, test_loader: DataLoader) -> None:
    """predictions plot 

    Args:
        test_preds (list): predictions 
        test_loader (DataLoader): loader from ther real dataset
    """
    plt.figure(figsize=(15, 10))
    plt.plot(np.concatenate(test_preds, axis=0), label='Prediction')
    plt.plot(test_loader.dataset[:]["targets"], label= 'Real', alpha =0.5)
    plt.legend(loc="best", fontsize=12)
    plt.grid(linestyle="--")

# %%
plot_predictions(test_preds=test_preds, test_loader=test_loader)

# %% [markdown]
# # Data with moving average

# %% [markdown]
# Since the results from the data presented above aren't that good, we can use the moving average that is already known in the stocks industry

# %%
# test the original data 
source_df.tail()
# Out:
#            Date         High          Low         Open        Close  \
# 8364 2022-11-27  4034.020020  4020.760010  4023.340088  4026.120117
# 8365 2022-11-28  4012.270020  3955.770020  4005.360107  3963.939941
# 8366 2022-11-29  3976.770020  3937.649902  3964.189941  3957.629883
# 8367 2022-11-30  4080.110107  3938.580078  3957.179932  4080.110107
# 8368 2022-12-01  4100.509766  4050.870117  4087.139893  4076.570068
#
#             Volume    Adj Close
# 8364  1.706460e+09  4026.120117
# 8365  3.615430e+09  3963.939941
# 8366  3.546040e+09  3957.629883
# 8367  6.579360e+09  4080.110107
# 8368  4.527130e+09  4076.570068

# %%
two_plots(ticker=ticker, df=source_df)

# %%
# Selection of columns
df = source_df[["Date", "High", "Low", "Open", "Close", "Volume"]].copy(deep=True)

# Avoid dividing by 0 
# (The volume isn't a given, for really old data we can have values of 0 for the volume)
df['Volume'].replace(to_replace=0, method='ffill', inplace=True)

# Sort the values based on date
df.sort_values('Date', inplace=True)

# Apply moving average with a window of 10 days to all columns
df[['Open', 'High', 'Low', 'Close', 'Volume']] = df[['Open', 'High', 'Low', 'Close', 'Volume']].rolling(10).mean()

df.tail()
# Out:
#            Date         High          Low         Open        Close  \
# 8364 2022-11-27  4007.716968  3975.775977  3989.153003  3998.242065
# 8365 2022-11-28  4010.954980  3977.754980  3993.050024  3998.102051
# 8366 2022-11-29  4010.642993  3977.921973  3992.830029  3997.331030
# 8367 2022-11-30  4020.665015  3978.181982  3991.909033  4008.808032
# 8368 2022-12-01  4034.515991  3989.934985  4005.000024  4021.471045
#
#             Volume
# 8364  3.152958e+09
# 8365  3.110765e+09
# 8366  3.061633e+09
# 8367  3.315833e+09
# 8368  3.383477e+09

# %% [markdown]
# ## Data normalization
# - Instead of the values we keep the percentage of change
# - Get the separation index values
# - Get the min and max returns
# - Normalize the data with the max and min (0-1 range)

# %%
df, last_10pct, last_20pct = data_normalization(df=df)

# %% [markdown]
# ## Split the data
# - Split into train, the first 80% of the data
# - Split into validation, between the first 80% and 90% of the data
# - Split into test, between 90% and tha 100% of the data

# %%
train_data, val_data, test_data = split_data(df=df, last_10pct=last_10pct, last_20pct=last_20pct)
# Out:
# Training data shape: (6688, 5)
# Validation data shape: (836, 5)
# Test data shape: (835, 5)
#         High       Low      Open     Close    Volume
# 10  0.596522  0.622713  0.576142  0.623704  0.521471
# 11  0.658639  0.711954  0.623659  0.731143  0.514876
# 12  0.721256  0.741750  0.708226  0.726653  0.492547
# 13  0.722927  0.719336  0.703895  0.724238  0.490576
# 14  0.678750  0.705955  0.701640  0.667282  0.452035
# 15  0.667048  0.708140  0.724627  0.652356  0.442942
# 16  0.661444  0.703944  0.709277  0.653465  0.451441
# 17  0.634041  0.627674  0.653534  0.614218  0.503280
# 18  0.623978  0.639794  0.614161  0.636206  0.551402
# 19  0.647646  0.650758  0.642486  0.645566  0.561985

# %% [markdown]
# # Visualization of the data separated

# %%
data_separated_plot(train_data=train_data, val_data=val_data, test_data=test_data)

# %% [markdown]
# # Dataset

# %%
train_data = TickerData(data=train_data, seq_len=seq_len)
val_data = TickerData(data=val_data, seq_len=seq_len)
test_data = TickerData(data=test_data, seq_len=seq_len)

# %% [markdown]
# # Data Loader
# Data loading, creation of the batches to feed the model

# %%
train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=False, drop_last=True)
val_loader = DataLoader(dataset=val_data, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(dataset=test_data, batch_size=batch_size, shuffle=False, drop_last=True)

# %% [markdown]
# # Device
# For some unknown reason it's faster on CPU however I leave commented the possibility of running on mps

# %%
# device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
device = torch.device("cpu")
device
# Out:
# device(type='cpu')

# %%
# model attribution
model = TimeSeriesTransformer().to(device)

# The criterion is the MSE (Mean Squared Error)
criterion = nn.MSELoss()

# ADAM as optimizer
lr = 0.005
optimizer = torch.optim.AdamW(model.parameters(), lr=lr)

scheduler = torch.optim.lr_scheduler.StepLR(optimizer=optimizer, step_size=1.0, gamma=0.98)

# Metrics for evaluation of the model
mean_absolute_error = MeanAbsoluteError()
mean_absolute_percentage_error = MeanAbsolutePercentageError()

# %%
train_mae, train_mape, val_mae, val_mape = fit(epochs=1000, model=model, train_loader=train_loader, val_loader=val_loader)
# Out:
# | epoch   1 |    41/  205 batches | lr 0.005000 | 11.39 ms | loss 2.53497 | ppl    12.62 | mae 0.04376 | mape 0.065309
# | epoch   1 |    82/  205 batches | lr 0.005000 | 10.03 ms | loss 0.02239 | ppl     1.02 | mae 0.13959 | mape 0.2479
# | epoch   1 |   123/  205 batches | lr 0.005000 |  8.83 ms | loss 0.01158 | ppl     1.01 | mae 0.04240 | mape 0.065972
# | epoch   1 |   164/  205 batches | lr 0.005000 |  8.71 ms | loss 0.00778 | ppl     1.01 | mae 0.06904 | mape 0.11037
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch   1 | time:  2.00s | valid loss 0.98731 | valid ppl     2.68 | valid MAE 0.08619 | valid MAPE 0.14585
# ----------------------------------------------------------------------------------------------------------------------
# | epoch   2 |    41/  205 batches | lr 0.004802 |  8.84 ms | loss 0.01492 | ppl     1.02 | mae 0.01933 | mape 0.029268
# | epoch   2 |    82/  205 batches | lr 0.004802 |  8.17 ms | loss 0.00506 | ppl     1.01 | mae 0.07252 | mape 0.1302
# | epoch   2 |   123/  205 batches | lr 0.004802 |  8.47 ms | loss 0.01186 | ppl     1.01 | mae 0.04169 | mape 0.067882
# | epoch   2 |   164/  205 batches | lr 0.004802 |  8.16 ms | loss 0.00396 | ppl     1.00 | mae 0.06763 | mape 0.10635
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch   2 | time:  1.77s | valid loss 0.68702 | valid ppl     1.99 | valid MAE 0.07138 | valid MAPE 0.12546
# ----------------------------------------------------------------------------------------------------------------------
# | epoch   3 |    41/  205 batches | lr 0.004706 |  8.39 ms | loss 0.00869 | ppl     1.01 | mae 0.05411 | mape 0.080825
# | epoch   3 |    82/  205 batches | lr 0.004706 |  8.34 ms | loss 0.00263 | ppl     1.00 | mae 0.07082 | mape 0.12704
# | epoch   3 |   123/  205 batches | lr 0.004706 |  8.69 ms | loss 0.00846 | ppl     1.01 | mae 0.06199 | mape 0.10417
# | epoch   3 |   164/  205 batches | lr 0.004706 |  8.62 ms | loss 0.00352 | ppl     1.00 | mae 0.07034 | mape 0.11361
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch   3 | time:  1.82s | valid loss 0.44162 | valid ppl     1.56 | valid MAE 0.05008 | valid MAPE 0.09903
# ----------------------------------------------------------------------------------------------------------------------
# | epoch   4 |    41/  205 batches | lr 0.004612 |  8.43 ms | loss 0.00731 | ppl     1.01 | mae 0.08821 | mape 0.13195
# | epoch   4 |    82/  205 batches | lr 0.004612 |  8.23 ms | loss 0.00176 | ppl     1.00 | mae 0.05987 | mape 0.10554
# | epoch   4 |   123/  205 batches | lr 0.004612 |  8.15 ms | loss 0.00800 | ppl     1.01 | mae 0.04854 | mape 0.080691
# | epoch   4 |   164/  205 batches | lr 0.004612 |  8.20 ms | loss 0.00325 | ppl     1.00 | mae 0.06757 | mape 0.10605
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch   4 | time:  1.74s | valid loss 0.44132 | valid ppl     1.55 | valid MAE 0.05107 | valid MAPE 0.09980
# ----------------------------------------------------------------------------------------------------------------------
# | epoch   5 |    41/  205 batches | lr 0.004520 |  8.59 ms | loss 0.00679 | ppl     1.01 | mae 0.07937 | mape 0.1187
# | epoch   5 |    82/  205 batches | lr 0.004520 |  8.08 ms | loss 0.00163 | ppl     1.00 | mae 0.05914 | mape 0.10403
# | epoch   5 |   123/  205 batches | lr 0.004520 |  8.14 ms | loss 0.00802 | ppl     1.01 | mae 0.04999 | mape 0.083234
# | epoch   5 |   164/  205 batches | lr 0.004520 |  8.36 ms | loss 0.00308 | ppl     1.00 | mae 0.06979 | mape 0.11223
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch   5 | time:  1.74s | valid loss 0.45103 | valid ppl     1.57 | valid MAE 0.05308 | valid MAPE 0.10192
# ----------------------------------------------------------------------------------------------------------------------
# | epoch   6 |    41/  205 batches | lr 0.004429 |  8.35 ms | loss 0.00657 | ppl     1.01 | mae 0.07467 | mape 0.11165
# | epoch   6 |    82/  205 batches | lr 0.004429 |  8.23 ms | loss 0.00162 | ppl     1.00 | mae 0.05949 | mape 0.10476
# | epoch   6 |   123/  205 batches | lr 0.004429 |  8.36 ms | loss 0.00809 | ppl     1.01 | mae 0.05448 | mape 0.091074
# | epoch   6 |   164/  205 batches | lr 0.004429 |  8.22 ms | loss 0.00302 | ppl     1.00 | mae 0.06781 | mape 0.10705
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch   6 | time:  1.75s | valid loss 0.45274 | valid ppl     1.57 | valid MAE 0.05333 | valid MAPE 0.10219
# ----------------------------------------------------------------------------------------------------------------------
# | epoch   7 |    41/  205 batches | lr 0.004341 |  8.42 ms | loss 0.00641 | ppl     1.01 | mae 0.06714 | mape 0.10036
# | epoch   7 |    82/  205 batches | lr 0.004341 |  8.15 ms | loss 0.00156 | ppl     1.00 | mae 0.05911 | mape 0.10395
# | epoch   7 |   123/  205 batches | lr 0.004341 |  8.35 ms | loss 0.00810 | ppl     1.01 | mae 0.06113 | mape 0.10269
# | epoch   7 |   164/  205 batches | lr 0.004341 |  8.54 ms | loss 0.00321 | ppl     1.00 | mae 0.06826 | mape 0.10837
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch   7 | time:  1.76s | valid loss 0.45600 | valid ppl     1.58 | valid MAE 0.05377 | valid MAPE 0.10269
# ----------------------------------------------------------------------------------------------------------------------
# | epoch   8 |    41/  205 batches | lr 0.004254 |  8.40 ms | loss 0.00632 | ppl     1.01 | mae 0.05645 | mape 0.084326
# | epoch   8 |    82/  205 batches | lr 0.004254 |  8.24 ms | loss 0.00157 | ppl     1.00 | mae 0.05942 | mape 0.10462
# | epoch   8 |   123/  205 batches | lr 0.004254 |  8.33 ms | loss 0.00816 | ppl     1.01 | mae 0.05952 | mape 0.099879
# | epoch   8 |   164/  205 batches | lr 0.004254 |  8.25 ms | loss 0.00307 | ppl     1.00 | mae 0.06767 | mape 0.10647
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch   8 | time:  1.75s | valid loss 0.47184 | valid ppl     1.60 | valid MAE 0.05565 | valid MAPE 0.10492
# ----------------------------------------------------------------------------------------------------------------------
# | epoch   9 |    41/  205 batches | lr 0.004169 |  8.33 ms | loss 0.00622 | ppl     1.01 | mae 0.04648 | mape 0.06939
# | epoch   9 |    82/  205 batches | lr 0.004169 |  8.27 ms | loss 0.00169 | ppl     1.00 | mae 0.06250 | mape 0.1109
# | epoch   9 |   123/  205 batches | lr 0.004169 |  8.25 ms | loss 0.00845 | ppl     1.01 | mae 0.07459 | mape 0.12543
# | epoch   9 |   164/  205 batches | lr 0.004169 |  8.19 ms | loss 0.00353 | ppl     1.00 | mae 0.06792 | mape 0.10739
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch   9 | time:  1.74s | valid loss 0.46206 | valid ppl     1.59 | valid MAE 0.05453 | valid MAPE 0.10358
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  10 |    41/  205 batches | lr 0.004085 |  8.84 ms | loss 0.00600 | ppl     1.01 | mae 0.03867 | mape 0.057673
# | epoch  10 |    82/  205 batches | lr 0.004085 |  8.44 ms | loss 0.00170 | ppl     1.00 | mae 0.06553 | mape 0.11705
# | epoch  10 |   123/  205 batches | lr 0.004085 |  8.61 ms | loss 0.00846 | ppl     1.01 | mae 0.07787 | mape 0.13087
# | epoch  10 |   164/  205 batches | lr 0.004085 |  8.59 ms | loss 0.00410 | ppl     1.00 | mae 0.06963 | mape 0.11183
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  10 | time:  1.80s | valid loss 0.45172 | valid ppl     1.57 | valid MAE 0.05318 | valid MAPE 0.10203
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  11 |    41/  205 batches | lr 0.004004 |  8.72 ms | loss 0.00595 | ppl     1.01 | mae 0.03302 | mape 0.049203
# | epoch  11 |    82/  205 batches | lr 0.004004 |  8.41 ms | loss 0.00170 | ppl     1.00 | mae 0.06795 | mape 0.12167
# | epoch  11 |   123/  205 batches | lr 0.004004 |  8.14 ms | loss 0.00837 | ppl     1.01 | mae 0.07306 | mape 0.12287
# | epoch  11 |   164/  205 batches | lr 0.004004 |  8.18 ms | loss 0.00401 | ppl     1.00 | mae 0.06957 | mape 0.11169
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  11 | time:  1.75s | valid loss 0.44363 | valid ppl     1.56 | valid MAE 0.05174 | valid MAPE 0.10046
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  12 |    41/  205 batches | lr 0.003924 |  8.35 ms | loss 0.00568 | ppl     1.01 | mae 0.01779 | mape 0.026382
# | epoch  12 |    82/  205 batches | lr 0.003924 |  8.36 ms | loss 0.00168 | ppl     1.00 | mae 0.06643 | mape 0.1188
# | epoch  12 |   123/  205 batches | lr 0.003924 |  8.52 ms | loss 0.00820 | ppl     1.01 | mae 0.06894 | mape 0.11597
# | epoch  12 |   164/  205 batches | lr 0.003924 |  8.34 ms | loss 0.00407 | ppl     1.00 | mae 0.07067 | mape 0.11442
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  12 | time:  1.78s | valid loss 0.44195 | valid ppl     1.56 | valid MAE 0.05129 | valid MAPE 0.10002
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  13 |    41/  205 batches | lr 0.003845 |  8.55 ms | loss 0.00562 | ppl     1.01 | mae 0.01361 | mape 0.020179
# | epoch  13 |    82/  205 batches | lr 0.003845 |  8.43 ms | loss 0.00164 | ppl     1.00 | mae 0.06420 | mape 0.11435
# | epoch  13 |   123/  205 batches | lr 0.003845 |  9.11 ms | loss 0.00813 | ppl     1.01 | mae 0.05970 | mape 0.10019
# | epoch  13 |   164/  205 batches | lr 0.003845 |  8.41 ms | loss 0.00386 | ppl     1.00 | mae 0.06774 | mape 0.10681
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  13 | time:  1.82s | valid loss 0.45635 | valid ppl     1.58 | valid MAE 0.05382 | valid MAPE 0.10275
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  14 |    41/  205 batches | lr 0.003768 | 11.35 ms | loss 0.00565 | ppl     1.01 | mae 0.01612 | mape 0.023907
# | epoch  14 |    82/  205 batches | lr 0.003768 | 11.67 ms | loss 0.00160 | ppl     1.00 | mae 0.06409 | mape 0.11414
# | epoch  14 |   123/  205 batches | lr 0.003768 |  8.83 ms | loss 0.00813 | ppl     1.01 | mae 0.05589 | mape 0.093548
# | epoch  14 |   164/  205 batches | lr 0.003768 |  8.76 ms | loss 0.00382 | ppl     1.00 | mae 0.07407 | mape 0.12251
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  14 | time:  2.22s | valid loss 0.46112 | valid ppl     1.59 | valid MAE 0.05442 | valid MAPE 0.10344
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  15 |    41/  205 batches | lr 0.003693 | 15.61 ms | loss 0.00555 | ppl     1.01 | mae 0.01119 | mape 0.016642
# | epoch  15 |    82/  205 batches | lr 0.003693 | 12.33 ms | loss 0.00159 | ppl     1.00 | mae 0.06339 | mape 0.11271
# | epoch  15 |   123/  205 batches | lr 0.003693 | 10.96 ms | loss 0.00813 | ppl     1.01 | mae 0.05205 | mape 0.08684
# | epoch  15 |   164/  205 batches | lr 0.003693 |  9.19 ms | loss 0.00371 | ppl     1.00 | mae 0.07040 | mape 0.11376
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  15 | time:  2.40s | valid loss 0.44070 | valid ppl     1.55 | valid MAE 0.05047 | valid MAPE 0.09929
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  16 |    41/  205 batches | lr 0.003619 | 10.04 ms | loss 0.00542 | ppl     1.01 | mae 0.00975 | mape 0.014657
# | epoch  16 |    82/  205 batches | lr 0.003619 | 10.23 ms | loss 0.00161 | ppl     1.00 | mae 0.06419 | mape 0.11433
# | epoch  16 |   123/  205 batches | lr 0.003619 |  9.13 ms | loss 0.00810 | ppl     1.01 | mae 0.04830 | mape 0.080253
# | epoch  16 |   164/  205 batches | lr 0.003619 |  9.72 ms | loss 0.00370 | ppl     1.00 | mae 0.06971 | mape 0.11203
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  16 | time:  2.01s | valid loss 0.44089 | valid ppl     1.55 | valid MAE 0.05029 | valid MAPE 0.09916
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  17 |    41/  205 batches | lr 0.003547 |  9.38 ms | loss 0.00539 | ppl     1.01 | mae 0.00981 | mape 0.014796
# | epoch  17 |    82/  205 batches | lr 0.003547 |  8.55 ms | loss 0.00160 | ppl     1.00 | mae 0.06466 | mape 0.11529
# | epoch  17 |   123/  205 batches | lr 0.003547 |  8.72 ms | loss 0.00803 | ppl     1.01 | mae 0.05264 | mape 0.087863
# | epoch  17 |   164/  205 batches | lr 0.003547 |  8.68 ms | loss 0.00348 | ppl     1.00 | mae 0.07119 | mape 0.11573
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  17 | time:  1.87s | valid loss 0.44130 | valid ppl     1.55 | valid MAE 0.05012 | valid MAPE 0.09905
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  18 |    41/  205 batches | lr 0.003476 |  9.01 ms | loss 0.00533 | ppl     1.01 | mae 0.00986 | mape 0.014866
# | epoch  18 |    82/  205 batches | lr 0.003476 |  8.90 ms | loss 0.00160 | ppl     1.00 | mae 0.06513 | mape 0.11625
# | epoch  18 |   123/  205 batches | lr 0.003476 | 10.90 ms | loss 0.00803 | ppl     1.01 | mae 0.06133 | mape 0.10302
# | epoch  18 |   164/  205 batches | lr 0.003476 | 10.00 ms | loss 0.00349 | ppl     1.00 | mae 0.07159 | mape 0.11675
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  18 | time:  2.00s | valid loss 0.44119 | valid ppl     1.55 | valid MAE 0.05011 | valid MAPE 0.09903
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  19 |    41/  205 batches | lr 0.003406 |  8.84 ms | loss 0.00530 | ppl     1.01 | mae 0.00987 | mape 0.014883
# | epoch  19 |    82/  205 batches | lr 0.003406 |  8.62 ms | loss 0.00159 | ppl     1.00 | mae 0.06421 | mape 0.11439
# | epoch  19 |   123/  205 batches | lr 0.003406 |  8.51 ms | loss 0.00812 | ppl     1.01 | mae 0.07437 | mape 0.12506
# | epoch  19 |   164/  205 batches | lr 0.003406 |  8.94 ms | loss 0.00361 | ppl     1.00 | mae 0.06966 | mape 0.11197
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  19 | time:  1.84s | valid loss 0.44313 | valid ppl     1.56 | valid MAE 0.05173 | valid MAPE 0.10043
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  20 |    41/  205 batches | lr 0.003338 |  8.66 ms | loss 0.00557 | ppl     1.01 | mae 0.01860 | mape 0.027603
# | epoch  20 |    82/  205 batches | lr 0.003338 |  8.55 ms | loss 0.00151 | ppl     1.00 | mae 0.06444 | mape 0.11485
# | epoch  20 |   123/  205 batches | lr 0.003338 |  8.65 ms | loss 0.00803 | ppl     1.01 | mae 0.04586 | mape 0.075741
# | epoch  20 |   164/  205 batches | lr 0.003338 |  8.49 ms | loss 0.00344 | ppl     1.00 | mae 0.06793 | mape 0.1075
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  20 | time:  1.81s | valid loss 0.44005 | valid ppl     1.55 | valid MAE 0.05045 | valid MAPE 0.09925
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  21 |    41/  205 batches | lr 0.003271 |  8.98 ms | loss 0.00522 | ppl     1.01 | mae 0.00971 | mape 0.014588
# | epoch  21 |    82/  205 batches | lr 0.003271 |  8.56 ms | loss 0.00159 | ppl     1.00 | mae 0.06679 | mape 0.11949
# | epoch  21 |   123/  205 batches | lr 0.003271 |  8.62 ms | loss 0.00794 | ppl     1.01 | mae 0.06589 | mape 0.11086
# | epoch  21 |   164/  205 batches | lr 0.003271 |  8.60 ms | loss 0.00362 | ppl     1.00 | mae 0.06833 | mape 0.10884
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  21 | time:  1.83s | valid loss 0.45155 | valid ppl     1.57 | valid MAE 0.05343 | valid MAPE 0.10226
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  22 |    41/  205 batches | lr 0.003206 |  8.90 ms | loss 0.00534 | ppl     1.01 | mae 0.01288 | mape 0.019106
# | epoch  22 |    82/  205 batches | lr 0.003206 |  8.41 ms | loss 0.00150 | ppl     1.00 | mae 0.06646 | mape 0.11889
# | epoch  22 |   123/  205 batches | lr 0.003206 |  8.27 ms | loss 0.00794 | ppl     1.01 | mae 0.04710 | mape 0.078079
# | epoch  22 |   164/  205 batches | lr 0.003206 |  8.53 ms | loss 0.00322 | ppl     1.00 | mae 0.06764 | mape 0.1071
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  22 | time:  1.79s | valid loss 0.43484 | valid ppl     1.54 | valid MAE 0.05083 | valid MAPE 0.09938
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  23 |    41/  205 batches | lr 0.003142 |  8.67 ms | loss 0.00516 | ppl     1.01 | mae 0.01238 | mape 0.018376
# | epoch  23 |    82/  205 batches | lr 0.003142 |  8.37 ms | loss 0.00147 | ppl     1.00 | mae 0.06698 | mape 0.11986
# | epoch  23 |   123/  205 batches | lr 0.003142 |  8.41 ms | loss 0.00792 | ppl     1.01 | mae 0.04500 | mape 0.074256
# | epoch  23 |   164/  205 batches | lr 0.003142 |  8.24 ms | loss 0.00302 | ppl     1.00 | mae 0.06776 | mape 0.10798
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  23 | time:  1.78s | valid loss 0.42367 | valid ppl     1.53 | valid MAE 0.04966 | valid MAPE 0.09790
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  24 |    41/  205 batches | lr 0.003079 |  8.73 ms | loss 0.00526 | ppl     1.01 | mae 0.03720 | mape 0.055476
# | epoch  24 |    82/  205 batches | lr 0.003079 |  8.37 ms | loss 0.00156 | ppl     1.00 | mae 0.05813 | mape 0.10198
# | epoch  24 |   123/  205 batches | lr 0.003079 |  8.42 ms | loss 0.00788 | ppl     1.01 | mae 0.06776 | mape 0.114
# | epoch  24 |   164/  205 batches | lr 0.003079 |  8.47 ms | loss 0.00342 | ppl     1.00 | mae 0.06830 | mape 0.10886
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  24 | time:  1.79s | valid loss 0.45174 | valid ppl     1.57 | valid MAE 0.05361 | valid MAPE 0.10237
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  25 |    41/  205 batches | lr 0.003017 |  8.86 ms | loss 0.00536 | ppl     1.01 | mae 0.01379 | mape 0.020445
# | epoch  25 |    82/  205 batches | lr 0.003017 |  8.47 ms | loss 0.00147 | ppl     1.00 | mae 0.06642 | mape 0.11888
# | epoch  25 |   123/  205 batches | lr 0.003017 |  8.21 ms | loss 0.00776 | ppl     1.01 | mae 0.04910 | mape 0.081996
# | epoch  25 |   164/  205 batches | lr 0.003017 |  8.44 ms | loss 0.00313 | ppl     1.00 | mae 0.06422 | mape 0.10149
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  25 | time:  1.79s | valid loss 0.43775 | valid ppl     1.55 | valid MAE 0.05163 | valid MAPE 0.10009
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  26 |    41/  205 batches | lr 0.002957 |  8.43 ms | loss 0.00504 | ppl     1.01 | mae 0.01007 | mape 0.015009
# | epoch  26 |    82/  205 batches | lr 0.002957 |  8.26 ms | loss 0.00148 | ppl     1.00 | mae 0.06585 | mape 0.11784
# | epoch  26 |   123/  205 batches | lr 0.002957 |  8.72 ms | loss 0.00760 | ppl     1.01 | mae 0.04498 | mape 0.074252
# | epoch  26 |   164/  205 batches | lr 0.002957 |  8.18 ms | loss 0.00292 | ppl     1.00 | mae 0.06572 | mape 0.10504
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  26 | time:  1.76s | valid loss 0.40302 | valid ppl     1.50 | valid MAE 0.04977 | valid MAPE 0.09633
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  27 |    41/  205 batches | lr 0.002898 |  8.90 ms | loss 0.00522 | ppl     1.01 | mae 0.02536 | mape 0.037717
# | epoch  27 |    82/  205 batches | lr 0.002898 |  8.47 ms | loss 0.00144 | ppl     1.00 | mae 0.06452 | mape 0.11525
# | epoch  27 |   123/  205 batches | lr 0.002898 |  8.45 ms | loss 0.00763 | ppl     1.01 | mae 0.05409 | mape 0.090486
# | epoch  27 |   164/  205 batches | lr 0.002898 |  9.41 ms | loss 0.00305 | ppl     1.00 | mae 0.06617 | mape 0.10542
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  27 | time:  1.85s | valid loss 0.40154 | valid ppl     1.49 | valid MAE 0.04790 | valid MAPE 0.09531
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  28 |    41/  205 batches | lr 0.002840 |  8.75 ms | loss 0.00473 | ppl     1.00 | mae 0.03571 | mape 0.053254
# | epoch  28 |    82/  205 batches | lr 0.002840 |  8.53 ms | loss 0.00121 | ppl     1.00 | mae 0.05757 | mape 0.10214
# | epoch  28 |   123/  205 batches | lr 0.002840 |  8.45 ms | loss 0.00653 | ppl     1.01 | mae 0.05133 | mape 0.08633
# | epoch  28 |   164/  205 batches | lr 0.002840 |  8.50 ms | loss 0.00302 | ppl     1.00 | mae 0.06675 | mape 0.10646
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  28 | time:  1.81s | valid loss 0.40652 | valid ppl     1.50 | valid MAE 0.04884 | valid MAPE 0.09570
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  29 |    41/  205 batches | lr 0.002783 |  8.63 ms | loss 0.00473 | ppl     1.00 | mae 0.04116 | mape 0.061418
# | epoch  29 |    82/  205 batches | lr 0.002783 |  8.51 ms | loss 0.00128 | ppl     1.00 | mae 0.05982 | mape 0.10639
# | epoch  29 |   123/  205 batches | lr 0.002783 |  8.46 ms | loss 0.00687 | ppl     1.01 | mae 0.05301 | mape 0.089485
# | epoch  29 |   164/  205 batches | lr 0.002783 |  8.65 ms | loss 0.00298 | ppl     1.00 | mae 0.05889 | mape 0.094044
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  29 | time:  1.81s | valid loss 0.39002 | valid ppl     1.48 | valid MAE 0.04872 | valid MAPE 0.09552
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  30 |    41/  205 batches | lr 0.002727 |  8.69 ms | loss 0.00441 | ppl     1.00 | mae 0.03088 | mape 0.04613
# | epoch  30 |    82/  205 batches | lr 0.002727 |  8.50 ms | loss 0.00124 | ppl     1.00 | mae 0.06127 | mape 0.10934
# | epoch  30 |   123/  205 batches | lr 0.002727 |  8.53 ms | loss 0.00643 | ppl     1.01 | mae 0.03857 | mape 0.063661
# | epoch  30 |   164/  205 batches | lr 0.002727 |  8.48 ms | loss 0.00259 | ppl     1.00 | mae 0.06070 | mape 0.097668
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  30 | time:  1.80s | valid loss 0.36152 | valid ppl     1.44 | valid MAE 0.04817 | valid MAPE 0.09405
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  31 |    41/  205 batches | lr 0.002673 |  9.20 ms | loss 0.00391 | ppl     1.00 | mae 0.02522 | mape 0.037619
# | epoch  31 |    82/  205 batches | lr 0.002673 |  8.66 ms | loss 0.00127 | ppl     1.00 | mae 0.06130 | mape 0.10936
# | epoch  31 |   123/  205 batches | lr 0.002673 |  8.34 ms | loss 0.00642 | ppl     1.01 | mae 0.05859 | mape 0.098629
# | epoch  31 |   164/  205 batches | lr 0.002673 |  8.50 ms | loss 0.00287 | ppl     1.00 | mae 0.05919 | mape 0.096154
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  31 | time:  1.82s | valid loss 0.40898 | valid ppl     1.51 | valid MAE 0.04846 | valid MAPE 0.09588
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  32 |    41/  205 batches | lr 0.002619 |  8.57 ms | loss 0.00461 | ppl     1.00 | mae 0.01645 | mape 0.024526
# | epoch  32 |    82/  205 batches | lr 0.002619 |  8.53 ms | loss 0.00128 | ppl     1.00 | mae 0.06242 | mape 0.11119
# | epoch  32 |   123/  205 batches | lr 0.002619 |  8.29 ms | loss 0.00633 | ppl     1.01 | mae 0.05718 | mape 0.096276
# | epoch  32 |   164/  205 batches | lr 0.002619 |  8.47 ms | loss 0.00298 | ppl     1.00 | mae 0.06445 | mape 0.10433
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  32 | time:  1.79s | valid loss 0.34784 | valid ppl     1.42 | valid MAE 0.04802 | valid MAPE 0.09180
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  33 |    41/  205 batches | lr 0.002567 |  8.70 ms | loss 0.00428 | ppl     1.00 | mae 0.02905 | mape 0.043257
# | epoch  33 |    82/  205 batches | lr 0.002567 |  8.37 ms | loss 0.00128 | ppl     1.00 | mae 0.05977 | mape 0.10622
# | epoch  33 |   123/  205 batches | lr 0.002567 |  8.37 ms | loss 0.00666 | ppl     1.01 | mae 0.05497 | mape 0.092444
# | epoch  33 |   164/  205 batches | lr 0.002567 |  8.25 ms | loss 0.00299 | ppl     1.00 | mae 0.05724 | mape 0.092238
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  33 | time:  1.78s | valid loss 0.33778 | valid ppl     1.40 | valid MAE 0.04768 | valid MAPE 0.09249
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  34 |    41/  205 batches | lr 0.002516 |  8.77 ms | loss 0.00383 | ppl     1.00 | mae 0.02159 | mape 0.03224
# | epoch  34 |    82/  205 batches | lr 0.002516 |  8.51 ms | loss 0.00130 | ppl     1.00 | mae 0.05779 | mape 0.10257
# | epoch  34 |   123/  205 batches | lr 0.002516 |  8.52 ms | loss 0.00597 | ppl     1.01 | mae 0.03890 | mape 0.065101
# | epoch  34 |   164/  205 batches | lr 0.002516 |  8.48 ms | loss 0.00266 | ppl     1.00 | mae 0.05693 | mape 0.091686
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  34 | time:  1.81s | valid loss 0.35149 | valid ppl     1.42 | valid MAE 0.04556 | valid MAPE 0.09067
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  35 |    41/  205 batches | lr 0.002465 |  8.48 ms | loss 0.00364 | ppl     1.00 | mae 0.03125 | mape 0.046788
# | epoch  35 |    82/  205 batches | lr 0.002465 |  8.53 ms | loss 0.00120 | ppl     1.00 | mae 0.05775 | mape 0.10236
# | epoch  35 |   123/  205 batches | lr 0.002465 |  8.40 ms | loss 0.00577 | ppl     1.01 | mae 0.04672 | mape 0.078165
# | epoch  35 |   164/  205 batches | lr 0.002465 |  8.79 ms | loss 0.00282 | ppl     1.00 | mae 0.06352 | mape 0.10233
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  35 | time:  1.81s | valid loss 0.38295 | valid ppl     1.47 | valid MAE 0.04704 | valid MAPE 0.09313
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  36 |    41/  205 batches | lr 0.002416 |  8.57 ms | loss 0.00386 | ppl     1.00 | mae 0.04280 | mape 0.063968
# | epoch  36 |    82/  205 batches | lr 0.002416 |  8.36 ms | loss 0.00109 | ppl     1.00 | mae 0.05479 | mape 0.096713
# | epoch  36 |   123/  205 batches | lr 0.002416 |  8.64 ms | loss 0.00555 | ppl     1.01 | mae 0.05654 | mape 0.095195
# | epoch  36 |   164/  205 batches | lr 0.002416 |  8.53 ms | loss 0.00290 | ppl     1.00 | mae 0.06292 | mape 0.10005
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  36 | time:  1.80s | valid loss 0.34454 | valid ppl     1.41 | valid MAE 0.04583 | valid MAPE 0.08922
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  37 |    41/  205 batches | lr 0.002368 |  8.65 ms | loss 0.00374 | ppl     1.00 | mae 0.02395 | mape 0.0359
# | epoch  37 |    82/  205 batches | lr 0.002368 |  8.43 ms | loss 0.00125 | ppl     1.00 | mae 0.05560 | mape 0.099068
# | epoch  37 |   123/  205 batches | lr 0.002368 |  8.46 ms | loss 0.00571 | ppl     1.01 | mae 0.03527 | mape 0.058077
# | epoch  37 |   164/  205 batches | lr 0.002368 |  8.39 ms | loss 0.00247 | ppl     1.00 | mae 0.05365 | mape 0.086036
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  37 | time:  1.78s | valid loss 0.33127 | valid ppl     1.39 | valid MAE 0.04309 | valid MAPE 0.08368
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  38 |    41/  205 batches | lr 0.002320 |  8.48 ms | loss 0.00362 | ppl     1.00 | mae 0.05607 | mape 0.08361
# | epoch  38 |    82/  205 batches | lr 0.002320 |  8.31 ms | loss 0.00131 | ppl     1.00 | mae 0.05340 | mape 0.094052
# | epoch  38 |   123/  205 batches | lr 0.002320 |  8.21 ms | loss 0.00548 | ppl     1.01 | mae 0.05165 | mape 0.086701
# | epoch  38 |   164/  205 batches | lr 0.002320 |  8.45 ms | loss 0.00283 | ppl     1.00 | mae 0.06346 | mape 0.10038
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  38 | time:  1.78s | valid loss 0.37031 | valid ppl     1.45 | valid MAE 0.04634 | valid MAPE 0.09066
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  39 |    41/  205 batches | lr 0.002274 |  8.50 ms | loss 0.00429 | ppl     1.00 | mae 0.04930 | mape 0.073624
# | epoch  39 |    82/  205 batches | lr 0.002274 |  8.24 ms | loss 0.00119 | ppl     1.00 | mae 0.05754 | mape 0.10249
# | epoch  39 |   123/  205 batches | lr 0.002274 |  8.40 ms | loss 0.00612 | ppl     1.01 | mae 0.04180 | mape 0.070397
# | epoch  39 |   164/  205 batches | lr 0.002274 |  8.41 ms | loss 0.00268 | ppl     1.00 | mae 0.05345 | mape 0.082889
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  39 | time:  1.76s | valid loss 0.30934 | valid ppl     1.36 | valid MAE 0.04220 | valid MAPE 0.08306
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  40 |    41/  205 batches | lr 0.002229 |  8.70 ms | loss 0.00346 | ppl     1.00 | mae 0.03704 | mape 0.055427
# | epoch  40 |    82/  205 batches | lr 0.002229 |  8.32 ms | loss 0.00108 | ppl     1.00 | mae 0.05275 | mape 0.093588
# | epoch  40 |   123/  205 batches | lr 0.002229 |  8.18 ms | loss 0.00517 | ppl     1.01 | mae 0.04220 | mape 0.071191
# | epoch  40 |   164/  205 batches | lr 0.002229 |  8.52 ms | loss 0.00272 | ppl     1.00 | mae 0.05846 | mape 0.090904
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  40 | time:  1.80s | valid loss 0.26027 | valid ppl     1.30 | valid MAE 0.04084 | valid MAPE 0.07827
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  41 |    41/  205 batches | lr 0.002184 |  8.90 ms | loss 0.00337 | ppl     1.00 | mae 0.05240 | mape 0.078276
# | epoch  41 |    82/  205 batches | lr 0.002184 |  8.58 ms | loss 0.00099 | ppl     1.00 | mae 0.04445 | mape 0.076771
# | epoch  41 |   123/  205 batches | lr 0.002184 |  8.25 ms | loss 0.00477 | ppl     1.00 | mae 0.03961 | mape 0.066728
# | epoch  41 |   164/  205 batches | lr 0.002184 |  8.30 ms | loss 0.00249 | ppl     1.00 | mae 0.06010 | mape 0.094374
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  41 | time:  1.80s | valid loss 0.26914 | valid ppl     1.31 | valid MAE 0.03830 | valid MAPE 0.07243
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  42 |    41/  205 batches | lr 0.002140 |  8.72 ms | loss 0.00316 | ppl     1.00 | mae 0.02420 | mape 0.036097
# | epoch  42 |    82/  205 batches | lr 0.002140 |  8.50 ms | loss 0.00104 | ppl     1.00 | mae 0.03819 | mape 0.065441
# | epoch  42 |   123/  205 batches | lr 0.002140 |  8.46 ms | loss 0.00468 | ppl     1.00 | mae 0.04769 | mape 0.080604
# | epoch  42 |   164/  205 batches | lr 0.002140 |  8.26 ms | loss 0.00273 | ppl     1.00 | mae 0.05989 | mape 0.096064
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  42 | time:  1.79s | valid loss 0.23555 | valid ppl     1.27 | valid MAE 0.03747 | valid MAPE 0.07133
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  43 |    41/  205 batches | lr 0.002097 |  8.75 ms | loss 0.00271 | ppl     1.00 | mae 0.02571 | mape 0.038381
# | epoch  43 |    82/  205 batches | lr 0.002097 |  8.54 ms | loss 0.00086 | ppl     1.00 | mae 0.03719 | mape 0.060026
# | epoch  43 |   123/  205 batches | lr 0.002097 |  8.38 ms | loss 0.00433 | ppl     1.00 | mae 0.04841 | mape 0.081556
# | epoch  43 |   164/  205 batches | lr 0.002097 |  8.63 ms | loss 0.00272 | ppl     1.00 | mae 0.05788 | mape 0.092123
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  43 | time:  1.79s | valid loss 0.27243 | valid ppl     1.31 | valid MAE 0.04012 | valid MAPE 0.07753
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  44 |    41/  205 batches | lr 0.002055 |  8.70 ms | loss 0.00296 | ppl     1.00 | mae 0.03184 | mape 0.047546
# | epoch  44 |    82/  205 batches | lr 0.002055 |  8.57 ms | loss 0.00094 | ppl     1.00 | mae 0.05199 | mape 0.091989
# | epoch  44 |   123/  205 batches | lr 0.002055 |  8.29 ms | loss 0.00442 | ppl     1.00 | mae 0.03607 | mape 0.059446
# | epoch  44 |   164/  205 batches | lr 0.002055 |  8.18 ms | loss 0.00254 | ppl     1.00 | mae 0.05571 | mape 0.088745
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  44 | time:  1.79s | valid loss 0.26321 | valid ppl     1.30 | valid MAE 0.03951 | valid MAPE 0.07570
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  45 |    41/  205 batches | lr 0.002014 |  8.62 ms | loss 0.00286 | ppl     1.00 | mae 0.03079 | mape 0.045987
# | epoch  45 |    82/  205 batches | lr 0.002014 |  8.40 ms | loss 0.00101 | ppl     1.00 | mae 0.05429 | mape 0.096748
# | epoch  45 |   123/  205 batches | lr 0.002014 |  8.44 ms | loss 0.00437 | ppl     1.00 | mae 0.03489 | mape 0.057139
# | epoch  45 |   164/  205 batches | lr 0.002014 |  8.38 ms | loss 0.00216 | ppl     1.00 | mae 0.04408 | mape 0.068015
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  45 | time:  1.80s | valid loss 0.22701 | valid ppl     1.25 | valid MAE 0.03825 | valid MAPE 0.07343
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  46 |    41/  205 batches | lr 0.001974 |  8.80 ms | loss 0.00287 | ppl     1.00 | mae 0.02578 | mape 0.038509
# | epoch  46 |    82/  205 batches | lr 0.001974 |  8.42 ms | loss 0.00097 | ppl     1.00 | mae 0.05028 | mape 0.089135
# | epoch  46 |   123/  205 batches | lr 0.001974 |  8.44 ms | loss 0.00453 | ppl     1.00 | mae 0.03448 | mape 0.056911
# | epoch  46 |   164/  205 batches | lr 0.001974 |  8.50 ms | loss 0.00209 | ppl     1.00 | mae 0.04729 | mape 0.073598
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  46 | time:  1.79s | valid loss 0.24531 | valid ppl     1.28 | valid MAE 0.03754 | valid MAPE 0.07126
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  47 |    41/  205 batches | lr 0.001935 |  8.61 ms | loss 0.00265 | ppl     1.00 | mae 0.02615 | mape 0.039012
# | epoch  47 |    82/  205 batches | lr 0.001935 |  8.47 ms | loss 0.00091 | ppl     1.00 | mae 0.04650 | mape 0.08159
# | epoch  47 |   123/  205 batches | lr 0.001935 |  8.51 ms | loss 0.00432 | ppl     1.00 | mae 0.03322 | mape 0.054751
# | epoch  47 |   164/  205 batches | lr 0.001935 |  8.47 ms | loss 0.00207 | ppl     1.00 | mae 0.04858 | mape 0.076312
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  47 | time:  1.79s | valid loss 0.22614 | valid ppl     1.25 | valid MAE 0.03710 | valid MAPE 0.07030
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  48 |    41/  205 batches | lr 0.001896 |  8.85 ms | loss 0.00260 | ppl     1.00 | mae 0.02220 | mape 0.033164
# | epoch  48 |    82/  205 batches | lr 0.001896 |  8.41 ms | loss 0.00090 | ppl     1.00 | mae 0.04770 | mape 0.083842
# | epoch  48 |   123/  205 batches | lr 0.001896 |  8.34 ms | loss 0.00426 | ppl     1.00 | mae 0.03239 | mape 0.053199
# | epoch  48 |   164/  205 batches | lr 0.001896 |  8.13 ms | loss 0.00198 | ppl     1.00 | mae 0.04793 | mape 0.075338
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  48 | time:  1.78s | valid loss 0.23609 | valid ppl     1.27 | valid MAE 0.03702 | valid MAPE 0.06992
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  49 |    41/  205 batches | lr 0.001858 |  8.82 ms | loss 0.00252 | ppl     1.00 | mae 0.02032 | mape 0.030327
# | epoch  49 |    82/  205 batches | lr 0.001858 |  8.35 ms | loss 0.00088 | ppl     1.00 | mae 0.04717 | mape 0.082768
# | epoch  49 |   123/  205 batches | lr 0.001858 |  8.47 ms | loss 0.00411 | ppl     1.00 | mae 0.03096 | mape 0.050716
# | epoch  49 |   164/  205 batches | lr 0.001858 |  8.46 ms | loss 0.00190 | ppl     1.00 | mae 0.04788 | mape 0.076067
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  49 | time:  1.80s | valid loss 0.22728 | valid ppl     1.26 | valid MAE 0.03655 | valid MAPE 0.06900
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  50 |    41/  205 batches | lr 0.001821 |  8.59 ms | loss 0.00242 | ppl     1.00 | mae 0.02281 | mape 0.034034
# | epoch  50 |    82/  205 batches | lr 0.001821 |  8.80 ms | loss 0.00085 | ppl     1.00 | mae 0.04481 | mape 0.078122
# | epoch  50 |   123/  205 batches | lr 0.001821 |  8.67 ms | loss 0.00391 | ppl     1.00 | mae 0.02944 | mape 0.047338
# | epoch  50 |   164/  205 batches | lr 0.001821 |  8.67 ms | loss 0.00182 | ppl     1.00 | mae 0.04563 | mape 0.072097
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  50 | time:  1.82s | valid loss 0.21702 | valid ppl     1.24 | valid MAE 0.03590 | valid MAPE 0.06804
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  51 |    41/  205 batches | lr 0.001784 |  8.65 ms | loss 0.00240 | ppl     1.00 | mae 0.01921 | mape 0.028689
# | epoch  51 |    82/  205 batches | lr 0.001784 |  8.32 ms | loss 0.00073 | ppl     1.00 | mae 0.04052 | mape 0.069129
# | epoch  51 |   123/  205 batches | lr 0.001784 |  8.27 ms | loss 0.00371 | ppl     1.00 | mae 0.03037 | mape 0.049823
# | epoch  51 |   164/  205 batches | lr 0.001784 |  8.54 ms | loss 0.00192 | ppl     1.00 | mae 0.04760 | mape 0.075571
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  51 | time:  1.79s | valid loss 0.22597 | valid ppl     1.25 | valid MAE 0.03594 | valid MAPE 0.06798
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  52 |    41/  205 batches | lr 0.001749 |  8.85 ms | loss 0.00233 | ppl     1.00 | mae 0.01704 | mape 0.025475
# | epoch  52 |    82/  205 batches | lr 0.001749 |  8.66 ms | loss 0.00082 | ppl     1.00 | mae 0.04217 | mape 0.073269
# | epoch  52 |   123/  205 batches | lr 0.001749 |  8.48 ms | loss 0.00358 | ppl     1.00 | mae 0.02874 | mape 0.046588
# | epoch  52 |   164/  205 batches | lr 0.001749 |  8.24 ms | loss 0.00184 | ppl     1.00 | mae 0.04433 | mape 0.070399
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  52 | time:  1.79s | valid loss 0.22090 | valid ppl     1.25 | valid MAE 0.03545 | valid MAPE 0.06707
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  53 |    41/  205 batches | lr 0.001714 |  8.72 ms | loss 0.00226 | ppl     1.00 | mae 0.01836 | mape 0.027409
# | epoch  53 |    82/  205 batches | lr 0.001714 |  8.41 ms | loss 0.00078 | ppl     1.00 | mae 0.04079 | mape 0.070405
# | epoch  53 |   123/  205 batches | lr 0.001714 |  8.40 ms | loss 0.00350 | ppl     1.00 | mae 0.02750 | mape 0.044886
# | epoch  53 |   164/  205 batches | lr 0.001714 |  8.71 ms | loss 0.00181 | ppl     1.00 | mae 0.04519 | mape 0.072456
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  53 | time:  1.80s | valid loss 0.21748 | valid ppl     1.24 | valid MAE 0.03500 | valid MAPE 0.06613
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  54 |    41/  205 batches | lr 0.001679 |  8.68 ms | loss 0.00223 | ppl     1.00 | mae 0.01895 | mape 0.02828
# | epoch  54 |    82/  205 batches | lr 0.001679 |  8.55 ms | loss 0.00077 | ppl     1.00 | mae 0.04085 | mape 0.07061
# | epoch  54 |   123/  205 batches | lr 0.001679 |  8.52 ms | loss 0.00347 | ppl     1.00 | mae 0.02773 | mape 0.045454
# | epoch  54 |   164/  205 batches | lr 0.001679 |  8.41 ms | loss 0.00168 | ppl     1.00 | mae 0.04308 | mape 0.069487
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  54 | time:  1.80s | valid loss 0.21822 | valid ppl     1.24 | valid MAE 0.03460 | valid MAPE 0.06521
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  55 |    41/  205 batches | lr 0.001646 |  8.73 ms | loss 0.00217 | ppl     1.00 | mae 0.01873 | mape 0.027982
# | epoch  55 |    82/  205 batches | lr 0.001646 |  8.54 ms | loss 0.00074 | ppl     1.00 | mae 0.03960 | mape 0.068202
# | epoch  55 |   123/  205 batches | lr 0.001646 |  8.42 ms | loss 0.00342 | ppl     1.00 | mae 0.02748 | mape 0.045241
# | epoch  55 |   164/  205 batches | lr 0.001646 |  8.40 ms | loss 0.00168 | ppl     1.00 | mae 0.04378 | mape 0.07058
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  55 | time:  1.82s | valid loss 0.22043 | valid ppl     1.25 | valid MAE 0.03355 | valid MAPE 0.06390
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  56 |    41/  205 batches | lr 0.001613 |  8.61 ms | loss 0.00222 | ppl     1.00 | mae 0.01693 | mape 0.025338
# | epoch  56 |    82/  205 batches | lr 0.001613 |  8.60 ms | loss 0.00072 | ppl     1.00 | mae 0.03924 | mape 0.067398
# | epoch  56 |   123/  205 batches | lr 0.001613 |  8.44 ms | loss 0.00349 | ppl     1.00 | mae 0.03007 | mape 0.050196
# | epoch  56 |   164/  205 batches | lr 0.001613 |  8.59 ms | loss 0.00165 | ppl     1.00 | mae 0.04154 | mape 0.066719
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  56 | time:  1.80s | valid loss 0.21966 | valid ppl     1.25 | valid MAE 0.03387 | valid MAPE 0.06409
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  57 |    41/  205 batches | lr 0.001581 |  8.60 ms | loss 0.00213 | ppl     1.00 | mae 0.01882 | mape 0.02812
# | epoch  57 |    82/  205 batches | lr 0.001581 |  8.59 ms | loss 0.00075 | ppl     1.00 | mae 0.04052 | mape 0.070222
# | epoch  57 |   123/  205 batches | lr 0.001581 |  8.49 ms | loss 0.00343 | ppl     1.00 | mae 0.02837 | mape 0.047133
# | epoch  57 |   164/  205 batches | lr 0.001581 |  8.18 ms | loss 0.00163 | ppl     1.00 | mae 0.04109 | mape 0.066039
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  57 | time:  1.78s | valid loss 0.21968 | valid ppl     1.25 | valid MAE 0.03345 | valid MAPE 0.06357
# ----------------------------------------------------------------------------------------------------------------------
# | epoch  58 |    41/  205 batches | lr 0.001549 |  8.53 ms | loss 0.00209 | ppl     1.00 | mae 0.01797 | mape 0.026871
# | epoch  58 |    82/  205 batches | lr 0.001549 |  8.16 ms | loss 0.00075 | ppl     1.00 | mae 0.04032 | mape 0.069858
# | epoch  58 |   123/  205 batches | lr 0.001549 |  8.71 ms | loss 0.00339 | ppl     1.00 | mae 0.02955 | mape 0.049396
# | epoch  58 |   164/  205 batches | lr 0.001549 |  8.55 ms | loss 0.00162 | ppl     1.00 | mae 0.04186 | mape 0.067383
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch  58 | time:  1.79s | valid loss 0.23214 | valid ppl     1.26 | valid MAE 0.03318 | valid MAPE 0.06333
# ...
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 982 |    41/  205 batches | lr 0.000000 |  8.48 ms | loss 0.00114 | ppl     1.00 | mae 0.01439 | mape 0.021476
# | epoch 982 |    82/  205 batches | lr 0.000000 |  8.14 ms | loss 0.00037 | ppl     1.00 | mae 0.02913 | mape 0.048067
# | epoch 982 |   123/  205 batches | lr 0.000000 |  8.06 ms | loss 0.00139 | ppl     1.00 | mae 0.02171 | mape 0.034966
# | epoch 982 |   164/  205 batches | lr 0.000000 |  8.26 ms | loss 0.00067 | ppl     1.00 | mae 0.02787 | mape 0.046193
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 982 | time:  1.73s | valid loss 0.19583 | valid ppl     1.22 | valid MAE 0.02645 | valid MAPE 0.05105
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 983 |    41/  205 batches | lr 0.000000 |  8.41 ms | loss 0.00114 | ppl     1.00 | mae 0.01439 | mape 0.021476
# | epoch 983 |    82/  205 batches | lr 0.000000 |  8.39 ms | loss 0.00037 | ppl     1.00 | mae 0.02913 | mape 0.048067
# | epoch 983 |   123/  205 batches | lr 0.000000 |  8.19 ms | loss 0.00139 | ppl     1.00 | mae 0.02171 | mape 0.034966
# | epoch 983 |   164/  205 batches | lr 0.000000 |  8.13 ms | loss 0.00067 | ppl     1.00 | mae 0.02787 | mape 0.046193
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 983 | time:  1.75s | valid loss 0.19583 | valid ppl     1.22 | valid MAE 0.02645 | valid MAPE 0.05105
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 984 |    41/  205 batches | lr 0.000000 |  8.36 ms | loss 0.00114 | ppl     1.00 | mae 0.01439 | mape 0.021476
# | epoch 984 |    82/  205 batches | lr 0.000000 |  8.10 ms | loss 0.00037 | ppl     1.00 | mae 0.02913 | mape 0.048067
# | epoch 984 |   123/  205 batches | lr 0.000000 |  8.57 ms | loss 0.00139 | ppl     1.00 | mae 0.02171 | mape 0.034966
# | epoch 984 |   164/  205 batches | lr 0.000000 |  8.25 ms | loss 0.00067 | ppl     1.00 | mae 0.02787 | mape 0.046193
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 984 | time:  1.76s | valid loss 0.19583 | valid ppl     1.22 | valid MAE 0.02645 | valid MAPE 0.05105
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 985 |    41/  205 batches | lr 0.000000 |  8.65 ms | loss 0.00114 | ppl     1.00 | mae 0.01439 | mape 0.021476
# | epoch 985 |    82/  205 batches | lr 0.000000 |  8.32 ms | loss 0.00037 | ppl     1.00 | mae 0.02913 | mape 0.048067
# | epoch 985 |   123/  205 batches | lr 0.000000 |  8.17 ms | loss 0.00139 | ppl     1.00 | mae 0.02171 | mape 0.034966
# | epoch 985 |   164/  205 batches | lr 0.000000 |  8.10 ms | loss 0.00067 | ppl     1.00 | mae 0.02787 | mape 0.046193
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 985 | time:  1.75s | valid loss 0.19583 | valid ppl     1.22 | valid MAE 0.02645 | valid MAPE 0.05105
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 986 |    41/  205 batches | lr 0.000000 |  8.33 ms | loss 0.00114 | ppl     1.00 | mae 0.01439 | mape 0.021476
# | epoch 986 |    82/  205 batches | lr 0.000000 |  8.41 ms | loss 0.00037 | ppl     1.00 | mae 0.02913 | mape 0.048067
# | epoch 986 |   123/  205 batches | lr 0.000000 |  8.48 ms | loss 0.00139 | ppl     1.00 | mae 0.02171 | mape 0.034966
# | epoch 986 |   164/  205 batches | lr 0.000000 |  8.50 ms | loss 0.00067 | ppl     1.00 | mae 0.02787 | mape 0.046193
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 986 | time:  1.78s | valid loss 0.19583 | valid ppl     1.22 | valid MAE 0.02645 | valid MAPE 0.05105
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 987 |    41/  205 batches | lr 0.000000 |  8.69 ms | loss 0.00114 | ppl     1.00 | mae 0.01439 | mape 0.021476
# | epoch 987 |    82/  205 batches | lr 0.000000 |  8.16 ms | loss 0.00037 | ppl     1.00 | mae 0.02913 | mape 0.048067
# | epoch 987 |   123/  205 batches | lr 0.000000 |  8.12 ms | loss 0.00139 | ppl     1.00 | mae 0.02171 | mape 0.034966
# | epoch 987 |   164/  205 batches | lr 0.000000 |  8.13 ms | loss 0.00067 | ppl     1.00 | mae 0.02787 | mape 0.046193
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 987 | time:  1.75s | valid loss 0.19583 | valid ppl     1.22 | valid MAE 0.02645 | valid MAPE 0.05105
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 988 |    41/  205 batches | lr 0.000000 |  8.82 ms | loss 0.00114 | ppl     1.00 | mae 0.01439 | mape 0.021476
# | epoch 988 |    82/  205 batches | lr 0.000000 |  8.30 ms | loss 0.00037 | ppl     1.00 | mae 0.02913 | mape 0.048067
# | epoch 988 |   123/  205 batches | lr 0.000000 |  8.32 ms | loss 0.00139 | ppl     1.00 | mae 0.02171 | mape 0.034966
# | epoch 988 |   164/  205 batches | lr 0.000000 |  8.38 ms | loss 0.00067 | ppl     1.00 | mae 0.02787 | mape 0.046193
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 988 | time:  1.79s | valid loss 0.19583 | valid ppl     1.22 | valid MAE 0.02645 | valid MAPE 0.05105
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 989 |    41/  205 batches | lr 0.000000 |  8.66 ms | loss 0.00114 | ppl     1.00 | mae 0.01439 | mape 0.021476
# | epoch 989 |    82/  205 batches | lr 0.000000 |  8.53 ms | loss 0.00037 | ppl     1.00 | mae 0.02913 | mape 0.048067
# | epoch 989 |   123/  205 batches | lr 0.000000 |  8.31 ms | loss 0.00139 | ppl     1.00 | mae 0.02171 | mape 0.034966
# | epoch 989 |   164/  205 batches | lr 0.000000 |  8.26 ms | loss 0.00067 | ppl     1.00 | mae 0.02787 | mape 0.046193
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 989 | time:  1.78s | valid loss 0.19583 | valid ppl     1.22 | valid MAE 0.02645 | valid MAPE 0.05105
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 990 |    41/  205 batches | lr 0.000000 |  8.47 ms | loss 0.00114 | ppl     1.00 | mae 0.01439 | mape 0.021476
# | epoch 990 |    82/  205 batches | lr 0.000000 |  8.54 ms | loss 0.00037 | ppl     1.00 | mae 0.02913 | mape 0.048067
# | epoch 990 |   123/  205 batches | lr 0.000000 |  9.31 ms | loss 0.00139 | ppl     1.00 | mae 0.02171 | mape 0.034966
# | epoch 990 |   164/  205 batches | lr 0.000000 |  9.07 ms | loss 0.00067 | ppl     1.00 | mae 0.02787 | mape 0.046193
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 990 | time:  1.87s | valid loss 0.19583 | valid ppl     1.22 | valid MAE 0.02645 | valid MAPE 0.05105
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 991 |    41/  205 batches | lr 0.000000 |  8.83 ms | loss 0.00114 | ppl     1.00 | mae 0.01439 | mape 0.021476
# | epoch 991 |    82/  205 batches | lr 0.000000 |  8.17 ms | loss 0.00037 | ppl     1.00 | mae 0.02913 | mape 0.048067
# | epoch 991 |   123/  205 batches | lr 0.000000 |  8.20 ms | loss 0.00139 | ppl     1.00 | mae 0.02171 | mape 0.034966
# | epoch 991 |   164/  205 batches | lr 0.000000 |  8.23 ms | loss 0.00067 | ppl     1.00 | mae 0.02787 | mape 0.046193
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 991 | time:  1.76s | valid loss 0.19583 | valid ppl     1.22 | valid MAE 0.02645 | valid MAPE 0.05105
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 992 |    41/  205 batches | lr 0.000000 |  8.35 ms | loss 0.00114 | ppl     1.00 | mae 0.01439 | mape 0.021476
# | epoch 992 |    82/  205 batches | lr 0.000000 |  8.45 ms | loss 0.00037 | ppl     1.00 | mae 0.02913 | mape 0.048067
# | epoch 992 |   123/  205 batches | lr 0.000000 |  8.40 ms | loss 0.00139 | ppl     1.00 | mae 0.02171 | mape 0.034966
# | epoch 992 |   164/  205 batches | lr 0.000000 |  8.91 ms | loss 0.00067 | ppl     1.00 | mae 0.02787 | mape 0.046193
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 992 | time:  1.79s | valid loss 0.19583 | valid ppl     1.22 | valid MAE 0.02645 | valid MAPE 0.05105
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 993 |    41/  205 batches | lr 0.000000 |  8.71 ms | loss 0.00114 | ppl     1.00 | mae 0.01439 | mape 0.021476
# | epoch 993 |    82/  205 batches | lr 0.000000 |  8.27 ms | loss 0.00037 | ppl     1.00 | mae 0.02913 | mape 0.048067
# | epoch 993 |   123/  205 batches | lr 0.000000 |  8.40 ms | loss 0.00139 | ppl     1.00 | mae 0.02171 | mape 0.034966
# | epoch 993 |   164/  205 batches | lr 0.000000 |  8.26 ms | loss 0.00067 | ppl     1.00 | mae 0.02787 | mape 0.046193
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 993 | time:  1.76s | valid loss 0.19583 | valid ppl     1.22 | valid MAE 0.02645 | valid MAPE 0.05105
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 994 |    41/  205 batches | lr 0.000000 |  8.64 ms | loss 0.00114 | ppl     1.00 | mae 0.01439 | mape 0.021476
# | epoch 994 |    82/  205 batches | lr 0.000000 |  8.42 ms | loss 0.00037 | ppl     1.00 | mae 0.02913 | mape 0.048067
# | epoch 994 |   123/  205 batches | lr 0.000000 |  8.21 ms | loss 0.00139 | ppl     1.00 | mae 0.02171 | mape 0.034966
# | epoch 994 |   164/  205 batches | lr 0.000000 |  8.17 ms | loss 0.00067 | ppl     1.00 | mae 0.02787 | mape 0.046193
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 994 | time:  1.76s | valid loss 0.19583 | valid ppl     1.22 | valid MAE 0.02645 | valid MAPE 0.05105
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 995 |    41/  205 batches | lr 0.000000 |  8.35 ms | loss 0.00114 | ppl     1.00 | mae 0.01439 | mape 0.021476
# | epoch 995 |    82/  205 batches | lr 0.000000 |  8.37 ms | loss 0.00037 | ppl     1.00 | mae 0.02913 | mape 0.048067
# | epoch 995 |   123/  205 batches | lr 0.000000 |  8.33 ms | loss 0.00139 | ppl     1.00 | mae 0.02171 | mape 0.034966
# | epoch 995 |   164/  205 batches | lr 0.000000 |  8.18 ms | loss 0.00067 | ppl     1.00 | mae 0.02787 | mape 0.046193
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 995 | time:  1.75s | valid loss 0.19583 | valid ppl     1.22 | valid MAE 0.02645 | valid MAPE 0.05105
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 996 |    41/  205 batches | lr 0.000000 |  8.39 ms | loss 0.00114 | ppl     1.00 | mae 0.01439 | mape 0.021476
# | epoch 996 |    82/  205 batches | lr 0.000000 |  8.71 ms | loss 0.00037 | ppl     1.00 | mae 0.02913 | mape 0.048067
# | epoch 996 |   123/  205 batches | lr 0.000000 |  8.16 ms | loss 0.00139 | ppl     1.00 | mae 0.02171 | mape 0.034966
# | epoch 996 |   164/  205 batches | lr 0.000000 |  8.56 ms | loss 0.00067 | ppl     1.00 | mae 0.02787 | mape 0.046193
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 996 | time:  1.79s | valid loss 0.19583 | valid ppl     1.22 | valid MAE 0.02645 | valid MAPE 0.05105
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 997 |    41/  205 batches | lr 0.000000 |  8.93 ms | loss 0.00114 | ppl     1.00 | mae 0.01439 | mape 0.021476
# | epoch 997 |    82/  205 batches | lr 0.000000 |  8.77 ms | loss 0.00037 | ppl     1.00 | mae 0.02913 | mape 0.048067
# | epoch 997 |   123/  205 batches | lr 0.000000 |  8.89 ms | loss 0.00139 | ppl     1.00 | mae 0.02171 | mape 0.034966
# | epoch 997 |   164/  205 batches | lr 0.000000 |  8.63 ms | loss 0.00067 | ppl     1.00 | mae 0.02787 | mape 0.046193
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 997 | time:  1.84s | valid loss 0.19583 | valid ppl     1.22 | valid MAE 0.02645 | valid MAPE 0.05105
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 998 |    41/  205 batches | lr 0.000000 |  9.56 ms | loss 0.00114 | ppl     1.00 | mae 0.01439 | mape 0.021476
# | epoch 998 |    82/  205 batches | lr 0.000000 |  8.88 ms | loss 0.00037 | ppl     1.00 | mae 0.02913 | mape 0.048067
# | epoch 998 |   123/  205 batches | lr 0.000000 |  8.75 ms | loss 0.00139 | ppl     1.00 | mae 0.02171 | mape 0.034966
# | epoch 998 |   164/  205 batches | lr 0.000000 |  8.55 ms | loss 0.00067 | ppl     1.00 | mae 0.02787 | mape 0.046193
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 998 | time:  1.87s | valid loss 0.19583 | valid ppl     1.22 | valid MAE 0.02645 | valid MAPE 0.05105
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 999 |    41/  205 batches | lr 0.000000 |  8.84 ms | loss 0.00114 | ppl     1.00 | mae 0.01439 | mape 0.021476
# | epoch 999 |    82/  205 batches | lr 0.000000 |  8.34 ms | loss 0.00037 | ppl     1.00 | mae 0.02913 | mape 0.048067
# | epoch 999 |   123/  205 batches | lr 0.000000 |  8.29 ms | loss 0.00139 | ppl     1.00 | mae 0.02171 | mape 0.034966
# | epoch 999 |   164/  205 batches | lr 0.000000 |  8.98 ms | loss 0.00067 | ppl     1.00 | mae 0.02787 | mape 0.046193
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 999 | time:  1.81s | valid loss 0.19583 | valid ppl     1.22 | valid MAE 0.02645 | valid MAPE 0.05105
# ----------------------------------------------------------------------------------------------------------------------
# | epoch 1000 |    41/  205 batches | lr 0.000000 |  8.79 ms | loss 0.00114 | ppl     1.00 | mae 0.01439 | mape 0.021476
# | epoch 1000 |    82/  205 batches | lr 0.000000 |  8.49 ms | loss 0.00037 | ppl     1.00 | mae 0.02913 | mape 0.048067
# | epoch 1000 |   123/  205 batches | lr 0.000000 |  8.43 ms | loss 0.00139 | ppl     1.00 | mae 0.02171 | mape 0.034966
# | epoch 1000 |   164/  205 batches | lr 0.000000 |  8.47 ms | loss 0.00067 | ppl     1.00 | mae 0.02787 | mape 0.046193
# ----------------------------------------------------------------------------------------------------------------------
# | end of epoch 1000 | time:  1.79s | valid loss 0.19583 | valid ppl     1.22 | valid MAE 0.02645 | valid MAPE 0.05105
# ----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Evaluate the model

# %%
# load the bets model
model.load_state_dict(torch.load('tranformer_models/state_dict.pt'))
# Out:
# <All keys matched successfully>

# %%
summary(model=model, input_size=(32, 128, 5))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# TimeSeriesTransformer                         [32, 1]                   593,024
# ├─Time2Vector: 1-1                            [32, 128, 2]              512
# ├─TransformerEncoder: 1-2                     [32, 7, 128]              --
# │    └─ModuleList: 2-1                        --                        --
# │    │    └─TransformerEncoderLayer: 3-1      [32, 7, 128]              593,024
# ├─Linear: 1-3                                 [32, 1]                   129
# ===============================================================================================
# Total params: 1,186,689
# Trainable params: 1,186,689
# Non-trainable params: 0
# Total mult-adds (M): 18.96
# ===============================================================================================
# Input size (MB): 0.08
# Forward/backward pass size (MB): 4.42
# Params size (MB): 2.11
# Estimated Total Size (MB): 6.62
# ===============================================================================================

# %%
model
# Out:
# TimeSeriesTransformer(
#   (t2v): Time2Vector()
#   (encoder_layer): TransformerEncoderLayer(
#     (self_attn): MultiheadAttention(
#       (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#     )
#     (linear1): Linear(in_features=128, out_features=2048, bias=True)
#     (dropout): Dropout(p=0.0, inplace=False)
#     (linear2): Linear(in_features=2048, out_features=128, bias=True)
#     (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     (dropout1): Dropout(p=0.0, inplace=False)
#     (dropout2): Dropout(p=0.0, inplace=False)
#   )
#   (transformer_encoder): TransformerEncoder(
#     (layers): ModuleList(
#       (0): TransformerEncoderLayer(
#         (self_attn): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=128, out_features=128, bias=True)
#         )
#         (linear1): Linear(in_features=128, out_features=2048, bias=True)
#         (dropout): Dropout(p=0.0, inplace=False)
#         (linear2): Linear(in_features=2048, out_features=128, bias=True)
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (dropout1): Dropout(p=0.0, inplace=False)
#         (dropout2): Dropout(p=0.0, inplace=False)
#       )
#     )
#   )
#   (decoder): Linear(in_features=128, out_features=1, bias=True)
# )

# %% [markdown]
# ## Mean Absolute Error and Mean Absolute Percentage Error evaluations

# %%
evaluation_plots(
    train_mae=train_mae, train_mape=train_mape, 
    val_mae=val_mae, val_mape=val_mape
)
# Out:
# Train -> MAE: 0.02031993865966797 | MAPE: 0.03313007205724716
# Validation -> MAE: 0.026445839554071426 | MAPE: 0.05105065926909447

# %%
test_preds = test_predictions(model=model, test_loader=test_loader)
# Out:
# Test loss: 0.005

# %%
plot_predictions(test_preds=test_preds, test_loader=test_loader)
